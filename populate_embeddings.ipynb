# %% [markdown]
# # Populate Profile Embeddings
#
# This notebook populates the `profile_embedding` field for all ServiceProviderProfile records using OpenAI embeddings.

# %% [markdown]
# ## 1. Setup Django Environment

# %%
import os
import sys
import django
from pathlib import Path

# Setup Django path and settings
notebook_dir = Path.cwd()
django_path = notebook_dir / 'growbal_django'
sys.path.insert(0, str(django_path))

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "growbal.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

django.setup()

print("✅ Django environment setup complete")
# Out:
# ✅ Django environment setup complete

# %% [markdown]
# ## 2. Import Required Modules

# %%
from accounts.models import ServiceProviderProfile
from accounts.embedding_utils import EmbeddingGenerator, bulk_update_embeddings
from django.db.models import Q
import time

print("✅ Modules imported successfully")
# Out:
# ✅ Modules imported successfully

# %% [markdown]
# ## 3. Check Current Profile Status

# %%
# Get counts
total_profiles = ServiceProviderProfile.objects.count()
profiles_with_embeddings = ServiceProviderProfile.objects.filter(profile_embedding__isnull=False).count()
profiles_without_embeddings = ServiceProviderProfile.objects.filter(profile_embedding__isnull=True).count()

print(f"📊 Profile Statistics:")
print(f"   Total profiles: {total_profiles}")
print(f"   With embeddings: {profiles_with_embeddings}")
print(f"   Without embeddings: {profiles_without_embeddings}")
# Out:
# 📊 Profile Statistics:
#    Total profiles: 482
#    With embeddings: 482
#    Without embeddings: 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 4. Initialize Embedding Generator

# %%
# Initialize the embedding generator
# It will automatically load the API key from environment variables
generator = EmbeddingGenerator()

# Verify API key is loaded
if generator.api_key:
    print(f"✅ OpenAI API key loaded (using model: {generator.model})")
else:
    print("❌ OpenAI API key not found! Please set OPENAI_API_KEY in environment variables.")
# Out:
# ✅ OpenAI API key loaded (using model: text-embedding-ada-002)

# %% [markdown]
# ## 5. Populate Embeddings for All Profiles
#
# This will generate embeddings for all profiles that don't have them yet.

# %%
# Get profiles without embeddings
profiles_to_update = ServiceProviderProfile.objects.filter(profile_embedding__isnull=True)
count_to_update = profiles_to_update.count()

if count_to_update == 0:
    print("✅ All profiles already have embeddings!")
else:
    print(f"🚀 Starting to generate embeddings for {count_to_update} profiles...")
    print(f"   (Processing in batches of 10)\n")
    
    start_time = time.time()
    
    # Use the bulk update function
    bulk_update_embeddings(profiles=profiles_to_update)
    
    elapsed_time = time.time() - start_time
    
    print(f"\n✅ Embedding generation complete!")
    print(f"   Time taken: {elapsed_time:.2f} seconds")
    print(f"   Average time per profile: {elapsed_time/count_to_update:.2f} seconds")
# Out:
# 🚀 Starting to generate embeddings for 482 profiles...
#    (Processing in batches of 10)
#
# Updated embedding for profile: 111 Group (1/482)
# Updated embedding for profile: 360 Chartered Accountants (2/482)
# Updated embedding for profile: 91Travel and Immigration (3/482)
# Updated embedding for profile: 3E Accounting India (4/482)
# Updated embedding for profile: A&A Associate LLC (5/482)
# Updated embedding for profile: AEY Group (6/482)
# Updated embedding for profile: AKA Management Consultancy (7/482)
# Updated embedding for profile: A & H Consultants LLC (8/482)
# Updated embedding for profile: AMA Accounting (9/482)
# Updated embedding for profile: AAA Associates Immigration Services (10/482)
# Updated embedding for profile: A.V. Immigration & Careers Consultancy Pvt. Ltd. (Apex Visas) (11/482)
# Updated embedding for profile: ACDORA DMCC (12/482)
# Updated embedding for profile: Abu Dhabi Global Market (ADGM) (13/482)
# Updated embedding for profile: AKM Global (14/482)
# Updated embedding for profile: AKT Associates (15/482)
# Updated embedding for profile: Al Nabaha Consultancies LLC (16/482)
# Updated embedding for profile: AMA Audit Tax Advisory (17/482)
# Updated embedding for profile: AMCA Auditing (18/482)
# Updated embedding for profile: ARC Associates (19/482)
# Updated embedding for profile: AX CAPITAL (20/482)
# Updated embedding for profile: A1 Properties (21/482)
# Updated embedding for profile: AB Capital Services FZE (22/482)
# Updated embedding for profile: Abdul Majeed Al Marzooqi Auditing (23/482)
# Updated embedding for profile: AD Ports Group (24/482)
# Updated embedding for profile: Adepts Chartered Accountants (25/482)
# Updated embedding for profile: AGL & Co. Consulting (26/482)
# Updated embedding for profile: Ahmed Hassanien Group (AHG) (27/482)
# Updated embedding for profile: AHL AL KHIBRA TAX CONSULTANCIES CO. L.L.C (28/482)
# Updated embedding for profile: AIMS Immigration & Relocation Specialist (29/482)
# Updated embedding for profile: AIX Consultancy (30/482)
# Updated embedding for profile: Al Arish Tax Consultancy (31/482)
# Updated embedding for profile: Al Jern General Trading LLC (32/482)
# Updated embedding for profile: Bizvise Business Setup (33/482)
# Updated embedding for profile: AY (Astute Tax Consultancy & Yaqoob Alhammadi Auditing) (34/482)
# Updated embedding for profile: Abode Options (35/482)
# Updated embedding for profile: Accounting Drive (36/482)
# Updated embedding for profile: Acuvat Auditing (37/482)
# Updated embedding for profile: Ad Astra IRC (38/482)
# Updated embedding for profile: Affiniax Partners (39/482)
# Updated embedding for profile: Agarwal Taxcon Private Limited (40/482)
# Updated embedding for profile: Ajman Free Zone (41/482)
# Updated embedding for profile: Ajman Media City Free Zone (42/482)
# Updated embedding for profile: Al Arabiya Group (43/482)
# Updated embedding for profile: Al Motakamela Tax Consultancy L.L.C. (44/482)
# Updated embedding for profile: Al Tamayuz Accounting & Bookkeeping (45/482)
# Updated embedding for profile: Al Zarooni Tureva (46/482)
# Updated embedding for profile: Al Bassam Accounting, Tax, and Consultancy (47/482)
# Updated embedding for profile: Allied Accountants (48/482)
# Updated embedding for profile: Ardor Global Consultancy (49/482)
# Updated embedding for profile: Arkan Accounting (50/482)
# Updated embedding for profile: ARQ Group (51/482)
# Updated embedding for profile: Al Sudais CPA - Chartered Accountants (52/482)
# Updated embedding for profile: Astolinks International (53/482)
# Updated embedding for profile: Al Tamimi & Company (54/482)
# Updated embedding for profile: ALBADDAD (55/482)
# Updated embedding for profile: ATTO International Group (56/482)
# Updated embedding for profile: Auditax Advisory (57/482)
# Updated embedding for profile: Alchemist Accounting (58/482)
# Updated embedding for profile: Al Hadif Business Setup (59/482)
# Updated embedding for profile: Alpadis (60/482)
# Updated embedding for profile: Alphabets Group (61/482)
# Updated embedding for profile: Alterf Services (62/482)
# Updated embedding for profile: Ampcus Cyber (63/482)
# Updated embedding for profile: Anbac Advisors (64/482)
# Updated embedding for profile: Anil K. Goyal & Associates (65/482)
# Updated embedding for profile: ARDENT Advisory and Accounting LLC (66/482)
# Updated embedding for profile: Argentum FZ LLC (67/482)
# Updated embedding for profile: ARKA Consulting (68/482)
# Updated embedding for profile: A Salwan & Associates (69/482)
# Updated embedding for profile: Ask Kubeir Immigration (70/482)
# Updated embedding for profile: AuditCo UAE (71/482)
# Updated embedding for profile: AVS Immigration (72/482)
# Updated embedding for profile: AZ Group (73/482)
# Updated embedding for profile: Abacus Global (74/482)
# Updated embedding for profile: Abdallah Al Qaydi SPA Auditing (75/482)
# Updated embedding for profile: AMCA (Abdulla Al Marzooqi Chartered Accountants) (76/482)
# Updated embedding for profile: AMAJ Aljanahi Auditing (77/482)
# Updated embedding for profile: Abhinav Immigration (78/482)
# Updated embedding for profile: Abu-Ghazaleh Intellectual Property (AGIP) (79/482)
# Updated embedding for profile: Account Plus Management Consultancy (80/482)
# Updated embedding for profile: Askew CPA Consulting Firm, LLC (81/482)
# Updated embedding for profile: Ackah Business Immigration Law (82/482)
# Updated embedding for profile: Finbook Business Services (83/482)
# Updated embedding for profile: Adamjee Global Solutions (84/482)
# Updated embedding for profile: Adept Tax Consultancy (85/482)
# Updated embedding for profile: AdeptBiz Consulting (86/482)
# Updated embedding for profile: Advent Management Consultancies (87/482)
# Updated embedding for profile: Afaq Accounting & Management Services LLC (88/482)
# Updated embedding for profile: Al Tayer Auditing (89/482)
# Updated embedding for profile: Al Firas General Contracting & Steel (90/482)
# Updated embedding for profile: Al Habtoor Group LLC (91/482)
# Updated embedding for profile: ALMAIMANA (92/482)
# Updated embedding for profile: AL Mirath Real Estates (93/482)
# Updated embedding for profile: Al Reef Group (94/482)
# Updated embedding for profile: Atom Prive (95/482)
# Updated embedding for profile: Avanceon (96/482)
# Updated embedding for profile: Avyanco Business Setup Consultancy (97/482)
# Updated embedding for profile: Axiom Mark (98/482)
# Updated embedding for profile: BBNC (Decisive Tax and Compliance Solutions Private Limited) (99/482)
# Updated embedding for profile: BDO Dr. Mohamed Al-Amri & Co. (100/482)
# Updated embedding for profile: BDO Pakistan (101/482)
# Updated embedding for profile: BDO UAE (102/482)
# Updated embedding for profile: BDO India (103/482)
# Updated embedding for profile: Baker Tilly JFC Group (104/482)
# Updated embedding for profile: Al Watania Tax Consultant (ATC) (105/482)
# Updated embedding for profile: Black Stone Tax Consultancy (106/482)
# Updated embedding for profile: Albatross Immigration Consultants (107/482)
# Updated embedding for profile: Amir Ismail & Associates (AIA) (108/482)
# Updated embedding for profile: Arise Immigration Consultant (109/482)
# Updated embedding for profile: Bazaar Accounting & Management Advisors LLC (110/482)
# Updated embedding for profile: Best Solution® Business Setup Consultancy (111/482)
# Updated embedding for profile: Ascentia Corporate Services (112/482)
# Updated embedding for profile: Audiix (113/482)
# Updated embedding for profile: Big Bracket UAE (114/482)
# Updated embedding for profile: Binayah Properties LLC (115/482)
# Updated embedding for profile: Bizex LLC (116/482)
# Updated embedding for profile: Business Corridor (117/482)
# Updated embedding for profile: Business One Businessmen Services (118/482)
# Updated embedding for profile: MSZ Consultancy (119/482)
# Updated embedding for profile: Business Setup Worldwide Services FZE (120/482)
# Updated embedding for profile: BusinessBOX (121/482)
# Updated embedding for profile: Gainme (122/482)
# Updated embedding for profile: CSP Group (123/482)
# Updated embedding for profile: CFO Angle (124/482)
# Updated embedding for profile: CPA Australia (125/482)
# Updated embedding for profile: Aurega Group (126/482)
# Updated embedding for profile: Aussizz Group (127/482)
# Updated embedding for profile: Averyx Group (128/482)
# Updated embedding for profile: BI WORLDWIDE (129/482)
# Updated embedding for profile: Bookworks (130/482)
# Updated embedding for profile: Bright Universe L.L.C (131/482)
# Updated embedding for profile: The British Standards Institution (BSI) (132/482)
# Updated embedding for profile: BSP HUB LLC (133/482)
# Updated embedding for profile: BVS Global (134/482)
# Updated embedding for profile: Bait Al Khebra (135/482)
# Updated embedding for profile: Baker McKenzie (136/482)
# Updated embedding for profile: Banke International Properties (137/482)
# Updated embedding for profile: Batley Law Limited (138/482)
# Updated embedding for profile: Bayat Group (139/482)
# Updated embedding for profile: Becker Advisors Accounting & Taxation (140/482)
# Updated embedding for profile: BinHimyar Law Group (141/482)
# Updated embedding for profile: Bisdesk FZ LLC (142/482)
# Updated embedding for profile: Blackstone Legal (143/482)
# Updated embedding for profile: Boston Consulting Group (BCG) (144/482)
# Updated embedding for profile: Boundless Immigration Inc. (145/482)
# Updated embedding for profile: Brampton Immigration Consultancy (146/482)
# Updated embedding for profile: Brand Finance (147/482)
# Updated embedding for profile: British Centres for Business (BCB) (148/482)
# Updated embedding for profile: Budget UAE (149/482)
# Updated embedding for profile: CSC (Corporation Service Company) (150/482)
# Updated embedding for profile: Charterhouse Lombard Limited (151/482)
# Updated embedding for profile: DM Consultants (152/482)
# Updated embedding for profile: Commitbiz Management Consultants (153/482)
# Updated embedding for profile: COFOCSP (154/482)
# Updated embedding for profile: CorpLex Corporate Services Provider LLC (155/482)
# Updated embedding for profile: Corppluse Management Consultancy (156/482)
# Updated embedding for profile: Creation Business Consultants (157/482)
# Updated embedding for profile: Creative Zone (158/482)
# Updated embedding for profile: Credence Corporate Solutions Pvt Ltd (159/482)
# Updated embedding for profile: Business Advisors (160/482)
# Updated embedding for profile: Farahat & Co. (161/482)
# Updated embedding for profile: Crowe UAE (162/482)
# Updated embedding for profile: Cybil Solutions (163/482)
# Updated embedding for profile: DET Group (164/482)
# Updated embedding for profile: Dubai Multi Commodities Centre (DMCC) (165/482)
# Updated embedding for profile: Business Consultant UAE (166/482)
# Updated embedding for profile: Charles and Darwish Associates (CDA Corporate Services LLC) (167/482)
# Updated embedding for profile: ACCBOOKS (168/482)
# Updated embedding for profile: CTC Tax & Accounting (169/482)
# Updated embedding for profile: DP World UAE (170/482)
# Updated embedding for profile: CRC Property (Commercial Real Estate Consultants) (171/482)
# Updated embedding for profile: DUQE Free Zone (172/482)
# Updated embedding for profile: C3 - Companies Creating Change (173/482)
# Updated embedding for profile: Dancing Numbers (174/482)
# Updated embedding for profile: Calculus Management Consultancy FZCO (175/482)
# Updated embedding for profile: Capella Tax Consultancy L.L.C (176/482)
# Updated embedding for profile: Dawn Consultancy (177/482)
# Updated embedding for profile: Fahad Ahmed & Co. Chartered Accountants (178/482)
# Updated embedding for profile: Decisive Zone (179/482)
# Updated embedding for profile: Domain Conveyancing (180/482)
# Updated embedding for profile: Dubai Health Authority (181/482)
# Updated embedding for profile: Dubai Holding (182/482)
# Updated embedding for profile: Dubai South (183/482)
# Updated embedding for profile: E20 INVESTMENT Limited (184/482)
# Updated embedding for profile: EBMS Business Services LLC (185/482)
# Updated embedding for profile: ERPGulf (186/482)
# Updated embedding for profile: EWBS Excellence Business Services LLC (187/482)
# Updated embedding for profile: Easy Map Advertising LLC (188/482)
# Updated embedding for profile: Easyway Business Services (189/482)
# Updated embedding for profile: ebs Chartered Accountants (190/482)
# Updated embedding for profile: Eliteikonglobal (191/482)
# Updated embedding for profile: Emerald Softwares (192/482)
# Updated embedding for profile: CBRE Group, Inc. (193/482)
# Updated embedding for profile: CEO Connection (194/482)
# Updated embedding for profile: CMBS Middle East TAX Consultancy (195/482)
# Updated embedding for profile: Corp Advisors Corporate Services (196/482)
# Updated embedding for profile: Cyberfox Consultancy Services (197/482)
# Updated embedding for profile: CanApprove (198/482)
# Updated embedding for profile: CapiZona (199/482)
# Updated embedding for profile: Careerz4me International HR Consultancy (200/482)
# Updated embedding for profile: Centurion Immigration Consultant (201/482)
# Updated embedding for profile: Chadwell International (202/482)
# Updated embedding for profile: Channel Migration (203/482)
# Updated embedding for profile: Citizenship Invest (204/482)
# Updated embedding for profile: Clifford Chance (205/482)
# Updated embedding for profile: Cognizant (206/482)
# Updated embedding for profile: CoinPanel (207/482)
# Updated embedding for profile: College of Immigration and Citizenship Consultants (208/482)
# Updated embedding for profile: Colliers (209/482)
# Updated embedding for profile: Compliance Tax Consultancy LLC (210/482)
# Updated embedding for profile: Comus International FZCO (211/482)
# Updated embedding for profile: Concord Accounting & Taxation Services (212/482)
# Updated embedding for profile: CMS DOCUMENTS CLEARING SERVICES (213/482)
# Updated embedding for profile: Core Immigration (214/482)
# Updated embedding for profile: Corp Creators (215/482)
# Updated embedding for profile: The Corporate Group (TCG) (216/482)
# Updated embedding for profile: Cosmos Immigration (217/482)
# Updated embedding for profile: Emirates Advocates (218/482)
# Updated embedding for profile: Emirates Glass LLC (219/482)
# Updated embedding for profile: Emirates Zone (220/482)
# Updated embedding for profile: Enrich Ventures Business Setup Services LLC (221/482)
# Updated embedding for profile: Escrow Consulting Group (222/482)
# Updated embedding for profile: Europe Emirates Group (223/482)
# Updated embedding for profile: FAR Consulting Middle East (FAR-Farhat Office & Co.) (224/482)
# Updated embedding for profile: FCME Corporate Advisors (225/482)
# Updated embedding for profile: FELCO Global Documents Clearing and Business Services (226/482)
# Updated embedding for profile: PT. Fortuna Pratama Konsultan Indonesia (227/482)
# Updated embedding for profile: The Cragus Group (228/482)
# Updated embedding for profile: Crenov8 Consulting (229/482)
# Updated embedding for profile: Crescent Advisory Group (230/482)
# Updated embedding for profile: Cushman & Wakefield Core (231/482)
# Updated embedding for profile: Fairmont Bab Al Bahr (232/482)
# Updated embedding for profile: Fanar Management Consulting (233/482)
# Updated embedding for profile: FinAdvantage (234/482)
# Updated embedding for profile: Dani Shaheen Accounting & BookKeeping (235/482)
# Updated embedding for profile: Central Bank of the UAE (236/482)
# Updated embedding for profile: DAR ALMASHWRAH MANAGEMENT CONSULTANCIES L.L.C (237/482)
# Updated embedding for profile: Firm Zone Businessmen Services L.L.C (238/482)
# Updated embedding for profile: Dulkifil Abdul Rasheed Tax Consultancy (DARTC) (239/482)
# Updated embedding for profile: First Notch (240/482)
# Updated embedding for profile: DC Global Services (241/482)
# Updated embedding for profile: First Step Education & Immigration Consultancy (242/482)
# Updated embedding for profile: Flybiz (243/482)
# Updated embedding for profile: Flyway Visas (244/482)
# Updated embedding for profile: Formaco Corporate Services Provider (245/482)
# Updated embedding for profile: Fragomen (246/482)
# Updated embedding for profile: Free Zones Authority of Ajman (247/482)
# Updated embedding for profile: FZM Solutions DMCC (248/482)
# Updated embedding for profile: Freemont Oneworld Group (249/482)
# Updated embedding for profile: Fuze (250/482)
# Updated embedding for profile: GANDHI & ASSOCIATES LLP (251/482)
# Updated embedding for profile: GCCMatters (252/482)
# Updated embedding for profile: Elegant Services (253/482)
# Updated embedding for profile: Dubai Department of Economy and Tourism (DET) (254/482)
# Updated embedding for profile: DiamondRock (255/482)
# Updated embedding for profile: Dalebrook Media (256/482)
# Updated embedding for profile: Dar Alnuzum, Mahmoud Juma & Partners Public Accountants (257/482)
# Updated embedding for profile: DAS Businessman Services (258/482)
# Updated embedding for profile: DTACC (Definitive Taxation Procedures Follow Up) (259/482)
# Updated embedding for profile: Denken Solutions (260/482)
# Updated embedding for profile: Dizon & Associates (261/482)
# Updated embedding for profile: Domestic Real Estate Brokers L.L.C. (262/482)
# Updated embedding for profile: DRE Real Estate Broker LLC (263/482)
# Updated embedding for profile: Dubai Airport Freezone (DAFZ) (264/482)
# Updated embedding for profile: Dubai Chambers (265/482)
# Updated embedding for profile: Dubai Islamic Bank (DIB) (266/482)
# Updated embedding for profile: GHJ Advisors (267/482)
# Updated embedding for profile: GMD Properties (268/482)
# Updated embedding for profile: Ghassan Aboud Group (269/482)
# Updated embedding for profile: Global Gateway FZ-LLC (270/482)
# Updated embedding for profile: Global Link (271/482)
# Updated embedding for profile: GRG Corporate Services Provider (272/482)
# Updated embedding for profile: Growth Secret (273/482)
# Updated embedding for profile: HLB HAMT (274/482)
# Updated embedding for profile: HLB Saudi Arabia International Accountants (275/482)
# Updated embedding for profile: HOF Migration (276/482)
# Updated embedding for profile: Harris Group CPAs (277/482)
# Updated embedding for profile: Hashtag Startup (278/482)
# Updated embedding for profile: Elite Steps (279/482)
# Updated embedding for profile: Dubai World Trade Centre (280/482)
# Updated embedding for profile: Dubiz Consultancy L.L.C (281/482)
# Updated embedding for profile: Emirates First Business Service LLC (282/482)
# Updated embedding for profile: E.muwafaq Accountants & Tax Consultants (283/482)
# Updated embedding for profile: EMT Accounting & Taxation Services L.L.C. (284/482)
# Updated embedding for profile: ERAD UAE (285/482)
# Updated embedding for profile: ESMA Group (286/482)
# Updated embedding for profile: E-Tax Relief Consultancies LLC (287/482)
# Updated embedding for profile: EVAS International Management Consultants & Chartered Accountants (288/482)
# Updated embedding for profile: Smart Ezone Corporate Services Provider LLC (289/482)
# Updated embedding for profile: Earningo Accounting & Tax Consultancy (290/482)
# Updated embedding for profile: Effective Solutions Tax Consultants (291/482)
# Updated embedding for profile: Healy Consultants Group (292/482)
# Updated embedding for profile: Heng Sheng Group (293/482)
# Updated embedding for profile: Henley & Partners (294/482)
# Updated embedding for profile: Holborn Assets (DIFC) Limited (295/482)
# Updated embedding for profile: Savoy Central Hotel Apartments (296/482)
# Updated embedding for profile: IBG Consulting (297/482)
# Updated embedding for profile: IFZA Dubai (298/482)
# Updated embedding for profile: IMAS Business Setup & Support Services (299/482)
# Updated embedding for profile: IMC Group (300/482)
# Updated embedding for profile: INCO Group (301/482)
# Updated embedding for profile: Ibara Consultancy (302/482)
# Updated embedding for profile: Iktimal Corporate Services (303/482)
# Updated embedding for profile: Elite ATC (Elite Accountants Auditing & Tax Consultancy) (304/482)
# Updated embedding for profile: Emerald Trading Enterprises LLC (305/482)
# Updated embedding for profile: EMIR Consulting (306/482)
# Updated embedding for profile: Envoy Global (307/482)
# Updated embedding for profile: EPTA (308/482)
# Updated embedding for profile: InZone (309/482)
# Updated embedding for profile: Euro Gulf Business Bridge FZE (310/482)
# Updated embedding for profile: InstaCo Corporate Services LLC (311/482)
# Updated embedding for profile: Exceed Real Estate (312/482)
# Updated embedding for profile: Intermark Global (313/482)
# Updated embedding for profile: Excellent Financial and Tax Consultancy (314/482)
# Updated embedding for profile: Intouch Relocations (315/482)
# Updated embedding for profile: Expert Corporate Services (316/482)
# Updated embedding for profile: Expert Opinion (317/482)
# Updated embedding for profile: Financial Consultants Group (FCG) (318/482)
# Updated embedding for profile: FITRIS Management Consultants (319/482)
# Updated embedding for profile: FTI Delta (320/482)
# Updated embedding for profile: Fairmont Immigration Consultants (321/482)
# Updated embedding for profile: Fakhoury Global Immigration (322/482)
# Updated embedding for profile: Federal Outsourcing (323/482)
# Updated embedding for profile: Fichte & Co Legal Consultancy LLC (324/482)
# Updated embedding for profile: FirmDecisions (325/482)
# Updated embedding for profile: First Corner Tax Consultancy (326/482)
# Updated embedding for profile: Flow State Management Consultants L.L.C (327/482)
# Updated embedding for profile: Franchise Arabia (328/482)
# Updated embedding for profile: Jebel Ali Free Zone Authority (Jafza) (329/482)
# Updated embedding for profile: Junaidy Shoaib Asad (JSA) (330/482)
# Updated embedding for profile: Juriszone (331/482)
# Updated embedding for profile: KBA Accounting and Bookkeeping Services LLC (332/482)
# Updated embedding for profile: KPI (333/482)
# Updated embedding for profile: K. Raghu & Co. (334/482)
# Updated embedding for profile: Khawaja Tanveer & Co. (335/482)
# Updated embedding for profile: Labdhie Associates (336/482)
# Updated embedding for profile: Latitude Group (337/482)
# Updated embedding for profile: Limitless Business Avenue (338/482)
# Updated embedding for profile: London School of Business & Certified Accountants (339/482)
# Updated embedding for profile: Globevisa Group (340/482)
# Updated embedding for profile: ECOVIS Fuller International CPA (341/482)
# Updated embedding for profile: athGADLANG (342/482)
# Updated embedding for profile: Global Advertising Lawyers Alliance (GALA) (343/482)
# Updated embedding for profile: Gatestone Group (344/482)
# Updated embedding for profile: GenZone (345/482)
# Updated embedding for profile: Genome Consulting (346/482)
# Updated embedding for profile: Genpact (347/482)
# Updated embedding for profile: German Emirati Joint Council for Industry & Commerce (AHK) (348/482)
# Updated embedding for profile: Ghassan El Saheb – Public Accountants (349/482)
# Updated embedding for profile: GBMENA (350/482)
# Updated embedding for profile: Global Migrate (351/482)
# Updated embedding for profile: GlobelZone (352/482)
# Updated embedding for profile: M O J & Associates (353/482)
# Updated embedding for profile: MCA UAE (354/482)
# Updated embedding for profile: MNBK & Associates (355/482)
# Updated embedding for profile: MOR Realtors (356/482)
# Updated embedding for profile: Make Fortune (357/482)
# Updated embedding for profile: MAZ Chartered Accountants (358/482)
# Updated embedding for profile: Forvis Mazars (359/482)
# Updated embedding for profile: Meydan Free Zone (360/482)
# Updated embedding for profile: Momentum MENA (361/482)
# Updated embedding for profile: Moore UAE (362/482)
# Updated embedding for profile: Move One Inc (363/482)
# Updated embedding for profile: PheasanTech Ltd (364/482)
# Updated embedding for profile: Go Overseas (365/482)
# Updated embedding for profile: Golden Falcon Consultants (366/482)
# Updated embedding for profile: GLT TAX CONSULTANT LLC (367/482)
# Updated embedding for profile: GreenTree Immigration (368/482)
# Updated embedding for profile: Guide Consultants (369/482)
# Updated embedding for profile: Gulf Xellence (370/482)
# Updated embedding for profile: HDMS Consultants (371/482)
# Updated embedding for profile: Hitlab (372/482)
# Updated embedding for profile: Hyphen Accounting & Bookkeeping (373/482)
# Updated embedding for profile: Hadef & Partners (374/482)
# Updated embedding for profile: Hamriyah Free Zone Authority (375/482)
# Updated embedding for profile: My Business Consulting DMCC (376/482)
# Updated embedding for profile: MyVenturePro (377/482)
# Updated embedding for profile: N R Doshi & Partners (378/482)
# Updated embedding for profile: Nasser Aldosari Auditing and Consulting (379/482)
# Updated embedding for profile: NEBA Private Clients (380/482)
# Updated embedding for profile: NH Management (381/482)
# Updated embedding for profile: Nangia & Co LLP (382/482)
# Updated embedding for profile: Neeraj Bhagat & Co. (383/482)
# Updated embedding for profile: Nex Consultants (384/482)
# Updated embedding for profile: Nexia International Limited (385/482)
# Updated embedding for profile: Nexus Partners (386/482)
# Updated embedding for profile: Arabian Premier Logistics (387/482)
# Updated embedding for profile: Nimbus Consultancy (388/482)
# Updated embedding for profile: NKSD Service Private Limited (389/482)
# Updated embedding for profile: O-Square Communications Hub (390/482)
# Updated embedding for profile: ORG Logistics (391/482)
# Updated embedding for profile: Open Hub Corporate Services (392/482)
# Updated embedding for profile: PAAY & Co LLP (393/482)
# Updated embedding for profile: PKF United Arab Emirates (394/482)
# Updated embedding for profile: Prakash Sachin & Co. (395/482)
# Updated embedding for profile: Paramount Zone (396/482)
# Updated embedding for profile: Patron Accounting LLP (397/482)
# Updated embedding for profile: ProElite Consultants Private Limited (398/482)
# Updated embedding for profile: PU Professional Utilities Pvt Ltd (399/482)
# Updated embedding for profile: Profits Plus Accountants (400/482)
# Updated embedding for profile: Qoyod (401/482)
# Updated embedding for profile: Quiick Work (402/482)
# Updated embedding for profile: Quill Corporate Services (403/482)
# Updated embedding for profile: RFZ (404/482)
# Updated embedding for profile: RIF Trust (405/482)
# Updated embedding for profile: RIZ & MONA CONSULTANCY (406/482)
# Updated embedding for profile: RP Accounting Services (407/482)
# Updated embedding for profile: RVG Chartered Accountants (408/482)
# Updated embedding for profile: RadiantBiz (409/482)
# Updated embedding for profile: Ras Al Khaimah Economic Zone (RAKEZ) (410/482)
# Updated embedding for profile: Re/think (411/482)
# Updated embedding for profile: Riaz Ahmad, Saqib, Gohar & Co. (412/482)
# Updated embedding for profile: SBS and Company LLP (413/482)
# Updated embedding for profile: SFM Corporate Services (414/482)
# Updated embedding for profile: S H R & CO (415/482)
# Updated embedding for profile: SIMPLE BN DMCC (416/482)
# Updated embedding for profile: SKGY (417/482)
# Updated embedding for profile: SPS Associates (418/482)
# Updated embedding for profile: Sharjah Research, Technology and Innovation Park (SPark) (419/482)
# Updated embedding for profile: Saffery LLP (420/482)
# Updated embedding for profile: Samana Business Centre (421/482)
# Updated embedding for profile: Savory & Partners (422/482)
# Updated embedding for profile: SetMyCompany (423/482)
# Updated embedding for profile: SGY Chartered Accountants (424/482)
# Updated embedding for profile: Shah & Alshamali Associates Chartered Accountants (425/482)
# Updated embedding for profile: Sharjah Book Authority (426/482)
# Updated embedding for profile: Sharjah Media City (Shams) (427/482)
# Updated embedding for profile: Sharjah Publishing City Free Zone (SPC Free Zone) (428/482)
# Updated embedding for profile: Shuraa Business Setup (429/482)
# Updated embedding for profile: Shuraa Tax and Accounting Services L.L.C (430/482)
# Updated embedding for profile: Smart Business Creation (431/482)
# Updated embedding for profile: Smart Zone (432/482)
# Updated embedding for profile: Soundlines Group (433/482)
# Updated embedding for profile: Sovereign PPG Corporate Services (434/482)
# Updated embedding for profile: SpaceBox Business Center (435/482)
# Updated embedding for profile: Sparkle Solutions (436/482)
# Updated embedding for profile: Speciality Engineering Chemicals (SpEC) (437/482)
# Updated embedding for profile: Spicer Pegler (438/482)
# Updated embedding for profile: Studycafe Private Limited (439/482)
# Updated embedding for profile: Taxwise Services (440/482)
# Updated embedding for profile: Think Biz Business Services (441/482)
# Updated embedding for profile: Timeless Pro Services (442/482)
# Updated embedding for profile: TME Legal Consultants (443/482)
# Updated embedding for profile: TROUVAY & CAUVIN Group (444/482)
# Updated embedding for profile: TVG Management Consultancy (445/482)
# Updated embedding for profile: TVG Migration DMCC (446/482)
# Updated embedding for profile: Tally Solutions (447/482)
# Updated embedding for profile: TASS Advisors LLP (448/482)
# Updated embedding for profile: Tax Magic (449/482)
# Updated embedding for profile: TaxBuddy (450/482)
# Updated embedding for profile: TaxHelp.ae (451/482)
# Updated embedding for profile: The Accountant LLC (452/482)
# Updated embedding for profile: THE GOLDEN GAVEL (453/482)
# Updated embedding for profile: The Tax Point (454/482)
# Updated embedding for profile: GLOBAL MIGRATION SERVICES - FZCO (455/482)
# Updated embedding for profile: Titan Financial Brokers (456/482)
# Updated embedding for profile: Trade License Zone (457/482)
# Updated embedding for profile: TransTech FZ-LLC (458/482)
# Updated embedding for profile: Tulpar Global Taxation (459/482)
# Updated embedding for profile: UHY James (460/482)
# Updated embedding for profile: Unity Partners (461/482)
# Updated embedding for profile: Upwork (462/482)
# Updated embedding for profile: Utico FZC (463/482)
# Updated embedding for profile: Yousuf Adil (464/482)
# Updated embedding for profile: VJM Global (465/482)
# Updated embedding for profile: VAT Centric (466/482)
# Updated embedding for profile: Virtual Accountants LLC (467/482)
# Updated embedding for profile: Vacsolution (468/482)
# Updated embedding for profile: Virtuzone (469/482)
# Updated embedding for profile: Vispi T. Patel & Associates (470/482)
# Updated embedding for profile: WESTBOND INTERNATIONAL (471/482)
# Updated embedding for profile: Wealth Tellers (472/482)
# Updated embedding for profile: XL Financials Pvt. Ltd. (473/482)
# Updated embedding for profile: Xara GmbH (474/482)
# Updated embedding for profile: ZAF Consultants LLP (475/482)
# Updated embedding for profile: ZH Broadway Immigration Consultants (476/482)
# Updated embedding for profile: Future Vision Businessmen Services (477/482)
# Updated embedding for profile: Ideal B International FZE (478/482)
# Updated embedding for profile: Tenl Technologies (479/482)
# Updated embedding for profile: UBL Corporate Service Provider (480/482)
# Updated embedding for profile: Worldwide Accounts And Taxes Solution LLC (481/482)
# Updated embedding for profile: Y's Consultancy FZ LLE (482/482)
#
# ✅ Embedding generation complete!
#    Time taken: 582.98 seconds
#    Average time per profile: 1.21 seconds

# %% [markdown]
# ## 6. Verify Results

# %%
# Re-check counts after update
total_profiles = ServiceProviderProfile.objects.count()
profiles_with_embeddings = ServiceProviderProfile.objects.filter(profile_embedding__isnull=False).count()
profiles_without_embeddings = ServiceProviderProfile.objects.filter(profile_embedding__isnull=True).count()

print(f"📊 Updated Profile Statistics:")
print(f"   Total profiles: {total_profiles}")
print(f"   With embeddings: {profiles_with_embeddings} ✅")
print(f"   Without embeddings: {profiles_without_embeddings}")

if profiles_without_embeddings == 0:
    print("\n🎉 Success! All profiles now have embeddings.")
else:
    print(f"\n⚠️ {profiles_without_embeddings} profiles still need embeddings.")
    print("   This might be due to errors during generation. Check the output above for error messages.")
# Out:
# 📊 Updated Profile Statistics:
#    Total profiles: 482
#    With embeddings: 422 ✅
#    Without embeddings: 60
#
# ⚠️ 60 profiles still need embeddings.
#    This might be due to errors during generation. Check the output above for error messages.

# %% [markdown]
# ## 7. Test Search Functionality (Optional)
#
# Test that the embeddings work correctly for similarity search.

# %%
from accounts.embedding_utils import search_profiles_by_text

# Test search with a sample query
test_query = "software development and web design services"
print(f"🔍 Testing search with query: '{test_query}'\n")

results = search_profiles_by_text(test_query, limit=5)

if results:
    print(f"Found {len(results)} similar profiles:\n")
    for i, profile in enumerate(results, 1):
        similarity = getattr(profile, 'similarity', 'N/A')
        print(f"{i}. {profile.name}")
        print(f"   Type: {profile.provider_type}")
        print(f"   Country: {profile.country or 'Not specified'}")
        print(f"   Similarity distance: {similarity}")
        print()
else:
    print("No results found. Make sure embeddings have been generated.")

# %% [markdown]
# ## 8. Update Single Profile (If Needed)
#
# Use this cell to update embedding for a specific profile.

# %%
# Uncomment and modify to update a specific profile
# profile_name = "Your Company Name"
# 
# try:
#     profile = ServiceProviderProfile.objects.get(name=profile_name)
#     generator = EmbeddingGenerator()
#     embedding = generator.update_profile_embedding(profile)
#     print(f"✅ Updated embedding for: {profile.name}")
#     print(f"   Embedding dimensions: {len(embedding)}")
# except ServiceProviderProfile.DoesNotExist:
#     print(f"❌ Profile with name '{profile_name}' not found")
# except Exception as e:
#     print(f"❌ Error: {e}")

# %% [markdown]
# ## Notes
#
# - **API Rate Limits**: OpenAI has rate limits. The bulk update function processes profiles in batches to avoid hitting these limits.
# - **Cost**: Each embedding generation costs tokens. Monitor your OpenAI usage.
# - **Text Length**: Very long profile texts (>30,000 chars) are automatically truncated to fit OpenAI's token limits.
# - **Error Handling**: The bulk update function will continue even if some profiles fail, printing error messages for debugging.
