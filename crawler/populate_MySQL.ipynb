# %%
import os
import django
import sys
from asgiref.sync import sync_to_async

sys.path.insert(0, '/home/mohammed/Desktop/tech_projects/growbal/growbal_django')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "growbal.settings")

django.setup()

from services.models import Service
from services.serializers import ServiceSerializer
from accounts.serializers import ServiceProviderProfileSerializer
from accounts.models import ServiceProviderProfile
from asgiref.sync import sync_to_async

@sync_to_async
def load_all_services():
    services = Service.objects.all()
    serializer = ServiceSerializer(services, many=True)
    return serializer.data


# @sync_to_async
# def load_all_service_provider_profiles():
#     profiles = ServiceProviderProfile.objects.all()
#     serializer = ServiceProviderProfileSerializer(profiles, many=True)
#     return serializer.data

@sync_to_async
def load_all_service_provider_profiles():
    profiles = ServiceProviderProfile.objects.prefetch_related("services").all()
    serialized_profiles = []

    for profile in profiles:
        # Serialize profile
        profile_data = ServiceProviderProfileSerializer(profile).data
        
        # Serialize linked services
        services = profile.services.all()
        services_data = ServiceSerializer(services, many=True).data
        
        # Include services in profile dictionary
        profile_data["services"] = services_data
        
        serialized_profiles.append(profile_data)
    
    return serialized_profiles

@sync_to_async
def update_service_general_descriptions(descriptions):
    services_to_update = Service.objects.filter(
        service_description=descriptions.company_service_description
    )

    services_to_update.update(
        general_service_description=descriptions.general_service_description
    )

# %% [markdown]
# X Establishment type should be set 0 for corporate or 1 individual
# X Email is mandatory for user and establishment
# X type_service_id must be set
# X media -> media_collection -> user
# media -> profile -> establishment
# logo data population

# %%
# services = await load_all_services()
# for service in services:
#     print(service)

service_provider_profiles = await load_all_service_provider_profiles()
# print(service_provider_profiles[0].keys())
# for profile in service_provider_profiles:
#     print(profile["services"])

# %%
from collections import defaultdict

name_counts = defaultdict(list)
for profile in service_provider_profiles:
    name_counts[profile["name"]].append(profile)

duplicates = {name: profiles for name, profiles in name_counts.items() if len(profiles) > 1}

# Output the duplicates
for name, profiles in duplicates.items():
    print(f"Duplicate Name: {name}")
    for profile in profiles:
        print(profile)
    print()

# %%
import pandas as pd
import mysql.connector as mc

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── QUERY DATA FROM 'establishment' TABLE ORDERED BY creation_date ──
cur.execute(f"""
    SELECT * FROM `{SCHEMA}`.`establishment`
    ORDER BY creation_date DESC;
""")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_establishment = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ────────────────────────────────────────────
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)

print(f"Total rows: {len(df_establishment)}")

# print(df_establishment["slug"].unique().tolist())

df_establishment = df_establishment.head(60)
display(df_establishment.head(5))

# ── CLOSE CONNECTION ────────────────────────────────────────────────
cur.close()
cnx.close()
# Out:
# Total rows: 262
#     id  \
# 0  433
# 1  432
# 2  431
# 3  430
# 4  429
#
#                                                                                                                     adress  \
# 0                        Office No. 2501 - 2506, 25th Floor, Burj Al Salam, Trade Center First, Sh. Zayed Road, Dubai, UAE
# 1  Office 105, Level 1, Emaar Square – Building 4, Sheikh Mohammed Bin Rashid Boulevard Downtown Dubai, United Arab Emi...
# 2  Amer Center Al Tawar – Building – 1E – 155 Al Quds St – Al Twar – Dubai Airport Free Zone – Dubai – United Arab Emir...
# 3                                                                                                   Cluster W, JLT - Dubai
# 4                                                                                       Dubai Land Department Headquarters
#
#    blocked           company_name           creation_date  deleted  \
# 0        0           BFG Advisory 2025-06-13 07:56:36.119        0
# 1        0          Creative Zone 2025-06-13 07:56:36.117        0
# 2        0    Amer Center Al Twar 2025-06-13 07:56:36.116        0
# 3        0              Aston VIP 2025-06-13 07:56:36.114        0
# 4        0  Dubai Land Department 2025-06-13 07:56:36.111        0
#
#                                                                                                                description  \
# 0  BFG Advisory provides comprehensive Golden Visa services in the UAE with a 100% success rate. The service includes e...
# 1  Creative Zone is a leading business setup advisor in the Middle East, providing comprehensive company formation serv...
# 2  Amer Center provides comprehensive government services in Dubai, specializing in visa processing, residency applicat...
# 3  24-Hour Dubai residence VISA service with expedited processing. The service includes initial consultation, document ...
# 4  Dubai Land Department (DLD) provides real estate valuation services through accredited valuation companies. These co...
#
#   designation                   email expiry_date founded_in password  \
# 0        None    info@bfgadvisory.com        None       None     None
# 1        None   setup@creativezone.ae        None       None     None
# 2        None  main@businessindxb.com        None       None     None
# 3        None        contact@aston.ae        None       None     None
# 4        None   info@dubailand.gov.ae        None       None     None
#
#              phone representative_name      slug sub_name tax_number  type  \
# 0    +971502130288                None  DMuejeEe     None       None   0.0
# 1     800-542-3673                None  FY64Nwwy     None       None   0.0
# 2             None                None  lkRqff6w     None       None   0.0
# 3  +971 4 518 2623                None  TZ8BDKNW     None       None   0.0
# 4      97142438777                None  gI2r4qoK     None       None   0.0
#
#    verified                     web_site  city_id  country_id  \
# 0         0      https://bfgadvisory.com      NaN         NaN
# 1         0  https://www.creativezone.ae      NaN         NaN
# 2         0          https://amer.center      NaN         NaN
# 3         0             https://aston.ae      NaN         NaN
# 4         0     https://dubailand.gov.ae      NaN         NaN
#
#    cover_picture_id  licence_id  logo_id  profile_id  region_id  type_ez_id  \
# 0               NaN         NaN      NaN         NaN        NaN         NaN
# 1               NaN         NaN      NaN         NaN        NaN         NaN
# 2               NaN         NaN      NaN         NaN        NaN         NaN
# 3               NaN         NaN      NaN         NaN        NaN         NaN
# 4               NaN         NaN      NaN         NaN        NaN         NaN
#
#   user_user_id agency vision            mobile
# 0         None   None   None  +971 50 213 0327
# 1         None   None   None  +971 800 5423673
# 2         None   None   None     +971504512311
# 3         None   None   None              None
# 4         None   None   None        0585120063

# %%
import pandas as pd
import mysql.connector as mc

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`service`;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
print(len(df_service))
# df_service = df_service.head(100)
display(df_service.tail(5))
# Out:
# 156
#       id description                                                    name  \
# 151  154        None                                 UAE Government Services
# 152  155        None                              Emirates ID Typing Service
# 153  156        None  Business Setup and Company Formation Services in Dubai
# 154  157        None     Dubai Business Setup and Company Formation Services
# 155  158        None                                UAE Golden Visa Services
#
#      type_establishment  image_id  type_service_id offre_id  deleted
# 151                 NaN       NaN                1     None        0
# 152                 NaN       NaN                1     None        0
# 153                 NaN       NaN                1     None        0
# 154                 NaN       NaN                1     None        0
# 155                 NaN       NaN                1     None        0

# %%
import pandas as pd
import mysql.connector as mc
import string
import random

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)
# dict_keys(['user', 'provider_type', 'country', 'session_status', 'name', 'logo', 'website', 'linkedin', 'facebook', 'instagram', 'telephone', 'mobile', 'emails', 'office_locations', 'key_individuals', 'services'])

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`media`;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
# print(df_service["path"][0])
print(len(df_service))
# print(df_service["content_type"].unique())
# df_service = df_service.head(100)
display(df_service.head(5))
# Out:
# 2679
#    id content_type           creation_date  deleted  \
# 0   1    image/png 2023-12-25 15:04:54.135        0
# 1   2    image/png 2023-12-25 20:25:44.397        0
# 2   3    image/png 2023-12-25 20:37:59.363        0
# 3   4    image/png 2023-12-25 20:39:33.215        0
# 4   5    image/png 2023-12-25 20:48:12.370        0
#
#                                  label  \
# 0  avatar agent 220231225160454135.png
# 1     avatar EZ 120231225212544395.png
# 2     avatar EZ 120231225213759361.png
# 3     avatar EZ 120231225213933207.png
# 4     avatar EZ 220231225214812366.png
#
#                                                                  path  \
# 0  https://staging.growbal.net:8081/gateway/cms/media/display_image/1
# 1  https://staging.growbal.net:8081/gateway/cms/media/display_image/2
# 2  https://staging.growbal.net:8081/gateway/cms/media/display_image/3
# 3  https://staging.growbal.net:8081/gateway/cms/media/display_image/4
# 4  https://staging.growbal.net:8081/gateway/cms/media/display_image/5
#
#    document_collection_media_collection_id  media_collection_id  \
# 0                                      NaN                106.0
# 1                                      NaN                  NaN
# 2                                      NaN                  NaN
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
#
#   user_media_user_id media_user_creation_user_id  message_id message_ordre_id  \
# 0               None                        None         NaN             None
# 1               None                        None         NaN             None
# 2               None                        None         NaN             None
# 3               None                        None         NaN             None
# 4               None                        None         NaN             None
#
#   profile_id country_over_view_id  task_id
# 0       None                 None      NaN
# 1       None                 None      NaN
# 2       None                 None      NaN
# 3       None                 None      NaN
# 4       None                 None      NaN

# %%
import pandas as pd
import mysql.connector as mc
import string
import random

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)
# dict_keys(['user', 'provider_type', 'country', 'session_status', 'name', 'logo', 'website', 'linkedin', 'facebook', 'instagram', 'telephone', 'mobile', 'emails', 'office_locations', 'key_individuals', 'services'])

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`media_collection` ORDER BY creation_date DESC;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
# print(df_service["path"][0])
print(len(df_service))
# print(df_service["content_type"].unique())
# df_service = df_service.head(100)
display(df_service.head(5))
# Out:
# 304
#    media_collection_id       creation_date  deleted description label  type  \
# 0                  265 2025-06-13 07:56:36        0        None  None  None
# 1                  266 2025-06-13 07:56:36        0        None  None  None
# 2                  267 2025-06-13 07:56:36        0        None  None  None
# 3                  268 2025-06-13 07:56:36        0        None  None  None
# 4                  269 2025-06-13 07:56:36        0        None  None  None
#
#    user_id  profile_id
# 0    373.0         NaN
# 1    374.0         NaN
# 2    375.0         NaN
# 3    376.0         NaN
# 4    377.0         NaN

# %%
import os
import shutil
from datetime import datetime
import mysql.connector as mc
import mimetypes

HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

def insert_media_collection(user_id, cursor):
    cursor.execute(f"""
        SELECT media_collection_id FROM `{SCHEMA}`.`media_collection`
        WHERE user_id = %s
    """, (user_id,))

    existing_collection = cursor.fetchone()

    if existing_collection:
        return False

    creation_date = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')

    insert_query = f"""
        INSERT INTO `{SCHEMA}`.`media_collection` (
            user_id, creation_date, deleted
        ) VALUES (%s, %s, %s)
    """

    values = (
        user_id,
        creation_date,
        0
    )

    cursor.execute(insert_query, values)
    collection_id = cursor.lastrowid

    return collection_id

def insert_media_record(absolute_logo_path, logos_dest_dir, media_collection_id, content_type, cursor):
    file_name = os.path.basename(absolute_logo_path)

    # Check for existing record
    cursor.execute(f"""
        SELECT id FROM `{SCHEMA}`.`media`
        WHERE label = %s
    """, (file_name,))

    existing_media = cursor.fetchone()

    if existing_media:
        return False

    creation_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]

    insert_query = f"""
        INSERT INTO `{SCHEMA}`.`media` (
            content_type, creation_date, deleted, label, media_collection_id
        ) VALUES (%s, %s, %s, %s, %s)
    """

    values = (
        content_type,
        creation_date,
        0,
        file_name,
        media_collection_id
    )

    cursor.execute(insert_query, values)
    media_id = cursor.lastrowid

    # Prepare new file path using media ID and original extension
    file_extension = os.path.splitext(file_name)[1]
    new_file_name = f"{media_id}{file_extension}"
    new_file_path = os.path.join(logos_dest_dir, new_file_name)

    # Update path in database
    cursor.execute(f"""
        UPDATE `{SCHEMA}`.`media`
        SET path = %s
        WHERE id = %s
    """, (new_file_path, media_id))

    # Copy file to the new destination
    # os.makedirs(logos_dest_dir, exist_ok=True)
    if not os.path.exists(logos_dest_dir):
        print(f"Creating destination directory: {logos_dest_dir}")
        os.makedirs(logos_dest_dir)
        print(f"destination directory: {logos_dest_dir} created")
    shutil.copy2(absolute_logo_path, new_file_path)

    return media_id

absolute_logo_path = "/home/mohammed/Desktop/tech_projects/growbal/growbal_django/media/logos/logo-placeholder.png"
logos_dest_dir = "/home/mohammed/Desktop/tech_projects/growbal/growbal_django/media/logos_test"
user_id = 1

cnx = mc.connect(
    host=HOST, port=PORT, user=USER, password=PASSWORD,
    database=SCHEMA, auth_plugin="mysql_native_password"
)
cur = cnx.cursor()

content_type, _ = mimetypes.guess_type(absolute_logo_path)
collection_id = insert_media_collection(user_id, cur)
if collection_id:
    media_id = insert_media_record(absolute_logo_path, logos_dest_dir, collection_id, content_type, cur)
    if media_id:
        print(f"Successfully inserted media record: {media_id}")
        cnx.commit()
    else:
        print("Failed to insert media record")
        cnx.rollback()
# Out:
# Successfully inserted media record: 2684

# %%
print(collection_id)
# Out:
# 267

# %%
import os
import mimetypes


def print_image_content_types(directory):
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            content_type, _ = mimetypes.guess_type(filepath)
            print(f"{filename}: {content_type}")


# Usage example
download_dir = "/home/mohammed/Desktop/tech_projects/growbal/growbal_django/media/logos"
print_image_content_types(download_dir)
# Out:
# mof-logo.svg_0.svg: image/svg+xml
# logo-placeholder.png: image/png
# arb-logo.png_0.png: image/png
# vz-ascentium-1.svg_0.svg: image/svg+xml
# vz-ascentium-1.svg_1.svg: image/svg+xml
# BSE.png_0.png: image/png
# CIG-LOGO-01-1-1.png_0.png: image/png
# logo-fta.webp_0.img: None

# %%
import pandas as pd
import mysql.connector as mc
import string
import random

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)
# dict_keys(['user', 'provider_type', 'country', 'session_status', 'name', 'logo', 'website', 'linkedin', 'facebook', 'instagram', 'telephone', 'mobile', 'emails', 'office_locations', 'key_individuals', 'services'])

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`user`;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
print(len(df_service))
# df_service = df_service.head(100)
display(df_service.head(5))
# Out:
# 226
#    user_id adress                    birthday           creation_date  \
# 0        1   None  1995-12-29 14:58:56.073000 2023-12-25 15:05:09.628
# 1        2   None                        None 2023-12-25 21:17:40.801
# 2        5   None         0985-12-20 00:00:00 2023-12-26 13:35:10.327
# 3        6   None                        None 2023-12-26 13:53:05.037
# 4        7   None                        None 2023-12-26 14:06:15.235
#
#                        email        full_name  is_deleted  \
# 0    growbal.admin@gmail.com    GROWBAL ADMIN           0
# 1    admin.jafza@growbal.com             None           0
# 2  valentina.otero@ohllp.com  Valentina Otero           0
# 3   customersupport@shams.ae             None           0
# 4            blz@growbal.com             None           0
#
#                                                                                                                nationality  \
# 0  b'\xac\xed\x00\x05sr\x00\x13java.util.ArrayListx\x81\xd2\x1d\x99\xc7a\x9d\x03\x00\x01I\x00\x04sizexp\x00\x00\x00\x01...
# 1                                                                                                                     None
# 2  b'\xac\xed\x00\x05sr\x00\x13java.util.ArrayListx\x81\xd2\x1d\x99\xc7a\x9d\x03\x00\x01I\x00\x04sizexp\x00\x00\x00\x01...
# 3                                                                                                                     None
# 4                                                                                                                     None
#
#                                                        password  \
# 0  $2a$10$N2yN5vanlpviP58OXN3KFeMZqWVI.EsmBrOs9YwCA3XC9CBXNJomC
# 1  $2a$10$cPmfRPFGz/m/QV1c/iVbKOsi6hvEPOvN/8ZWXRZdwCkV6AYBo9a.C
# 2  $2a$10$5RIta34cyNct9vXB.JNDWeSbcCozRX3qcKLVCgz/F3339N41jhAhu
# 3  $2a$10$5WMlwIzIDnoLK0wlJ2bmd.Ke6S99qqWpSTzMVv5XGOZxzjFErN5cS
# 4  $2a$10$vdxA8Oxo7fdm1TkN5JNo1uQ7BQIZSDN4Wkqwi.YlaYorsAnSLRyA2
#
#              phone  role  stars web_site  establishment_id  image_id  \
# 0     +21631572542     1    0.0     None                 1       1.0
# 1   +216 4 4453270     6    0.0     None                 2       NaN
# 2  +21650 189 7506     4    5.0     None                 5      23.0
# 3    +216 80074267     6    0.0     None                 6       NaN
# 4    +973 17589999     6    0.0     None                 7       NaN
#
#    passeport_copy_id provider provider_id  confirm_email
# 0                NaN     None        None              1
# 1                NaN     None        None              1
# 2               24.0     None        None              1
# 3                NaN     None        None              1
# 4                NaN     None        None              1

# %%
import pandas as pd
import mysql.connector as mc
import string
import random

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)
# dict_keys(['user', 'provider_type', 'country', 'session_status', 'name', 'logo', 'website', 'linkedin', 'facebook', 'instagram', 'telephone', 'mobile', 'emails', 'office_locations', 'key_individuals', 'services'])

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`type_ez`;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
# print(df_service["path"][119])
print(len(df_service))
# df_service = df_service.head(100)
display(df_service.tail(5))
# Out:
# 3
#    id  deleted           type
# 0   1        0  Economic Zone
# 1   2        0      Free Zone
# 2   3        0  Logistic Zone

# %%
import pandas as pd
import mysql.connector as mc

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── QUERY DATA FROM 'service' TABLE ──────────────────────────
cur.execute(f"SELECT * FROM `{SCHEMA}`.`establishment_services`;")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_service = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ──────────────────────────────────────────────
pd.set_option("display.max_columns", None)
# ── DISPLAY OPTIONS ────────────────────────────────────────────────
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
print(len(df_service))
# df_service = df_service.head(100)
display(df_service.tail(50))

# %%
import pandas as pd
import mysql.connector as mc

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── QUERY DATA FROM 'user' TABLE ORDERED BY creation_date ──
cur.execute(f"""
    SELECT * FROM `{SCHEMA}`.`user`
    ORDER BY creation_date DESC;
""")
data = cur.fetchall()

# ── DISPLAY DATA AS DATAFRAME ──────────────────────────────────────
df_user = pd.DataFrame(data)

# ── DISPLAY ALL COLUMNS ────────────────────────────────────────────
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)

print(f"Total rows: {len(df_user)}")
df_user = df_user.head(10)
display(df_user.tail(5))
# display(df_user)

# ── CLOSE CONNECTION ────────────────────────────────────────────────
cur.close()
cnx.close()
# Out:
# Total rows: 226
#    user_id                                     adress birthday  \
# 5      375  Ministry of Finance, United Arab Emirates     None
# 6      374                      UAE Embassy in London     None
# 7      373                       United Arab Emirates     None
# 8      372                                       None     None
# 9      371                                       None     None
#
#             creation_date                    email  \
# 5 2025-06-04 07:18:37.449          info@mof.gov.ae
# 6 2025-06-04 07:18:37.447                     None
# 7 2025-06-04 07:18:37.445                     None
# 8 2025-01-27 13:47:31.172  42dcf56819@emailawb.pro
# 9 2025-01-27 13:44:07.627  789abe94bf@emailawb.pro
#
#                                     full_name  is_deleted nationality  \
# 5  Ministry of Finance - United Arab Emirates           0        None
# 6                       UAE Embassy in London           0        None
# 7                     Ministry of Economy UAE           0        None
# 8                                        None           0        None
# 9                                        None           0        None
#
#                                                        password         phone  \
# 5                                                          None     047771000
# 6                                                          None  +97180044444
# 7                                                          None      800 1222
# 8  $2a$10$UmX/hIeTkMUyNt/172kY5OqLazDhKdbbpOfL8/ILaaQr8/9cSPMC.  +21620025557
# 9  $2a$10$notBqxDfHp.cT31nmtfMue06rcgtLw7/N1OmyYL.NNtqNnnvk0/ki  +21620036366
#
#    role  stars                                    web_site  establishment_id  \
# 5     4    0.0                          https://mof.gov.ae               392
# 6     4    0.0  https://www.mofa.gov.ae/en/Missions/London               391
# 7     4    0.0                     https://www.moec.gov.ae               390
# 8     6    3.0                                        None               389
# 9     6    3.0                                        None               388
#
#    image_id  passeport_copy_id provider provider_id  confirm_email
# 5       NaN                NaN     None        None              1
# 6       NaN                NaN     None        None              1
# 7       NaN                NaN     None        None              1
# 8       NaN                NaN     None        None              1
# 9       NaN                NaN     None        None              1

# %%
from fuzzywuzzy import fuzz, process

# Example structure of your existing data:
# df_service contains column "company_name"
service_names = df_service["name"].tolist()

# Function to filter similar matches
def get_potential_matches(name, service_names, threshold=70):
    matches = process.extract(name, service_names, scorer=fuzz.token_set_ratio)
    return [match for match, score in matches if score >= threshold]

# Iterate over profiles to build potential matches
profile_potential_matches = {}
for service in services:
    service_name = service["service_title"]
    similar_names = get_potential_matches(service_name, service_names, threshold=70)
    profile_potential_matches[service_name] = similar_names

for service, similar_names in profile_potential_matches.items():
    print(f"{service}: {similar_names}")
# Out:
# Management Consulting & Professional Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Tax Preparation and Financial Services: ['Port Services', 'Legal Services']
# Tax Preparation and Accounting Services: ['Port Services', 'Legal Services']
# Professional Tax Services: ['Port Services', 'Legal Services']
# Global Management Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Management Consulting & Digital Transformation Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Professional Tax and Accounting Services: ['Port Services', 'Legal Services']
# Strategy and Management Consulting for Financial Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Real Estate Tax and Accounting Services: ['Real Estate', 'Real Estate', 'Real Estate Services', 'Real estate ', 'Real Estate ']
# Professional Services & Business Advisory: ['Port Services', 'Legal Services']
# Global Professional Services - Audit, Tax, Advisory & Business Services: ['Port Services', 'Legal Services']
# Accounting and Business Advisory Services: ['Port Services', 'Legal Services']
# IT Services and Digital Solutions: ['Port Services', 'Legal Services', 'IT and Telecommunication Services']
# Risk and Human Capital Advisory Services: ['Port Services', 'Legal Services']
# Managed IT Services & Solutions: ['Port Services', 'Legal Services', 'IT and Telecommunication Services']
# Professional Business Solutions & Government Procurement Services: ['Government', 'Government ', 'Government  ', 'Port Services', 'Legal Services']
# Financial Services and Insurance Solutions: ['Port Services', 'Legal Services']
# Tax and Accounting Services: ['Port Services', 'Legal Services', 'Consulting Services']
# Professional Accounting, Tax and Business Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Tax Professional Accreditation and Development Services: ['Port Services', 'Legal Services', 'Research & Development', 'Research & Development', 'Research & Development ']
# Tax Professional Services and Education: ['Education', 'Education', 'Education ', 'Education  ', 'Education ']
# Tax Preparation and Resolution Services: ['Port Services', 'Legal Services']
# Tax, Accounting and Business Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Tax, Accounting and Business Advisory Services: ['Port Services', 'Legal Services']
# Professional Advisory Services: ['Port Services', 'Legal Services']
# Digital Transformation and IT Services: ['Logistics and Transportation Services', 'Port Services', 'Legal Services', 'IT and Telecommunication Services']
# Professional Information and Software Solutions: []
# Digital Transformation Solutions: []
# Enterprise Software Support and Services: ['Marketing Support Services', 'Port Services', 'Legal Services']
# Tax Advisory Services: ['Port Services', 'Airport Services', 'Legal Services', 'Air Cargo Services']
# Corporate Tax Services: ['Port Services', 'Airport Services', 'Legal Services']
# Tax Accounting and Business Advisory Services: ['Port Services', 'Legal Services']
# Professional Tax & Accounting Services: ['Port Services', 'Legal Services']
# Auditing, Accounting & Tax Services: ['Port Services', 'Legal Services']
# Legal, Accounting & Tax Advisory Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Tax Filing API and Software Solutions: []
# Form 990 E-Filing Service: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Ethiopian Diaspora Hub - Comprehensive Diaspora Services Platform: ['Port Services', 'Legal Services']
# Enterprise TruRisk Platform - Cloud Security Solutions: ['Safety & Security', 'Safety & Security ', 'Safety & Security ', 'Safety & Security  ']
# Technology Solutions and Services: ['Technology', 'Technology', 'Port Services', 'Legal Services']
# Global Payment Solutions & Financial Technology Services: ['Technology', 'Technology', 'Port Services', 'Legal Services']
# Third-Party Logistics (3PL) and Supply Chain Solutions: []
# Full-Service Digital Marketing & Performance Agency: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Business Advisory and Accounting Services: ['Port Services', 'Legal Services']
# Global Financial Advisory and Asset Management Services: ['Port Services', 'Legal Services']
# U.S. Department of Commerce Services: ['Port Services', 'Legal Services']
# Public Sector Procurement Services: ['Port Services', 'Legal Services']
# Government Services - Ministry of Industry and Commerce: ['Government', 'Government ', 'Government  ', 'Port Services', 'Legal Services']
# RAK Chamber Services: ['Port Services', 'Legal Services', 'Real Estate Services']
# Tax Advisory and Compliance Services: ['Port Services', 'Legal Services']
# Corporate Tax Advisory Services: ['Port Services', 'Legal Services']
# 24/7 Global Technology Support Services: ['Technology', 'Technology', 'Marketing Support Services', 'Port Services', 'Legal Services']
# Abu Dhabi Government Services: ['Government', 'Government ', 'Government  ', 'Port Services', 'Legal Services']
# UAE Government Scientific Research Services: ['Government', 'Government ', 'Government  ', 'Port Services', 'Legal Services']
# Ministry of Interior Services: ['Port Services', 'Legal Services']
# Electricity and Water Utility Services: ['Port Services', 'Legal Services']
# Dubai Police Services: ['Port Services', 'Legal Services', 'Airport Services']
# Unemployment Insurance Scheme: []
# Renewal of Establishment Card - All Categories: []
# Dubai Roads and Transport Authority (RTA) Services: ['Port Services', 'Legal Services']
# Roofing Business Consulting & Training Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Business Setup and Company Formation Services in UAE: ['Port Services', 'Legal Services', 'New Company Setup and Licensing']
# Expert Tax, Family Office & Wealth Solutions: []
# Accounting, Auditing and Business Consulting Services in Dubai: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# HR Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Business Setup and Consulting Services in UAE: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Business Setup Services in Dubai: ['Port Services', 'Legal Services']
# IT Solutions and Technical Services: ['Port Services', 'Legal Services']
# Office Interior Design Services: ['Port Services', 'Legal Services']
# Global Business Registration and Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Structured Cabling Installation and Design Services: ['Port Services', 'Legal Services']
# Handyman Home Assembly Services: ['Port Services', 'Legal Services']
# Home Automation Installation Services: ['Port Services', 'Legal Services']
# AC Installation Services Dubai: ['Port Services', 'Legal Services']
# Sharjah Chamber of Commerce and Industry Services: ['Port Services', 'Legal Services']
# Bespoke Office Design, Fit-Out and Refurbishment Services: ['Port Services', 'Legal Services']
# UAE Ministry of Foreign Affairs Services: ['Port Services', 'Legal Services']
# Architecture and Design Services: ['Port Services', 'Legal Services']
# Global Asset Servicing Solutions: []
# Enterprise Cloud Hospitality Platform Solutions: ['Hospitality', 'Hospitality ']
# Government Services - Ministry of Economy UAE: ['Government', 'Government ', 'Government  ', 'Port Services', 'Legal Services']
# Federal Tax Services: ['General Law Services', 'General Legal Services', 'Port Services', 'Legal Services', 'Real Estate Services']
# Professional Moving and Packing Services in Dubai: ['Port Services', 'Legal Services']
# Professional Starlink Installation Services: ['Port Services', 'Legal Services']
# Loft Boarding and Storage Solutions: []
# Global Legal Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Digital Marketing and Web Development Services: ['Marketing Support Services', 'Port Services', 'Marketing & Sales', 'Marketing & Sales ', 'Legal Services']
# Lifting the ban on a file for individuals: []
# Dubai Department of Economy and Tourism (DET) Services: ['Travel and Tourism', 'Port Services', 'Legal Services']
# Dubai Parks and Resorts - Theme Park Destination: []
# Dubai Municipality Services: ['Port Services', 'Legal Services']
# Dubai Chambers Services: ['Port Services', 'Legal Services']
# British Chamber of Commerce Dubai Membership Services: ['Port Services', 'Legal Services']
# Investment and Wealth Management Services: ['Port Services', 'Legal Services']
# Investment Management Services: ['Port Services', 'Legal Services']
# US Expat Tax Preparation Services: ['Port Services', 'Legal Services']
# Tax Preparation & Planning Services: ['Port Services', 'Legal Services']
# Tax and Immigration Services: ['Port Services', 'Legal Services', 'IT and Telecommunication Services']
# Tax and Business Accounting Services: ['Port Services', 'Legal Services']
# Chartered Accountancy and Business Advisory Services: ['Port Services', 'Legal Services']
# Comprehensive Accounting & Tax Services: ['Port Services', 'Legal Services']
# Personal Tax Return Services: ['Port Services', 'Legal Services']
# Tax, Audit & Business Advisory Services: ['Port Services', 'Legal Services']
# Goals-Based Investment Management Services: ['Port Services', 'Legal Services']
# Legal and Tax Advisory Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Executive Search & Leadership Consulting: ['Consulting', 'Consulting', 'Consulting ']
# Public Health Strategic Planning and Management Services: ['Port Services', 'Legal Services']
# Global Management Consulting & Impact Investment: ['Consulting', 'Consulting', 'Consulting ']
# Management Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Professional Recruitment Services: ['Port Services', 'Legal Services']
# Social Impact Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Interim Management Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Environmental Consulting & Management Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Sustainable and Ethical Investment Management: []
# Asset Management Services: ['Port Services', 'Legal Services']
# Fixed Income Investment Management Services: ['Port Services', 'Legal Services']
# Comprehensive Wealth Management Services: ['Port Services', 'Legal Services']
# Wealth Management Services: ['Port Services', 'Legal Services']
# Investment Management and Family Advisory Services: ['Port Services', 'Legal Services']
# Financial Advisory & Private Wealth Management Services: ['Port Services', 'Legal Services']
# Global Immigration Legal Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# International Law Services: ['General Law Services', 'Port Services', 'Legal Services', 'General Legal Services']
# Financial Services Legal Support: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Legal Services: ['Legal', 'Legal', 'Legal Services', 'General Legal Services', 'Legal ']
# Full-Service Law Firm: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Sustainability Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Private Wealth Management Services: ['Port Services', 'Legal Services']
# Islamic Investment and Asset Management Services: ['Port Services', 'Legal Services']
# Quality Growth Investment Management: []
# Investment Banking Services: ['Port Services', 'Legal Services']
# Investment Banking and Financial Services: ['Port Services', 'Legal Services', 'Finance and banking']
# Global Investment Banking and Capital Markets Services: ['Port Services', 'Legal Services', 'Finance and banking']
# Technology Investment Banking Services: ['Technology', 'Technology', 'Port Services', 'Legal Services']
# Investment and Capital Management Services: ['Port Services', 'Legal Services']
# Enterprise Technology and Investment Solutions: ['Technology', 'Technology']
# Financial Technology and Wealth Management Solutions: ['Technology', 'Technology']
# Global Professional Services and Risk Management Solutions: ['Port Services', 'Legal Services']
# Accountancy and Advisory Services: ['Port Services', 'Legal Services']
# Professional Accounting Services: ['Port Services', 'Legal Services']
# Accountancy and Tax Services: ['Port Services', 'Legal Services']
# Legal Services & Strategic Counsel: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Executive Compensation Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Human Rights Services in the UAE: ['Port Services', 'Legal Services']
# Dubai Business Directory and News Platform: []
# Arabian Business News and Media Services: ['Media', 'Port Services', 'Legal Services']
# Business District Development and Management: ['Research & Development', 'Research & Development', 'Research & Development ', 'Research & Development ']
# Retail & Services Marketplace: ['Retail', 'Retail ', 'Real Estate Services', 'Port Services', 'Legal Services']
# Middle East Business Directory Services: ['Port Services', 'Legal Services', 'Last-Mile Delivery Services']
# Business Directory and Local Listing Service: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Document Verification Service: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Immigration and Residency Services: ['Port Services', 'Legal Services']
# Tax Preparation Services: ['Port Services', 'Legal Services']
# Tax Preparation and IRS Problem Resolution Services: ['Port Services', 'Legal Services']
# Insurance and Financial Services: ['Port Services', 'Legal Services']
# Immigration and Estate Planning Legal Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# UK and South Africa Immigration Services: ['Port Services', 'Legal Services']
# U.S. Immigration Legal Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Canadian Immigration Legal Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Australian Migration Services: ['Port Services', 'Legal Services']
# International Moving and Shipping Services: ['Port Services', 'Legal Services']
# International Express and Logistics Services: ['Logistics and Transportation Services', 'Port Services', 'Legal Services']
# Web Hosting Services: ['Consulting Services', 'Port Services', 'Legal Services']
# Global Workforce and Project Solutions: []
# Managed Services: ['Port Services', 'Legal Services', 'Air Cargo Services']
# Global Corporate Mobility Services: ['Port Services', 'Legal Services']
# Immigration Services: ['Port Services', 'Legal Services', 'Administrative Services']
# Moving, Immigration, Relocation and Fine Arts Transportation Services: ['Relocation', 'Relocation ', 'Relocation  ', 'Logistics and Transportation Services', 'Port Services']
# Testing, Inspection, Certification and Engineering Solutions: []
# Managed IT Services and Digital Infrastructure Solutions: ['Port Services', 'Legal Services']
# Abu Dhabi Government Procurement Gate: ['Government', 'Government ', 'Government  ']
# Vintage and Retro Clothing Store: []
# Tax, Accounting & Business Advisory Services: ['Port Services', 'Legal Services']
# Small Business Accounting and Tax Services: ['Port Services', 'Legal Services']
# Treasury Circular 230 for EAs and Other Tax Preparers: []
# Planned Giving Software and Services: ['Port Services', 'Legal Services']
# Microsoft Dynamics 365 Business Solutions: []
# Math Education and Test Preparation Services: ['Education', 'Education', 'Education ', 'Education  ', 'Education ']
# Math and Science Digital Solutions: []
# Lifeline Queensland Online Thrift Store: []
# Sacred Heart Mission Online Op Shop: []
# Third-Party Risk Management and Cybersecurity Risk Management Solutions: []
# Kiwanis Marketplace Thrift Store: []
# Structural Analysis and Design Software: []
# Manufacturing Intelligence Solutions: []
# ERACS - Power System Analysis Software: []
# Electronic Calculator Manufacturing and Supply: []
# Digital Industries Software Solutions: []
# Electronic Design Automation Solutions: []
# IoT and Industrial Computing Solutions: []
# Custom Software Development & IT Consulting: ['Consulting', 'Consulting', 'Consulting ', 'Research & Development', 'Research & Development']
# Quantum Computing Solutions and Services: ['Port Services', 'Legal Services']
# Numerical Simulation and Software Development Services: ['Port Services', 'Legal Services', 'Research & Development', 'Research & Development', 'Research & Development ']
# Used Books Retail and Trading: ['Retail', 'Retail ']
# Vintage Clothing Retail and E-commerce: ['Retail', 'Retail ']
# New Life Furniture Thrift Store: []
# Second Hand Furniture Services: ['Port Services', 'Legal Services']
# Used and New Office Furniture Sales: []
# High-End Furniture Consignment Store: []
# Luxury Designer Resale Services: ['Port Services', 'Legal Services']
# LEGO® Resale Store: []
# The Salvation Army Online Auction and Marketplace: []
# Consignment Services: ['Consulting Services', 'Port Services', 'Legal Services']
# Vintage Clothing and Decor Retail Store: ['Retail', 'Retail ']
# Thrift & Consignment Store: []
# Luxury Fashion Consignment Boutique: []
# COMSOL Multiphysics® Simulation Software: []
# Global IT Services and Consulting: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Digital Transformation and IT Consulting Services: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Enterprise Marketplace and Dropship Platform Solutions: []
# Data-Driven Marketing and Analytics Solutions: ['Marketing & Sales', 'Marketing & Sales ']
# Salesforce CRM Platform: []
# Managed IT Services: ['Port Services', 'Legal Services', 'IT and Telecommunication Services', 'Air Cargo Services']
# Enterprise Broadband Solutions and Services: ['Port Services', 'Legal Services']
# Managed IT Services and Cloud Consulting: ['Consulting', 'Consulting', 'Consulting Services', 'Consulting ', 'Customs Consulting & Services']
# Managed IT Services & Support: ['Marketing Support Services', 'Port Services', 'Legal Services']
# Foreign, Commonwealth & Development Office (FCDO) Services: ['Port Services', 'Legal Services', 'Research & Development', 'Research & Development', 'Research & Development ']
# Used Car Sales and Services: ['Port Services', 'Legal Services']
# Musical Instruments and Equipment Retailer: []
# Luxury Used Car Sales and Trading: []
# Used Car Sales and Dealership: []
# Second Hand Retail and Pawnbroking Services: ['Retail', 'Retail ', 'Port Services', 'Legal Services']
# TikTok Followers Service: ['service ', 'service ', 'service 1', 'service 11', 'service 12']
# Online Classified Advertising Platform: []
# Sustainable Baby Gear Marketplace: []
# U.S. Passport Services: ['Port Services', 'Airport Services', 'Legal Services']
# Department of Foreign Affairs (DFA) Services: ['Port Services', 'Legal Services']
# Passport Services: ['Port Services', 'Airport Services', 'Legal Services', 'Property Leasing Services', 'Security Services']
# Lebanese General Security Services: ['Security Services', 'General Law Services', 'General Legal Services', 'Port Services', 'Legal Services']
# Philippine Passport and Consular Services: ['Port Services', 'Legal Services']
# U.S. Department of State Services: ['Port Services', 'Legal Services']
# Accounting and Finance Outsourcing Services: ['Finance', 'Finance', 'Port Services', 'Legal Services', 'Finance and banking']
# Safety & Security Technology Solutions: ['Safety & Security', 'Safety & Security ', 'Safety & Security ', 'Safety & Security  ', 'Technology']
# Water Solutions and Services: ['Port Services', 'Legal Services']
# IT Services & Digital Solutions: ['Port Services', 'Legal Services']
# Company Registration Services: ['Port Services', 'Legal Services']
# Corporate Sector and Financial Market Regulation Services: ['Port Services', 'Legal Services']
# Business Registration Services: ['Port Services', 'Legal Services']
# New Business Formation Services: ['Port Services', 'Legal Services']
# Legal Support & Company Formation Services: ['Legal', 'Legal', 'Legal Services', 'Legal ', 'Legal ']
# Business Setup and Corporate Services in UAE: ['Port Services', 'Legal Services']
# Corporate Services & Business Solutions: ['Port Services', 'Legal Services']
# Asset Servicing and Custody Solutions: []
# Professional Engineering and Advisory Services: ['Port Services', 'Legal Services']
# Digital Transformation Services: ['Logistics and Transportation Services', 'Port Services', 'Legal Services']
# Digital Marketing and PR Services: ['Marketing Support Services', 'Port Services', 'Marketing & Sales', 'Marketing & Sales ', 'Legal Services']
# Comprehensive IT Services & Solutions: ['Port Services', 'Legal Services']

# %%
from fuzzywuzzy import fuzz, process

service_descriptions = df_service["description"].tolist()

# Function to filter similar matches
def get_potential_matches(name, service_descriptions, threshold=70):
    matches = process.extract(name, service_descriptions, scorer=fuzz.token_set_ratio)
    return [match for match, score in matches if score >= threshold]

# Iterate over profiles to build potential matches
profile_potential_matches = {}
for service in services:
    service_description = service["service_description"]
    similar_descriptions = get_potential_matches(service_description, service_descriptions, threshold=60)
    profile_potential_matches[service_description] = similar_descriptions

# for service_description, similar_descriptions in profile_potential_matches.items():
#     if similar_descriptions:
#         print(f"{service_description}: {similar_descriptions}")

for service_description in service_descriptions:
    if service_description:
        if "tax" in service_description or "Tax" in service_description or "TAX" in service_description:
            print(service_description)
        if "IT" in service_description:
            print(service_description)
        if "legal" in service_description or "Legal" in service_description or "LEGAL" in service_description:
            print(service_description)
# Out:
# Legal
# Legal
# Legal services encompass a diverse array of offerings provided by qualified legal professionals, including attorneys, lawyers, paralegals, and legal consultants.
# Legal services encompass a wide range of offerings designed to address the legal needs and concerns of individuals, businesses, and organizations.
# Legal services encompass a wide range of offerings designed to address the legal needs and concerns of individuals, businesses, and organizations.
# Legal services encompass a wide range of offerings designed to address the legal needs and concerns of individuals, businesses, and organizations.
# A range of legal tasks, such as drafting legal documents and providing legal advice on various matters.
# A range of legal tasks, such as drafting legal documents and providing legal advice on various matters.
# Handle administrative tasks related to payroll, taxes, and immigration.
# Enable citizens or permanent residents of a country to sponsor eligible family members for immigration, initiating the legal process to bring them to reside in the same country.

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
description_list = []
for text in service_descriptions:
    if text:
        description_list.append(text)

token_counts = [len(encoding.encode(text)) for text in description_list]
average_tokens = sum(token_counts) / len(token_counts)

print(f"Average number of tokens: {average_tokens:.2f}")
# Out:
# Average number of tokens: 13.43

# %%
from fuzzywuzzy import fuzz, process

# Example structure of your existing data:
# df_establishment contains column "company_name"
establishment_names = df_establishment["company_name"].tolist()

# Function to filter similar matches
def get_potential_matches(name, establishment_names, threshold=70):
    matches = process.extract(name, establishment_names, scorer=fuzz.token_set_ratio)
    return [match for match, score in matches if score >= threshold]

# Iterate over profiles to build potential matches
profile_potential_matches = {}
for profile in service_provider_profiles:
    company_name = profile["name"]
    similar_names = get_potential_matches(company_name, establishment_names, threshold=70)
    profile_potential_matches[company_name] = similar_names

for profile, similar_names in profile_potential_matches.items():
    print(f"{profile}: {similar_names}")
# Out:
# Alvarez & Marsal: []
# Ravi Tax Preparation Services Inc: []
# Tax Comp: []
# TAXtical LLC: []
# NMS Consulting: []
# Cambridge Management Consulting: []
# FBC & TAX SERVICES: []
# zeb: []
# GavTax Advisory Services: []
# RSM US LLP: []
# BDO Global: []
# KLR: []
# Tata Consultancy Services Limited: []
# Gulf Coast Accounting & Tax Services: []
# MNP LLP: []
# McKinsey & Company: []
# Aon: []
# Singapore Chartered Tax Professionals Limited: []
# Oregon Association of Tax Consultants: []
# Paradigm Business Solutions LLC: []
# Cash Tracks Financial: []
# Duke A. Forbes CPA, A Professional Corporation: []
# EthioDiasporaHub: []
# Aegon: []
# Blick Rothenberg: []
# Grant Thornton Ireland: []
# Atos: []
# Wolters Kluwer: []
# Intalio: []
# Rimini Street: []
# The Leppert CPA Group: []
# Qualys: []
# WWT (World Wide Technology): []
# Nuvei: []
# Abdiwali Mohamed CPA PLLC: []
# Barrett Distribution Centers: []
# Tinuiti: []
# Aprio: []
# Jitendra Chartered Accountants: []
# Mahanakorn Partners Group: []
# Lazard: []
# Column Tax: []
# U.S. Department of Commerce: []
# Tax990: []
# SPC CPAs & Associates, LLC: []
# Crown Commercial Service: []
# Ministry of Industry and Commerce: []
# Cotney Consulting Group: []
# Khattab: []
# Mosaic Chambers Group: []
# ECOVIS Fuller International: []
# S&K HR Consulting: []
# RTS Business Consulting DMCC: []
# NexaBiz: []
# Abiding Technical Services LLC: []
# Atlas Interiors: []
# Finevolution: []
# Live Innovative Solutions: []
# FixTman: []
# Home Cinemas: []
# Glinda Company Inc.: []
# San Diego Tax Professionals: []
# BDO LLP: ['OH LLP']
# Grant Thornton UK Advisory & Tax LLP: []
# Xplor Solutions: []
# Abu Dhabi Government: []
# UAE Government: []
# Ministry of Interior UAE: []
# Dubai Electricity and Water Authority (DEWA): []
# Dubai Police: []
# Ministry of Human Resources and Emiratisation: []
# General Directorate of Residency and Foreigners Affairs Dubai (GDRFA Dubai): []
# Roads and Transport Authority (RTA): []
# Naseem AC Services LLC: []
# Sharjah Chamber of Commerce and Industry: []
# Contact One: []
# Ministry of Foreign Affairs - UAE: []
# Gensler: []
# MUFG Investor Services: []
# IDS Next: []
# Ministry of Economy UAE: []
# Federal Tax Authority: []
# RAK Chamber: ['Subic Bay Freeport Chamber of Commerce']
# TFX (Taxes for Expats): []
# The Romeo Group: []
# Servicios Coronel: []
# Clear Tax: []
# Price Bailey LLP: []
# O'Connor and Agar, LLC: []
# WilkinGuttenplan: []
# SMR CPA: []
# Boyum & Barenscheer, PLLP: []
# Meaux Tax and Consulting: []
# Robert Fuller CPA DBA Tax One: []
# Loyens & Loeff: []
# Pedersen & Partners: []
# BME Strategies: []
# Palladium: []
# Boston Consulting Group (BCG): []
# ROC Consulting Group: []
# The Social Investment Consultancy (TSIC): []
# Desert Movers Dubai: []
# Starlink Installation Pros: []
# Instaloft Ltd: []
# Clyde & Co LLP: []
# Kinrock: []
# Dubai Department of Economy and Tourism (DET): []
# Dubai Parks and Resorts: []
# Dubai Municipality: []
# Dubai Chambers: []
# British Chamber of Commerce Dubai: ['Subic Bay Freeport Chamber of Commerce']
# Pictet Group: []
# Impax Asset Management: []
# Horizon Investments: []
# Franklin Templeton: []
# Pendal Group: []
# Gabelli: []
# Greenbank Investments: []
# Clime Investment Management: []
# Pareto Asset Management: []
# Rubrics Asset Management: []
# Wealthspire Advisors: []
# UBS Wealth Management USA: []
# ICONIQ Capital: []
# Roland Berger GmbH: []
# Morgan Lewis: []
# Gibson Dunn: []
# Kirkland & Ellis LLP: []
# Fragomen, Del Rey, Bernsen & Loewy, LLP: []
# Curtis, Mallet-Prevost, Colt & Mosle LLP: []
# GYC Financial Advisory & Private Wealth: []
# Fieldfisher: []
# CMS Poland: []
# Robert W. Baird & Co.: []
# Fasken: []
# Nelson Mullins Riley & Scarborough LLP: []
# Bessemer Trust: []
# TheRockGroup: []
# Roux Inc: []
# WTW: []
# Buzzacott LLP: []
# Carter & Co Accountants: []
# Al Meezan Investments: []
# LDP Luckmans: []
# Vontobel: []
# Nordea: []
# Quantinuum: []
# Accounts Unlocked Ltd: []
# Weil, Gotshal & Manges LLP: []
# Jenner & Block LLP: []
# Weightmans: []
# Charles Russell Speechlys: []
# Compensation Advisory Partners: []
# Day of Dubai: []
# Arabian Business: []
# TECOM Group: []
# dubizzle: []
# Middle East Business Directory: []
# GetListedUAE: []
# GDRFA Dubai: []
# Tax Avenue Services Inc.: []
# New Beginnings One Stop Tax Help: []
# Ledgers and Legends, CPA: []
# Mauro M. D'Amico, Inc: []
# Ara D. Kassabian CPA: []
# Cherokee CPA Services: []
# Virginia Society of Certified Public Accountants (VSCPA): []
# PG Calc: []
# KUMAVISION AG: []
# Kenanga Investment Bank Berhad: []
# RBC Capital Markets: ['Capital Markets']
# Ascento Capital: ['Capital Markets']
# Westbridge Capital: []
# SEI: []
# InvestCloud: []
# Allianz: []
# Fickey Martinez Law Firm, P.L.L.C.: []
# Breytenbachs Immigration Consultants: []
# Murthy Law Firm: []
# Canadim Immigration Law Firm: []
# ONEderland Consulting: []
# East Coast Shipping Inc.: []
# SF International: ['Sharjah Airport International Free Zone', 'Dubai International Financial Centre', 'Bahrain International Investment Park', 'Djibouti International Free Trade Zone', 'Two Rivers International Finance & Innovation Centre']
# Farley and Associates: []
# Brunel International: ['Sharjah Airport International Free Zone', 'Dubai International Financial Centre', 'Bahrain International Investment Park', 'Djibouti International Free Trade Zone', 'Two Rivers International Finance & Innovation Centre']
# K2 Corporate Mobility: []
# Insight Immigration: []
# Softengi: []
# Urban Exchange: []
# inuTech GmbH: []
# SIT Spain: []
# RINA S.p.A.: []
# Internet For Business (IFB): []
# Abu Dhabi Government Procurement Gate: []
# Effortless Math Education Inc.: []
# Fashion Rerun: []
# Wiris: []
# Sacred Heart Mission Online Op Shop: []
# ProcessUnity: []
# Dlubal Software GmbH: []
# Kiwanis Marketplace: []
# BookHero: []
# Hexagon Manufacturing Intelligence: []
# Thrifted.com: []
# Shantou Eates Electronic Industrial Co., Ltd.: []
# Siemens Digital Industries Software: []
# New Life Furniture Thrift Store: []
# Cadence Design Systems, Inc.: []
# Creative Bargains: []
# Office Furniture Liquidations: []
# Lost & Found Resale Interiors: []
# Advantech Co., Ltd.: []
# Bricks & Minifigs Richmond Westend: []
# The Salvation Army: []
# Conshy Consignment: []
# October House Vintage: []
# Overkill Thrift & Consign: []
# Fashion House Amman: []
# Mahindra First Choice Wheels: []
# Rich Tone Music: []
# Bayside Brothers Motors: []
# Car World Used: []
# WANTS: []
# Mercari: []
# Dave Kumar: []
# Junk Mail Publishing (PTY) LTD: []
# GoodBuy Gear: []
# Lifeline Queensland: []
# U.S. Department of State Bureau of Consular Affairs: []
# Department of Foreign Affairs (DFA): []
# Passport Seva, Ministry of External Affairs: []
# General Security Directorate: []
# COMSOL, Inc.: []
# NTT DATA UK&I: []
# Royal Cyber Inc: []
# Mirakl: []
# Acxiom: []
# Salesforce: []
# Ultima Business Solutions Limited: []
# FUJIFILM Business Innovation Australia: []
# Calix: []
# Adex International: ['Sharjah Airport International Free Zone', 'Dubai International Financial Centre', 'Bahrain International Investment Park', 'Djibouti International Free Trade Zone', 'Two Rivers International Finance & Innovation Centre']
# ITGurus: []
# Wateen Telecom: []
# befree: []
# Motorola Solutions: []
# Xylem: []
# Softtek: []
# Vanuatu Financial Services Commission: []
# Securities and Exchange Commission of Pakistan: []
# Ministry of Commerce Business Registration Department: []
# Mazzucco & Company CPAs: []
# Accura Indonesia: []
# U.S. Department of State: []
# Foreign, Commonwealth & Development Office: []
# WSP: []
# FTI Consulting: []
# Finmaas: []
# TechWaves: []
# iConsult Dubai: []
# ARO: []
# CACEIS: []

# %%
import mysql.connector as mc
from datetime import datetime
from mysql.connector.errors import IntegrityError

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)
# dict_keys(['user', 'provider_type', 'country', 'session_status', 'name', 'logo', 'website', 'linkedin', 'facebook', 'instagram', 'telephone', 'mobile', 'emails', 'office_locations', 'key_individuals', 'services'])

def truncate_string(value, max_length):
    if value is None:
        return None
    return value[:max_length]
# ── INSERT FUNCTION ────────────────────────────────────────────────
def insert_establishment(profile_dict, cursor):
    insert_query = f"""
    INSERT INTO `{SCHEMA}`.`establishment` (
        mobile, email, web_site, phone, description, creation_date, company_name, adress, blocked, deleted, verified
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """

    # Prepare values
    values = (
        profile_dict.get('mobile') if profile_dict.get('mobile') else None,
        profile_dict.get('emails')[0] if profile_dict.get('emails') else None,
        profile_dict.get('website') if profile_dict.get('website') else None,
        profile_dict.get('telephone') if profile_dict.get('telephone') else None,
        profile_dict["services"][0].get('service_description') if profile_dict.get('services') else None,
        datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3],
        profile_dict.get('name') if profile_dict.get('name') else None,
        # profile_dict.get('office_locations') if profile_dict.get('office_locations') else None,
        truncate_string(profile_dict.get('office_locations'), 255) if profile_dict.get('office_locations') else None,
        False,
        False,
        False
    )
    for value in values:
        print(type(value))
    print(values)

    # Execute query
    cursor.execute(insert_query, values)
    establishment_id = cursor.lastrowid
    return establishment_id

# ── INSERT FUNCTION FOR SERVICE TABLE ──────────────────────────────
def insert_service(service_dict, cursor):
    insert_query = f"""
    INSERT INTO `{SCHEMA}`.`service` (
        name, description, deleted
    )
    VALUES (%s, %s, %s)
    """

    # Prepare values
    values = (
        service_dict.get('service_title'),
        service_dict.get('general_service_description'),
        False
    )

    print(f"Inserting: {values}")

    # Execute query
    cursor.execute(insert_query, values)
    service_id = cursor.lastrowid
    return service_id

# ── INSERT FUNCTION FOR ESTABLISHMENT_SERVICE TABLE ──────────────────────────────
def insert_establishment_service(establishment_id, service_id, cursor):
    insert_query = f"""
    INSERT INTO `{SCHEMA}`.`establishment_services` (
        establishment_id, service_id, deleted
    )
    VALUES (%s, %s, %s)
    """

    # Prepare values
    values = (
        establishment_id,
        service_id,
        False
    )

    print(f"Inserting establishment_service record: {values}")

    # Execute query
    cursor.execute(insert_query, values)
    record_id = cursor.lastrowid
    return record_id

# ── INSERT FUNCTION FOR user TABLE ──────────────────────────────
def insert_user(profile_dict, establishment_id, cursor):
    insert_query = f"""
    INSERT INTO `{SCHEMA}`.`user` (
        adress, creation_date, email, full_name, phone, web_site, establishment_id, is_deleted, stars, confirm_email
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """

    # Prepare values
    values = (
        truncate_string(profile_dict.get('office_locations'), 255) if profile_dict.get('office_locations') else None,
        datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3],
        profile_dict.get('emails')[0] if profile_dict.get('emails') else None,
        profile_dict.get('name') if profile_dict.get('name') else None,
        profile_dict.get('telephone') if profile_dict.get('telephone') else None,
        profile_dict.get('website') if profile_dict.get('website') else None,
        establishment_id,
        False,
        0,
        1
    )

    print(f"Inserting user record: {values}")

    # Execute query
    cursor.execute(insert_query, values)
    record_id = cursor.lastrowid
    return record_id

# # ── INSERT ALL PROFILES ────────────────────────────────────────────
# for profile in service_provider_profiles:
#     insert_establishment(profile, cur)
#     # break

# try:
#     inserted_count = 0
#     skipped_count = 0
#     for profile in service_provider_profiles:
#         # if profile.get('name') == "Atos":
#         #     print("########################################")
#         #     print(profile)
#         #     print("########################################")
#         try:
#             insert_establishment(profile, cur)
#             inserted_count += 1
#             print(f"Inserted {inserted_count} profiles...")
#         except IntegrityError as e:
#             if e.errno == 1062:
#                 skipped_count += 1
#                 print(f"Skipped duplicate entry: {profile.get('name')}")
#             else:
#                 print(f"Encountered unexpected IntegrityError: {e}")
#                 raise e  # re-raise unexpected errors
#     print("All insertions succeeded without errors. Rolling back test inserts.")
# except Exception as e:
#     # print(f"Error encountered: {e}")
#     raise e
# finally:
#     # Single rollback to clear all test inserts at once
#     cnx.rollback()
#     cur.close()
#     cnx.close()

try:
    inserted_count = 0
    skipped_count = 0
    for profile in service_provider_profiles:
        try:
            establishment_id = insert_establishment(profile, cur)
            for service in profile["services"]:
                service_id = insert_service(service, cur)
                insert_establishment_service(establishment_id, service_id, cur)
            inserted_count += 1
            insert_user(profile, establishment_id, cur)
            print(f"Inserted {inserted_count} profiles...")
        except IntegrityError as e:
            if e.errno == 1062:
                skipped_count += 1
                print(f"Skipped duplicate entry: {profile.get('name')}")
            else:
                print(f"Encountered unexpected IntegrityError: {e}")
                raise e
    
    cnx.commit()  # <-- Commit your changes explicitly
    print(f"Final insertion complete. Total inserted: {inserted_count}, duplicates skipped: {skipped_count}")

except Exception as e:
    cnx.rollback()  # Rollback on unexpected exceptions
    print(f"Error encountered, rolled back changes: {e}")
    raise e

finally:
    cur.close()
    cnx.close()

print(f"Inserted {inserted_count} profiles.")
print(f"Skipped {skipped_count} duplicate entries.")
# Out:
# Inserting user record: ('Thales Headquarters location', '2025-06-02 07:31:45.397', None, 'Thales Group', '+33 (0) 1 57 77 80 00', 'https://www.thalesgroup.com', 1, False, 0, 1)
# Inserted 1 profiles...
# Inserting user record: ('Floor 16, Bay Gate Tower, Business Bay P.O.Box 88007, Dubai – United Arab Emirates', '2025-06-02 07:31:45.398', 'info@dubaiconsultancy.ae', 'Dubai Consultancy LLC', '+971 4 554 2020', 'https://dubaiconsultancy.ae/', 1, False, 0, 1)
# Inserted 2 profiles...
# Inserting user record: ('27451 Tourney Road, Ste. 160, Valencia, California 91355', '2025-06-02 07:31:45.399', 'info@protaxservices.com', 'Professional Tax Services', '(661) 259-1967', 'https://protaxservices.com', 1, False, 0, 1)
# Inserted 3 profiles...
# Inserting user record: ('84 offices across 40 countries spanning 6 continents', '2025-06-02 07:31:45.399', None, 'Alvarez & Marsal', None, 'https://www.alvarezandmarsal.com', 1, False, 0, 1)
# Inserted 4 profiles...
# Inserting user record: ('Global Headquarters: 280 Park Ave, 4th Floor, New York, NY 10017', '2025-06-02 07:31:45.399', 'newyork@teneo.com', 'Teneo', '+1 (212) 886 1600', 'https://www.teneo.com', 1, False, 0, 1)
# Inserted 5 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.400', None, 'All American Tax', None, 'https://www.allamericantax.com', 1, False, 0, 1)
# Inserted 6 profiles...
# Inserting user record: ('Global headquarters in Boston, with offices worldwide', '2025-06-02 07:31:45.400', None, 'Boston Consulting Group (BCG)', None, 'https://www.bcg.com', 1, False, 0, 1)
# Inserted 7 profiles...
# Inserting user record: ('24318 Hemlock Ave C2, Moreno Valley, California 92557', '2025-06-02 07:31:45.400', 'gerald@watsontaxfinancial.com', 'Watson Tax & Financial Services', None, 'https://watsontaxfinancial.com', 1, False, 0, 1)
# Inserted 8 profiles...
# Inserting user record: ('Global presence across 24 countries with European roots', '2025-06-02 07:31:45.401', None, 'BearingPoint', None, 'https://www.bearingpoint.com', 1, False, 0, 1)
# Inserted 9 profiles...
# Inserting user record: ('Eight Advisory has 15 offices globally including:\n- Paris: +33 (0) 1 45 61 88 88\n- London: +44 (0) 20 8089 8888\n- Brussels: +32 (78) 708 888\n- Frankfurt: +49 69 95 17 98 88\n- Munich: +49 89 55 20 98 88\n- Hamburg: +49 (0) 157 80636610\n- Amsterdam: +31 20 8', '2025-06-02 07:31:45.401', None, 'Eight Advisory', '+33 (0) 1 45 61 88 88', 'https://www.8advisory.com', 1, False, 0, 1)
# Inserted 10 profiles...
# Inserting user record: ('Global presence with 28 offices worldwide including:\nUS Offices: Arizona (Chandler), California (Campbell, Laguna Hills, San Diego), Florida (Palm Beach Gardens), Illinois (Chicago), Massachusetts (Andover, Beverly), Minnesota (Minneapolis), Ohio (Cincinn', '2025-06-02 07:31:45.402', None, 'Oxford Global Resources', '+353 21 485 7200', 'https://www.oxfordcorp.com', 1, False, 0, 1)
# Inserted 11 profiles...
# Inserting user record: ('Office No. 113, Al Kazim Building, Al Garhoud, Dubai, United Arab Emirates', '2025-06-02 07:31:45.402', 'info@arabianwingzuae.com', 'Arabian Wingz', '+971 566621785', 'https://arabianwingzuae.com/', 1, False, 0, 1)
# Inserted 12 profiles...
# Inserting user record: ('Multiple global locations including:\n- USA: Komori America Corporation\n- Canada: KOMCAN (Georgetown, ON)\n- Japan: Headquarters\nWith regional sales and service networks across North America, Europe, Asia and other regions.', '2025-06-02 07:31:45.402', 'clahr@komori.us', 'KOMORI CORPORATION', '1-800-566-6741', 'https://www.komori.com', 1, False, 0, 1)
# Inserted 13 profiles...
# Inserting user record: ('Corporate headquarters located in Houston, Texas with operations in more than 60 countries globally', '2025-06-02 07:31:45.402', None, 'ExxonMobil', None, 'https://corporate.exxonmobil.com', 1, False, 0, 1)
# Inserted 14 profiles...
# Inserting user record: ('Philadelphia headquarters: 1600 Arch Street, Suite 200, Philadelphia, PA 19103\nBoston office: 501 Boylston Street, 5th Floor, Boston, MA 02109\nDurham office: 110 Corcoran Street, 5th Floor, Durham, NC 27701\nNew York Office: 300 Vesey Street, 10th Floor, N', '2025-06-02 07:31:45.402', None, 'Vynamic LLC', None, 'https://vynamic.com', 1, False, 0, 1)
# Inserted 15 profiles...
# Inserting user record: ('DELL sp. z o. o., ul. Inflancka 4A, 00-189 Warsaw, Poland', '2025-06-02 07:31:45.403', None, 'Dell Technologies', '22 507 1700', 'https://www.dell.com/pl-pl', 1, False, 0, 1)
# Inserted 16 profiles...
# Inserting user record: ('IBM Corporation, 1 New Orchard Road, Armonk, New York 10504-1722, United States', '2025-06-02 07:31:45.403', None, 'IBM', None, 'https://www.ibm.com/cloud', 1, False, 0, 1)
# Inserted 17 profiles...
# Inserting user record: ('Multiple locations across USA', '2025-06-02 07:31:45.403', None, 'Datavail', '866-808-9340', 'https://www.datavail.com', 1, False, 0, 1)
# Inserted 18 profiles...
# Inserting user record: ('Multiple global offices (specific addresses not provided in content)', '2025-06-02 07:31:45.403', None, 'Cyble', '+1 888 673 2067', 'https://cyble.com', 1, False, 0, 1)
# Inserted 19 profiles...
# Inserting user record: ('NYC: 370 Lexington Ave. Suite 1806, New York, NY, 10017 United States\nBarcelona: Mas de Roda 6-14, Sant Martí, 08005 Barcelona, Spain\nKyiv Office (Address not provided)', '2025-06-02 07:31:45.404', None, 'DOOR3', '+1 (212) 673-1818', 'https://www.door3.com', 1, False, 0, 1)
# Inserted 20 profiles...
# Inserting user record: ('The Salvation Army operates 7,546 centers across communities in the United States', '2025-06-02 07:31:45.404', 'ARCCSupport.Ecomm@usw.salvationarmy.org', 'The Salvation Army', None, 'https://shopthesalvationarmy.com', 1, False, 0, 1)
# Inserted 21 profiles...
# Inserting user record: ('Four Corners, Bozeman, MT (specific address provided upon appointment) | Mailing Address: P.O. Box 10187, Bozeman, MT 59719', '2025-06-02 07:31:45.405', 'creativebargainsllc@yahoo.com', 'Creative Bargains', '406-209-3742', 'https://creativebargains.com', 1, False, 0, 1)
# Inserted 22 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.406', None, 'The Asia Group', None, 'https://theasiagroup.com/', 1, False, 0, 1)
# Inserted 23 profiles...
# Inserting user record: ('9/229 Robinson Road East, Geebung, Brisbane, QLD, Australia 4034. Opening hours: Mon-Fri 10am-5pm, Saturday 9am-4pm, Sunday 10am-2pm', '2025-06-02 07:31:45.406', 'geebungfridges@gmail.com', 'Second Hand Appliances Geebung', '0440 130 475', 'https://secondhandappliancesgeebung.com.au', 1, False, 0, 1)
# Inserted 24 profiles...
# Inserting user record: ('13 store locations throughout Ohio, Michigan and Texas', '2025-06-02 07:31:45.406', 'info@valueworld.com', 'Value World', None, 'https://valueworld.com', 1, False, 0, 1)
# Inserted 25 profiles...
# Inserting user record: ('2184 E 54th St, Broad Ripple, Indianapolis. Store Hours: Tuesday-Thursday 12-6pm, Friday-Saturday 12-7pm, Sundays 12-5pm, Closed Mondays.', '2025-06-02 07:31:45.406', 'NaptownThrift317@gmail.com', 'Naptown Thrift', '317-426-3331', 'https://naptownthrift.com', 1, False, 0, 1)
# Inserted 26 profiles...
# Inserting user record: ('2043 West Roscoe Street, Chicago, IL 60618', '2025-06-02 07:31:45.406', None, 'Village Discount Outlet', '(866) 545-3836', 'https://villagediscountoutlet.com', 1, False, 0, 1)
# Inserted 27 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.406', None, 'Black Shag Vintage', None, 'https://blackshagvintage.com', 1, False, 0, 1)
# Inserted 28 profiles...
# Inserting user record: ('Southern New Jersey, USA (Online only, no physical store)', '2025-06-02 07:31:45.406', None, 'Dandelion Vintage', None, 'https://www.dandelionvintage.com', 1, False, 0, 1)
# Inserted 29 profiles...
# Inserting user record: ('491 Bilsen Road, Geebung, Brisbane 4034', '2025-06-02 07:31:45.407', 'tracey.laird@uccommunity.org.au', 'Lifeline Queensland', '13 11 14', 'https://shop.lifelineqld.org.au', 1, False, 0, 1)
# Inserted 30 profiles...
# Inserting user record: ('Headquartered in Portland, Oregon, with additional worldwide offices in London, Charlotte (North Carolina), Frankfurt and Bangalore', '2025-06-02 07:31:45.407', None, 'NAVEX', '1-866-297-0224', 'https://www.navex.com', 1, False, 0, 1)
# Inserted 31 profiles...
# Inserting user record: ('521 E. Chatham Street, Cary NC', '2025-06-02 07:31:45.407', 'info@consigningdesign.com', "Petersons' Consigning Design", '919-468-9998', 'https://pcdshopping.com', 1, False, 0, 1)
# Inserted 32 profiles...
# Inserting user record: ('3210 Hewitt Ave Everett, WA 98201', '2025-06-02 07:31:45.407', 'everettconsignment@hotmail.com', 'Everett Consignment', '425-259-9998', 'https://www.everettconsignment.com', 1, False, 0, 1)
# Inserted 33 profiles...
# Inserting user record: ('Main Location: 5350 N Keystone Ave, Indianapolis, IN 46220\nAdditional Locations: \n- 9200 E. 131st St, Fishers, IN 46038\n- 5611 S Tamiami Trail, Sarasota, FL 34231', '2025-06-02 07:31:45.407', None, 'AutoGiant USA', '(317) 747-3081', 'https://www.autogiantusa.com', 1, False, 0, 1)
# Inserted 34 profiles...
# Inserting user record: ('10 locations across the Southern United States', '2025-06-02 07:31:45.407', None, 'United Apparel Liquidators', None, 'https://store.shopual.com', 1, False, 0, 1)
# Inserted 35 profiles...
# Inserting user record: ('Headquarters in Lithuania with offices across Europe', '2025-06-02 07:31:45.407', None, 'Vinted', None, 'https://www.vinted.com', 1, False, 0, 1)
# Inserted 36 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.407', None, 'Carousell', None, 'https://www.carousell.ph', 1, False, 0, 1)
# Inserted 37 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.408', None, 'Couture USA', None, 'https://coutureusa.com/', 1, False, 0, 1)
# Inserted 38 profiles...
# Inserting user record: ('Registered office - One Park Plaza, Suite 600, Irvine, CA 92614; Goa office - Software Technology Parks of India, 2nd floor, Udyog Bhawan, Panaji, Goa - 403 001; Kochi office - 3rd Floor UB Business Centre, near Aditya Hospital, Thrikkakara, Ernakulam, Ko', '2025-06-02 07:31:45.408', 'contact@mclarenss.com', 'McLaren Strategic Solutions', None, 'https://mclarenss.com/', 1, False, 0, 1)
# Inserted 39 profiles...
# Inserting user record: ('18 locations across major business centres in the UK', '2025-06-02 07:31:45.408', None, 'BDO LLP', None, 'https://www.bdo.co.uk', 1, False, 0, 1)
# Inserted 40 profiles...
# Inserting user record: ('BUSINESS CENTER 05, RAKEZ BUSINESS ZONE FZ', '2025-06-02 07:31:45.408', 'info@mosaicchambers.com', 'Mosaic Chambers Group', None, 'https://www.mosaicchambers.com', 1, False, 0, 1)
# Inserted 41 profiles...
# Inserting user record: ('Present in 35 countries across 5 continents', '2025-06-02 07:31:45.408', 'hi@globant.com', 'Globant', None, 'https://www.globant.com', 1, False, 0, 1)
# Inserted 42 profiles...
# Inserting user record: ('Multiple locations across 7 offices in 3 countries', '2025-06-02 07:31:45.408', None, 'Cart.com', None, 'https://cart.com', 1, False, 0, 1)
# Inserted 43 profiles...
# Inserting user record: ('Namibia', '2025-06-02 07:31:45.408', None, 'Cash Converters', None, 'https://www.cashconverters.com.na', 1, False, 0, 1)
# Inserted 44 profiles...
# Inserting user record: ('Global presence with offices across North America, Europe, Middle East, Australia and Oceania, Asia Pacific, and South America', '2025-06-02 07:31:45.408', None, 'Merkle', None, 'https://www.merkle.com', 1, False, 0, 1)
# Inserted 45 profiles...
# Inserting user record: ('Abraj Al Mamzar Building, Block A, Office 206, Al Ittihad Road, Dubai, UAE', '2025-06-02 07:31:45.408', 'info@efgpro.ae', 'EFG Corporate Services Provider', '+971 4 548 3002', 'https://efgpro.ae', 1, False, 0, 1)
# Inserted 46 profiles...
# Inserting user record: ('Office 313, D05-06, Floor 11, Al Sarab Tower, ADGM Square, Al Maryah Island, Abu Dhabi, United Arab Emirates', '2025-06-02 07:31:45.408', None, 'JTC', None, 'https://www.jtcgroup.com', 1, False, 0, 1)
# Inserted 47 profiles...
# Inserting user record: ('Headquarters: 9666 Olive Blvd | Suite 710, St. Louis, MO 63132\nSt. Louis Satellite Location: 1835 Lackland Hill Parkway, St. Louis, MO 63146', '2025-06-02 07:31:45.408', None, 'SSE Inc St. Louis', '(314) 439-4700', 'https://www.sseinc.com/', 1, False, 0, 1)
# Inserted 48 profiles...
# Inserting user record: ('USA (Headquarter): 700 N. Fairfax suite 614, Alexandria VA, 22314 United States\nEurope: Rua Viriato 27-3A, 1050-234 Lisbon, Portugal\nWestern Asia: 14 Paronyan St., Bln. 6, 0009 Yerevan, Armenia\nMiddle East: Al Marsa Street Marina Plaza, Level 27 Dubai, Un', '2025-06-02 07:31:45.409', None, 'Geomotiv', '+15715597486', 'https://geomotiv.com', 1, False, 0, 1)
# Inserted 49 profiles...
# Inserting user record: ('Headquarters in Atlanta with offices in Boston, Chicago, Dallas, Houston, Las Vegas, Los Angeles, Milwaukee, New York City, Orlando, Philadelphia, Sacramento, San Francisco, Toronto, Vancouver, Washington DC and other locations across North America', '2025-06-02 07:31:45.409', None, 'Insight Global', '855-485-8853', 'https://insightglobal.com', 1, False, 0, 1)
# Inserted 50 profiles...
# Inserting user record: ('EY has multiple offices across major cities in India including Mumbai, Delhi, Bangalore, Chennai, Kolkata, Hyderabad, and other locations.', '2025-06-02 07:31:45.409', 'ey.india@in.ey.com', 'EY India', '+91 22 6192 0000', 'https://www.ey.com/en_in', 1, False, 0, 1)
# Inserted 51 profiles...
# Inserting user record: ('Head Office Lahore: Main Walton Road, Opp. Bab-e-Pakistan, Walton Cantt, Lahore', '2025-06-02 07:31:45.409', 'info@wateen.com', 'Wateen Telecom', '042-111-365-111', 'https://wateen.com', 1, False, 0, 1)
# Inserted 52 profiles...
# Inserting user record: ('55 Walkers Brook Drive, 6th Floor, Reading, MA 01867', '2025-06-02 07:31:45.409', None, 'Eliassen Group', None, 'https://www.eliassen.com', 1, False, 0, 1)
# Inserted 53 profiles...
# Inserting user record: ('Whiteoaks International, Form 1, Bartley Wood Business Park, Bartley Way, Hook, RG27 9XA', '2025-06-02 07:31:45.409', 'hello@whiteoaks.co.uk', 'Whiteoaks International', '+44 (0)1252 727313', 'https://whiteoaks.co.uk', 1, False, 0, 1)
# Inserted 54 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.409', None, 'Tecno', None, None, 1, False, 0, 1)
# Inserted 55 profiles...
# Inserting user record: (None, '2025-06-02 07:31:45.409', None, 'Moneycontrol', None, 'https://www.moneycontrol.com', 1, False, 0, 1)
# Inserted 56 profiles...
# Inserting user record: ('Global presence with 400 offices across 60 countries worldwide', '2025-06-02 07:31:45.409', None, 'Cushman & Wakefield', None, 'https://www.cushmanwakefield.com', 1, False, 0, 1)
# Inserted 57 profiles...
# Inserting user record: ('USA: 15 British American Blvd. Latham, NY 12110\nCanada: 1111, St-Charles Street West, Suite 352 Longueuil, Quebec Canada J4K 5G4', '2025-06-02 07:31:45.409', 'support@k-ecommerce.com', 'k-ecommerce', '1-855-532-6663', 'https://k-ecommerce.com', 1, False, 0, 1)
# Inserted 58 profiles...
# Inserting user record: ('1401 Lavaca Street, Unit #298, Austin TX 78701', '2025-06-02 07:31:45.409', 'support@rb2b.com', 'RB2B', None, 'https://www.rb2b.com', 1, False, 0, 1)
# Inserted 59 profiles...
# Inserting user record: ('Locations in Boston, London, Toronto, Washington D.C.', '2025-06-02 07:31:45.409', 'gscibelli@marketbridge.com', 'Marketbridge', None, 'https://marketbridge.com', 1, False, 0, 1)
# Inserted 60 profiles...
# Final insertion complete. Total inserted: 60, duplicates skipped: 0
# Inserted 60 profiles.
# Skipped 0 duplicate entries.

# %%
import mysql.connector as mc
from datetime import datetime
from mysql.connector.errors import IntegrityError

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST     = "127.0.0.1"
PORT     = 3306
USER     = "root"
PASSWORD = "rootpass"
SCHEMA   = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── INSERT FUNCTION FOR SERVICE TABLE ──────────────────────────────
def insert_service(service_dict, cursor):
    insert_query = f"""
    INSERT INTO `{SCHEMA}`.`service` (
        name, description, deleted
    )
    VALUES (%s, %s, %s)
    """

    # Prepare values
    print("###############################")
    print(service_dict.get('general_service_description'))
    values = (
        service_dict.get('service_title'),
        service_dict.get('general_service_description'),
        False
    )

    print(f"Inserting: {values}")

    # Execute query
    cursor.execute(insert_query, values)

try:
    inserted_count = 0
    skipped_count = 0

    for service in services:
        print(service.get('general_service_description'))
    #     try:
    #         insert_service(service, cur)
    #         inserted_count += 1
    #         print(f"Inserted {inserted_count} services...")
    #     except IntegrityError as e:
    #         if e.errno == 1062:
    #             skipped_count += 1
    #             print(f"Skipped duplicate entry: {service.get('service_title')}")
    #         else:
    #             print(f"Encountered unexpected IntegrityError: {e}")
    #             raise e

    # cnx.commit()  # <-- Commit your changes explicitly
    # print(f"Final insertion complete. Total inserted: {inserted_count}, duplicates skipped: {skipped_count}")

except Exception as e:
    cnx.rollback()  # Rollback on unexpected exceptions
    print(f"Error encountered, rolled back changes: {e}")
    raise e

finally:
    cur.close()
    cnx.close()

print(f"Inserted {inserted_count} services.")
print(f"Skipped {skipped_count} duplicate entries.")
# Out:
# Executive-level advisory services encompassing strategic planning, communications, financial guidance, management consulting, risk management, and human capital solutions. Services focus on facilitating strategic organizational change, providing cross-functional expertise during critical business transitions, and delivering comprehensive business transformation support.
# Tax preparation and consulting services including tax return preparation, tax planning, and professional tax advisory support for individuals and businesses.
# Comprehensive tax and financial services encompassing tax preparation, accounting, bookkeeping, and tax problem resolution. Services include professional tax preparation for corporate, estate, individual, partnership, and multi-jurisdictional taxes. The service provides personalized tax preparation and planning, maintaining compliance with current tax laws and adapting to various life events.
# Strategic M&A advisory services focusing on deal strategy execution and value creation. Services include business and financial analysis, due diligence, identification of value drivers and risks, and comprehensive M&A process support. The service provides end-to-end guidance throughout merger and acquisition transactions.
# Technology solutions and services specializing in defense, aerospace, space, cyber and digital sectors. Services include development of solutions in avionics, air traffic management, digital identity, cybersecurity, and space systems. The service focuses on secure and human-centric technology development for critical systems and infrastructure.
# Business and government consultancy services encompassing business establishment assistance, market access facilitation, project development, and delegation management. Services include fostering government relationships, market fit analysis, concept development, professional representation, and B2B/B2G/G2G process facilitation.
# Comprehensive business setup and financial advisory services including accounting, auditing, bookkeeping, tax advisory, and financial consulting. Services encompass VAT registration, audit and assurance, ISO certification, transfer pricing consultation, tax residency certification, company liquidation support, merger and acquisition advisory, and business establishment across various jurisdictions.
# Comprehensive cybersecurity solutions and services including incident response, threat monitoring, and product security. End-to-end security solutions designed to address modern security challenges through scalable and controlled protective measures.
# Enterprise cloud platform services offering comprehensive solutions for data management, containerization, artificial intelligence, Internet of Things, and blockchain technology. Full-stack cloud platform capabilities supporting multi-deployment options, featuring AI integration, security measures, and hybrid architecture for organizational scaling and data governance.
# Comprehensive data and technology services encompassing business intelligence/analytics, enterprise solutions, data management, database administration, application development and management. Services include cloud solutions and continuous technical support.
# Cybersecurity and threat intelligence services utilizing AI-powered platforms for proactive threat monitoring and protection. Services include attack surface management, threat intelligence, dark web monitoring, vulnerability management, and cyber threat mitigation.
# Technology consultancy and software development services including UX/UI design, digital strategy, and technical consulting. Services encompass custom software development, mobile application development, portal development, enterprise architecture solutions, and artificial intelligence implementation.
# Online thrift store offering a diverse selection of second-hand and new products across multiple categories including clothing, accessories, books, DVDs, toys and other general merchandise.
# Online auction and marketplace platform selling second-hand items across diverse categories including antiques, art, electronics, clothing, and jewelry.
# Second-hand furniture and home decor retail service offering buying, selling, consignment, and trading of used furniture including bedroom furniture, office furniture, living room furniture, storage solutions, seating, and decorative items.
# Business consulting and advisory services focusing on market entry, sales strategy, corporate strategy development, risk management, and pre-litigation support, combining public policy and corporate strategy expertise.
# Thrift store retail service offering secondhand merchandise including clothing, housewares, and home goods. Daily inventory updates with items sourced through various channels, providing affordable shopping options for general merchandise.
# Vintage clothing retail service specializing in curated vintage apparel including t-shirts, sweatshirts, jerseys, outerwear, and headwear. Offers both physical store and e-commerce shopping options.
# Discount retail service offering new and secondhand name-brand merchandise, including clothing, housewares, and accessories for all ages. Features daily inventory updates with focus on quality secondhand items at competitive prices.
# Specialized vintage retail service focusing on authentic vintage clothing, accessories, and music-related merchandise. Offers curated collection of vintage apparel including concert merchandise, designer items, denim, outerwear, footwear, and jewelry for both men and women.
# Vintage clothing and accessories retail service specializing in authentic pieces from various historical periods. The service includes a diverse collection of wearable vintage garments, lingerie, and accessories such as hats, gloves, and bags. Additionally offers vintage fabrics and linens, with all items professionally cleaned and prepared for sale.
# Online thrift store service offering a comprehensive range of second-hand and new merchandise across multiple categories. The service includes retail of pre-owned clothing, accessories, books, DVDs, and various other items through an e-commerce platform.
# Large-scale furniture and home décor consignment service featuring an extensive selection of residential furnishings. The service specializes in consignment of various furniture categories including living room, dining room, and bedroom pieces, along with decorative items. Maintains a regularly updated inventory with daily new additions.
# Luxury designer resale service specializing in authenticated pre-owned high-end fashion items, bags, and jewelry. The service features regular inventory updates of premium designer merchandise through an online platform, with authentication services for luxury items.
# Pre-owned vehicle dealership service offering a selection of cars, trucks, and SUVs. The service includes vehicle reconditioning, financing options, and delivery services. The business model focuses on providing a comprehensive car-buying experience with various vehicle options and financing solutions.
# Apparel and accessories liquidation service specializing in designer brands. The business model involves selling limited quantity merchandise through both physical retail locations and online platforms. The service focuses on providing discounted designer fashion items.
# Mobile-based classified advertisements and marketplace platform supporting multiple product categories. The service facilitates peer-to-peer buying and selling through features including messaging, user ratings, and secure payment systems. The platform supports various product categories including property, vehicles, electronics, and fashion.
# Professional services including tax consulting, audit and assurance, business advisory, and outsourcing solutions across various economic sectors. Services are delivered through specialized expertise in respective fields to address business challenges and support organizational growth.
# Comprehensive wealth management and advisory services including tax planning, business establishment assistance, and relocation services. Offerings encompass international tax advisory, family office services, tax compliance, and strategic wealth management solutions for individuals and businesses.
# Digital transformation and technology solutions focusing on artificial intelligence implementation and digital product development. Services include creation of digital-native solutions, enterprise technology integration, and specialized industry-specific digital innovations.
# Luxury designer resale services specializing in authenticated pre-owned high-end fashion items, including designer bags, jewelry, and accessories. Services include authentication of luxury goods and resale of premium fashion merchandise.
# Second-hand goods trading and financial services operation that combines retail and lending services. The service includes buying and selling pre-owned items, providing personal loans, and offering payment solutions. Core services encompass second-hand retail operations and consumer financial services.
# Customer experience and digital transformation consulting services that combine strategic planning, data analytics, and technology implementation. Services include data-driven marketing strategy, customer relationship management, loyalty program development, business operations consulting, product design, platform engineering, and analytics solutions.
# Business establishment and corporate services that facilitate company formation and regulatory compliance. Services include business licensing, company incorporation, visa processing, sponsorship arrangements, and document authentication. The service scope covers all aspects of business setup and ongoing administrative support.
# Managed IT and cybersecurity services that focus on system protection, compliance management, and technology infrastructure support. Services include cybersecurity implementation, cloud service management, IT system maintenance, and regulatory compliance assistance. The service ensures continuous system operation while maintaining security and regulatory standards.
# Integrated professional services encompassing assurance, consulting, strategy, transactions, and tax services. Services utilize data-driven approaches and technology to deliver business transformation, operational improvement, and regulatory compliance solutions. Offerings include financial auditing, business advisory, strategic planning, merger and acquisition support, and tax planning services.
# B2B e-commerce and payment processing solutions integrated with ERP systems. Services include online store management, business process automation, order fulfillment systems, and payment processing. Platform provides real-time data integration, workflow optimization, and scalable e-commerce capabilities for business-to-business transactions.
# Integrated marketing and business growth consulting services encompassing go-to-market strategy development, marketing analytics, brand development, demand generation, and strategic communications. The service combines strategic planning with practical execution to enhance organizational marketing performance.
# Comprehensive financial and business services including tax preparation and planning, accounting and bookkeeping, business consulting, payroll processing, tax problem resolution, notary services, and mortgage information assistance. Services encompass individual and business tax returns, financial record maintenance, strategic business guidance, and regulatory compliance support.
# Professional advisory services focusing on business performance improvement and turnaround management. Services include strategic advisory, operational enhancement, interim leadership solutions, and specialized consulting for corporations, investors, and government organizations. Focus areas encompass decision support, growth acceleration, and practical problem-solving for complex business challenges.
# Enterprise software development services focusing on custom solutions, business process modeling, application development and customization, digital transformation, legacy system modernization, and software integration. The service aims to enhance organizational efficiency and scalability through tailored software solutions.
# Comprehensive ICT services including connectivity solutions, enterprise networking, professional IT services, and managed security services. The service portfolio encompasses infrastructure management, cloud services, network solutions, cybersecurity, and surveillance systems, providing end-to-end telecommunications and IT solutions.
# B2B technology public relations services including media relations, content creation, creative services, social media management, and digital PR, specializing in sectors such as cybersecurity, financial technology, healthcare technology, and digital infrastructure.
# 5G smartphone device offering curved display technology, high-capacity battery with fast charging capabilities, artificial intelligence software with language support, and advanced connectivity features.
# Financial information and news platform providing market analysis, stock price data, and comprehensive coverage of business, sports, and financial markets with real-time updates.
# Management consulting services providing comprehensive business transformation support, including strategic planning, organizational change management, growth enablement, and operational optimization. Services focus on addressing complex business challenges, implementing transformational initiatives, and delivering measurable performance improvements across various industries.
# Management and technology consultancy services operating through three main service areas: business advisory consulting, digital assets and managed services, and M&A and transaction services. The service focuses on delivering measurable business success while incorporating sustainability and environmental protection principles.
# Comprehensive SAP consulting services including implementations, upgrades, optimizations, and support. Services encompass project management, business process reengineering, system development, master data management, change management, and technical implementations across various business modules including finance, HR, operations, analytics, and e-commerce. The service provides end-to-end solutions from initial assessment through post-implementation support.
# Healthcare industry management consulting services focusing on strategic transformation and implementation. Specialized expertise in Life Sciences, Health Services, and Health Technology sectors, providing strategic solutions through collaborative engagement models to enable organizational growth and performance improvement.
# Printing press systems and solutions including offset printing, digital printing systems, post-press equipment, and print management services. Comprehensive printing solutions covering commercial, packaging, and currency printing applications.
# Integrated energy, chemical, and industrial solutions including low-carbon technologies, fuel products, lubricants, and chemical products. Services encompass energy production, emission reduction solutions, and innovative industrial product development.
# Retail service specializing in factory seconds, second-hand, and damaged appliances, offering various household appliances including refrigeration units, laundry equipment, and dishwashers, with delivery and removal services.
# Financial and corporate services provider offering fund administration, trust services, employer solutions, compliance services, treasury management, and sustainability consulting. Provides comprehensive business administration and financial management solutions.
# Full-service consignment operation specializing in resale of gently used furniture, clothing, and home décor. The service includes comprehensive management of the sales process, from item evaluation and pricing to merchandising and customer transactions. Features regular inventory updates and careful curation of quality pieces.
# Online marketplace platform for second-hand clothing and accessories trading. The service facilitates buying, selling, and exchanging pre-owned fashion items between users. The platform promotes sustainable fashion through extended product lifecycle and peer-to-peer trading.
# Professional consulting service specializing in governance, risk, and compliance (GRC) technology implementation and optimization. The service includes implementation support, system analysis, change management, compliance consulting, and training. The business focuses on helping organizations improve their GRC processes and technology utilization.
# Comprehensive technology consulting and digital transformation services encompassing artificial intelligence, machine learning, cloud computing, cybersecurity, data engineering, and enterprise platforms. Services include technology engineering and management, business process as a service (BPaaS), and platform services. Additional offerings cover quality engineering and enterprise resource planning consulting.
# E-commerce and logistics platform services that integrate multi-channel commerce operations. The service includes comprehensive solutions for online and physical retail management, encompassing listing management, sales processing, and fulfillment operations. The platform enables seamless integration of digital and physical commerce channels for business operations.
# Comprehensive staffing and recruitment services including talent acquisition, professional staffing solutions, recruitment process outsourcing, executive search, and human capital consulting. Services encompass identifying, evaluating, and placing qualified candidates across various industries and positions, along with providing workforce management solutions and organizational culture advisory.
# Comprehensive telecommunications services providing connectivity solutions for various customer segments. Services include carrier-grade network solutions, enterprise networking services, internet connectivity, and telecommunications infrastructure support. Offerings encompass both business and residential telecommunications solutions with focus on network reliability and accessibility.
# Website visitor identification and analytics service that provides real-time visitor tracking, CRM integration capabilities, and comprehensive traffic insights. The service enables conversion of website traffic into business opportunities through visitor profiling and automated data integration with various business platforms.
# Business transformation and process optimization services including strategic implementation, systems analysis, program management, change management, and process documentation. The service utilizes agile methodologies and systematic approaches to enhance organizational efficiency, process automation, and strategic objective achievement.
# Comprehensive commercial real estate services encompassing agency leasing, asset management, capital markets solutions, occupier services, project and development management, tenant representation, and property valuation and advisory. These services are designed to address complex real estate challenges and deliver value for property occupiers and owners.
# Comprehensive commercial real estate services encompassing agency leasing, asset management, capital markets solutions, occupier services, project and development management, tenant representation, and property valuation and advisory. These services are designed to address complex real estate challenges and deliver value for property occupiers and owners.
# Inserted 0 services.
# Skipped 0 duplicate entries.

# %%
import pandas as pd
import mysql.connector as mc

# ── DB CONFIG ──────────────────────────────────────────────────────
HOST = "127.0.0.1"
PORT = 3306
USER = "root"
PASSWORD = "rootpass"
SCHEMA = "growbal"

# ── CONNECT ────────────────────────────────────────────────────────
cnx = mc.connect(
    host=HOST, port=PORT,
    user=USER, password=PASSWORD,
    database=SCHEMA,
    auth_plugin="mysql_native_password",
)
cur = cnx.cursor(dictionary=True)

# ── EXECUTE QUERY ──────────────────────────────────────────────────
cur.execute(f"DESCRIBE `{SCHEMA}`.`establishment`;")
schema_info = cur.fetchall()

# ── DISPLAY RESULTS AS DATAFRAME ───────────────────────────────────
df_schema = pd.DataFrame(schema_info)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

print(df_schema)

# ── CLOSE CONNECTION ───────────────────────────────────────────────
cur.close()
cnx.close()
# Out:
#                   Field          Type Null  Key Default           Extra
# 0                    id        bigint   NO  PRI    None  auto_increment
# 1                adress  varchar(255)  YES         None
# 2               blocked        bit(1)   NO         None
# 3          company_name  varchar(255)  YES  UNI    None
# 4         creation_date   datetime(6)  YES         None
# 5               deleted        bit(1)   NO         None
# 6           description      longtext  YES         None
# 7           designation  varchar(255)  YES         None
# 8                 email  varchar(255)  YES  UNI    None
# 9           expiry_date   datetime(6)  YES         None
# 10           founded_in   datetime(6)  YES         None
# 11             password  varchar(255)  YES         None
# 12                phone  varchar(255)  YES         None
# 13  representative_name  varchar(255)  YES         None
# 14                 slug  varchar(255)  YES  UNI    None
# 15             sub_name  varchar(255)  YES         None
# 16           tax_number  varchar(255)  YES  UNI    None
# 17                 type      smallint  YES         None
# 18             verified        bit(1)   NO         None
# 19             web_site  varchar(255)  YES         None
# 20              city_id        bigint  YES  MUL    None
# 21           country_id        bigint  YES  MUL    None
# 22     cover_picture_id        bigint  YES  MUL    None
# 23           licence_id        bigint  YES  MUL    None
# 24              logo_id        bigint  YES  MUL    None
# 25           profile_id        bigint  YES  UNI    None
# 26            region_id        bigint  YES  MUL    None
# 27           type_ez_id        bigint  YES  MUL    None
# 28         user_user_id        bigint  YES  UNI    None
# 29               agency      longtext  YES         None
# 30               vision      longtext  YES         None
# 31               mobile  varchar(255)  YES         None

# %%
services = await load_all_services()
company_service_descriptions = []
for service in services:
    if service["service_description"]:
        company_service_descriptions.append(service["service_description"])
print(company_service_descriptions)
# Out:
# ['A&M is a global professional services firm that provides advisory, business performance improvement and turnaround management services across six continents. They help organizations tackle complex business issues, boost operating performance and maximize stakeholder value. The firm specializes in providing practical solutions to unique problems of companies, investors and government entities.', 'Comprehensive tax preparation and financial services including business services (payroll, bookkeeping, sales & use tax), individual tax services, incorporation services (Corporation, LLC, Non-Profit), financial planning (retirement, college & education, home owners), real estate & loans, and insurance services (personal, business, health, life).', 'Tax Comp has been serving the communities of Moreno Valley and Riverside area for 40 years, providing professional tax preparation, planning, and IRS tax problem resolution services. The firm specializes in both personal and business tax return preparation with a focus on saving clients money through maximizing tax benefits. As a member of the Riverside Tax Consultants Association and Inland Society of Tax Consultants, they offer professional tax services at affordable prices.', 'TAXtical LLC provides comprehensive tax services including tax preparation, audit defense, payroll processing, P&L statements, ITIN applications, business advisory, and tax planning. They ensure accurate filings, maximize deductions, and maintain full compliance with tax laws while offering expert guidance for businesses and individuals.', "NMS Consulting provides comprehensive management consulting services with custom solutions for private and public organizations. The firm is dedicated to an uncompromising principle of providing effective and bespoke management consulting services, challenging established thinking, inspiring innovation, and driving results. They act as a catalyst for clients' business growth and success on many levels.", 'Cambridge Management Consulting (Cambridge MC) is an international consulting firm that helps companies make positive impact through digital transformation and strategic consulting. They specialize in strategy, technology, process improvement, and organizational development across various sectors including telecoms, public sector, energy & utilities, retail, and financial services. The firm employs senior experts with extensive industry experience to provide credible advice and solutions.', 'FBC & TAX SERVICES is a full-service tax and accounting firm providing high-quality, professional services with a personal touch. They offer comprehensive year-round planning for tax, financial and business affairs, including tax return filing, tax planning, C-corporation/S-corporation/partnership tax returns, bookkeeping, and financial statement preparation. They have expertise in working with professional services firms, real estate firms, manufacturing companies, physician practices, and high-net-worth individuals.', 'zeb is one of the leading strategy, management and IT consultancies specializing in financial services in Europe. They support financial intermediaries in facing industry changes, regulatory requirements, and transformation challenges. Their expertise spans the entire value chain in financial services, with particular focus on banks, insurance companies, and specialized financial institutions.', 'GavTax Advisory Services specializes in tax planning, preparation, and accounting services for real estate investors and small businesses. They offer comprehensive services including tax return preparation, entity formation, bookkeeping, and strategic tax planning to help clients minimize tax burden and maximize portfolio growth. Their expertise covers individual and business taxation, with particular focus on real estate investment taxation and compliance.', 'RSM provides assurance, tax and consulting services to middle market leaders globally. They offer comprehensive solutions ...

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
description_list = []
for text in company_service_descriptions:
    if text:
        description_list.append(text)

token_counts = [len(encoding.encode(text)) for text in description_list]
print(sum(token_counts))
average_tokens = sum(token_counts) / len(token_counts)

print(f"Average number of tokens: {average_tokens:.2f}")
# Out:
# 5116
# Average number of tokens: 73.09

# %%
from pydantic import BaseModel
from langchain_anthropic import ChatAnthropic
from anthropic._exceptions import OverloadedError
from langchain_core.prompts import ChatPromptTemplate
from typing import List

class GeneralServiceDescription(BaseModel):
    company_service_description: str
    general_service_description: str

class GeneralServiceDescriptionOutput(BaseModel):
    general_service_description_output: List[GeneralServiceDescription]

def load_prompt(prompt_name):
    with open(f"prompts/{prompt_name}.md", "r") as f:
        return f.read()

prompt = load_prompt("generate_general_service_descriptions")

prompt_template = ChatPromptTemplate.from_messages([
    ("system", prompt),
    ("human", "Generate general service descriptions from the given company specific service descriptions")
])

# llm = ChatOpenAI(openai_api_key=os.environ["OPENAI_API_KEY"], model=llm_model, temperature=0).with_structured_output(RelevanceCheckOutput)
llm = ChatAnthropic(
    model="claude-3-5-sonnet-20241022",
    anthropic_api_key=os.environ["ANTHROPIC_API_KEY"], temperature=0).with_structured_output(GeneralServiceDescriptionOutput)
llm_chain = prompt_template | llm
llm_chain = llm_chain.with_retry(
    retry_if_exception_type=(OverloadedError,),
    wait_exponential_jitter=True,    
    stop_after_attempt=12
)

# %%
general_service_descriptions = None
batch_size = 5
for i in range(0, len(company_service_descriptions), batch_size):
    print(f"Processing batch {i//batch_size+1} of {len(company_service_descriptions)//batch_size}")
    print(f"{i} to {i+batch_size}")
    general_service_descriptions_response = llm_chain.invoke({"company_service_descriptions": company_service_descriptions[i:i+batch_size]})
    if general_service_descriptions is None:
        general_service_descriptions = general_service_descriptions_response
    else:
        general_service_descriptions.general_service_description_output.extend(general_service_descriptions_response.general_service_description_output)
# Out:
# Processing batch 1 of 54
# 0 to 5
# Processing batch 2 of 54
# 5 to 10
# Processing batch 3 of 54
# 10 to 15
# Processing batch 4 of 54
# 15 to 20
# Processing batch 5 of 54
# 20 to 25
# Processing batch 6 of 54
# 25 to 30
# Processing batch 7 of 54
# 30 to 35
# Processing batch 8 of 54
# 35 to 40
# Processing batch 9 of 54
# 40 to 45
# Processing batch 10 of 54
# 45 to 50
# Processing batch 11 of 54
# 50 to 55
# Processing batch 12 of 54
# 55 to 60
# Processing batch 13 of 54
# 60 to 65
# Processing batch 14 of 54
# 65 to 70
# Processing batch 15 of 54
# 70 to 75
# Processing batch 16 of 54
# 75 to 80
# Processing batch 17 of 54
# 80 to 85
# Processing batch 18 of 54
# 85 to 90
# Processing batch 19 of 54
# 90 to 95
# Processing batch 20 of 54
# 95 to 100
# Processing batch 21 of 54
# 100 to 105
# Processing batch 22 of 54
# 105 to 110
# Processing batch 23 of 54
# 110 to 115
# Processing batch 24 of 54
# 115 to 120
# Processing batch 25 of 54
# 120 to 125
# Processing batch 26 of 54
# 125 to 130
# Processing batch 27 of 54
# 130 to 135
# Processing batch 28 of 54
# 135 to 140
# Processing batch 29 of 54
# 140 to 145
# Processing batch 30 of 54
# 145 to 150
# Processing batch 31 of 54
# 150 to 155
# Processing batch 32 of 54
# 155 to 160
# Processing batch 33 of 54
# 160 to 165
# Processing batch 34 of 54
# 165 to 170
# Processing batch 35 of 54
# 170 to 175
# Processing batch 36 of 54
# 175 to 180
# Processing batch 37 of 54
# 180 to 185
# Processing batch 38 of 54
# 185 to 190
# Processing batch 39 of 54
# 190 to 195
# Processing batch 40 of 54
# 195 to 200
# Processing batch 41 of 54
# 200 to 205
# Processing batch 42 of 54
# 205 to 210
# Processing batch 43 of 54
# 210 to 215
# Processing batch 44 of 54
# 215 to 220
# Processing batch 45 of 54
# 220 to 225
# Processing batch 46 of 54
# 225 to 230
# Processing batch 47 of 54
# 230 to 235
# Processing batch 48 of 54
# 235 to 240
# Processing batch 49 of 54
# 240 to 245
# Processing batch 50 of 54
# 245 to 250
# Processing batch 51 of 54
# 250 to 255
# Processing batch 52 of 54
# 255 to 260
# Processing batch 53 of 54
# 260 to 265
# Processing batch 54 of 54
# 265 to 270
# Processing batch 55 of 54
# 270 to 275

# %%
print(general_service_descriptions.general_service_description_output[251].general_service_description)
# Out:
# Comprehensive passport services including processing of new passport applications, renewals, and related documentation services. Services are delivered through a network of dedicated passport processing centers and auxiliary facilities.

# %%
for i, general_service_description in enumerate(general_service_descriptions.general_service_description_output):
    print(i)
    print(general_service_description.company_service_description)
    print(general_service_description.general_service_description)
    print("\n")
# Out:
# 0
# A&M is a global professional services firm that provides advisory, business performance improvement and turnaround management services across six continents. They help organizations tackle complex business issues, boost operating performance and maximize stakeholder value. The firm specializes in providing practical solutions to unique problems of companies, investors and government entities.
# Professional advisory services focusing on business performance improvement and turnaround management. Services include addressing complex business challenges, enhancing operational efficiency, and maximizing value. Solutions are provided for organizational problems across various sectors including corporate, investment, and governmental domains.
#
#
# 1
# Comprehensive tax preparation and financial services including business services (payroll, bookkeeping, sales & use tax), individual tax services, incorporation services (Corporation, LLC, Non-Profit), financial planning (retirement, college & education, home owners), real estate & loans, and insurance services (personal, business, health, life).
# Comprehensive financial and tax services encompassing business tax preparation, payroll processing, bookkeeping, and sales tax management. Services include individual tax preparation, business incorporation assistance, financial planning for retirement and education, real estate services, and various insurance solutions.
#
#
# 2
# Tax Comp has been serving the communities of Moreno Valley and Riverside area for 40 years, providing professional tax preparation, planning, and IRS tax problem resolution services. The firm specializes in both personal and business tax return preparation with a focus on saving clients money through maximizing tax benefits. As a member of the Riverside Tax Consultants Association and Inland Society of Tax Consultants, they offer professional tax services at affordable prices.
# Professional tax services including tax preparation, planning, and IRS problem resolution. Specializes in personal and business tax return preparation with emphasis on maximizing tax benefits and deductions. Services focus on comprehensive tax solutions and compliance management.
#
#
# 3
# TAXtical LLC provides comprehensive tax services including tax preparation, audit defense, payroll processing, P&L statements, ITIN applications, business advisory, and tax planning. They ensure accurate filings, maximize deductions, and maintain full compliance with tax laws while offering expert guidance for businesses and individuals.
# Comprehensive tax and business services including tax preparation, audit defense, payroll processing, financial statement preparation, ITIN application assistance, business advisory, and tax planning. Services focus on accurate filing, deduction optimization, and tax law compliance for both businesses and individuals.
#
#
# 4
# NMS Consulting provides comprehensive management consulting services with custom solutions for private and public organizations. The firm is dedicated to an uncompromising principle of providing effective and bespoke management consulting services, challenging established thinking, inspiring innovation, and driving results. They act as a catalyst for clients' business growth and success on many levels.
# Management consulting services offering customized business solutions for organizations. Services include strategic planning, innovation management, and performance optimization. Focus on delivering effective business transformation and growth through specialized consulting approaches.
#
#
# 5
# Cambridge Management Consulting (Cambridge MC) is an international consulting firm that helps companies make positive impact through digital transformation and strategic consulting. They specialize in strategy, technology, process improvement, and organizational development across various sectors including telecoms, public sector, energy & utilities, retail, and financial services. The firm employs senior experts with extensive industry experience to provide credible advice and solutions.
# Management consulting services focusing on digital transformation and strategic consulting, encompassing strategy development, technology implementation, process improvement, and organizational development across multiple industries. Services include expert advisory and solution development for business transformation initiatives.
#
#
# 6
# FBC & TAX SERVICES is a full-service tax and accounting firm providing high-quality, professional services with a personal touch. They offer comprehensive year-round planning for tax, financial and business affairs, including tax return filing, tax planning, C-corporation/S-corporation/partnership tax returns, bookkeeping, and financial statement preparation. They have expertise in working with professional services firms, real estate firms, manufacturing companies, physician practices, and high-net-worth individuals.
# Comprehensive tax and accounting services including tax return preparation, tax planning, business entity tax returns, bookkeeping, and financial statement preparation. Services cover year-round tax and financial planning for various business structures and industries.
#
#
# 7
# zeb is one of the leading strategy, management and IT consultancies specializing in financial services in Europe. They support financial intermediaries in facing industry changes, regulatory requirements, and transformation challenges. Their expertise spans the entire value chain in financial services, with particular focus on banks, insurance companies, and specialized financial institutions.
# Financial services consulting specializing in strategy, management, and IT solutions. Services include support for industry transformation, regulatory compliance, and operational optimization across the financial services value chain, particularly focused on banking, insurance, and financial institutions.
#
#
# 8
# GavTax Advisory Services specializes in tax planning, preparation, and accounting services for real estate investors and small businesses. They offer comprehensive services including tax return preparation, entity formation, bookkeeping, and strategic tax planning to help clients minimize tax burden and maximize portfolio growth. Their expertise covers individual and business taxation, with particular focus on real estate investment taxation and compliance.
# Tax advisory and accounting services focusing on tax planning, preparation, and compliance. Services include tax return preparation, business entity formation, bookkeeping, and strategic tax planning, with specialized expertise in real estate investment taxation.
#
#
# 9
# RSM provides assurance, tax and consulting services to middle market leaders globally. They offer comprehensive solutions including AI analytics, cloud services, audit and assurance, business applications, financial consulting, global business services, managed services, management consulting, M&A, private client services, risk consulting, and sustainability services.
# Comprehensive professional services including assurance, tax, and consulting solutions. Services encompass AI analytics, cloud services, audit and assurance, business applications, financial consulting, managed services, management consulting, mergers and acquisitions, risk consulting, and sustainability services.
#
#
# 10
# BDO is an international network of public accounting, tax and advisory firms providing professional services across 166 countries and territories. They offer comprehensive services including Audit & Assurance, Tax, Advisory, and Business Services & Outsourcing. With 119,000+ professionals working from more than 1,750 offices worldwide, BDO focuses on delivering exceptional client service through local expertise combined with global reach. Their approach emphasizes understanding client needs, maintaining clear communication, and providing value through innovative solutions and industry-specific knowledge.
# Professional services encompassing audit and assurance, tax planning and compliance, business advisory, and outsourcing solutions. The services include financial statement audits, tax preparation and planning, strategic business consulting, and comprehensive business process outsourcing. These services help organizations maintain financial compliance, optimize tax positions, improve business operations, and efficiently manage back-office functions.
#
#
# 11
# KLR is one of New England's premier accounting and business advisory firms providing a wide range of services to both individuals and businesses. The firm offers comprehensive services including Accounting & Assurance, Business Valuation, Executive Search, Information Security, IT Consulting, Virtual CFO and Outsourced Accounting, Private Client Services, Public Company Services, Growth & Transition Services, Tax Services, and Transaction Advisory Services.
# Comprehensive professional services including accounting and assurance, business valuation, executive recruitment, information security consulting, IT advisory, outsourced financial management, private wealth management, public company compliance, business growth consulting, tax planning and preparation, and transaction advisory. These services support both individual and business clients in managing their financial affairs, operational efficiency, and strategic growth initiatives.
#
#
# 12
# TCS (Tata Consultancy Services) is a leading global IT services and consulting company with over 55 years of experience. They provide technology solutions and services across multiple industries in 55 countries. Their services include artificial intelligence, cloud computing, cognitive business operations, consulting, cybersecurity, data analytics, enterprise solutions, IoT digital engineering, and sustainability services.
# Technology and digital transformation services encompassing artificial intelligence implementation, cloud computing solutions, cognitive business operations, IT consulting, cybersecurity services, data analytics, enterprise system integration, IoT engineering, and sustainability technology solutions. These services enable digital transformation, operational efficiency, and technological advancement across various industries.
#
#
# 13
# McKinsey & Company is a global management consulting firm that helps organizations across the private, public, and social sectors create lasting change. They partner with clients to transform their organizations, embed technology, build capabilities, and create sustainable inclusive growth. Their services span strategy, digital transformation, operations, marketing, organization, and sustainability across various industries.
# Management consulting services focusing on organizational transformation, strategic planning, digital transformation, operational improvement, marketing strategy, organizational development, and sustainability consulting. These services help organizations achieve sustainable growth, operational excellence, and successful digital transformation across various sectors.
#
#
# 14
# Aon provides comprehensive advisory services across two key areas: Risk Capital and Human Capital. For Risk Capital, they offer broking and risk transfer, claims management, reinsurance, risk analytics, risk management, and risk retention services. For Human Capital, they provide health and benefits, human capital analytics, investments, pensions and retirement, talent and rewards, and workplace wellbeing solutions. Their integrated approach helps clients make better decisions to protect and grow their businesses through data-driven insights and expert advice.
# Risk management and human capital advisory services including insurance broking, risk transfer, claims management, reinsurance, risk analytics, and risk retention solutions. Human capital services encompassing health and benefits administration, workforce analytics, investment consulting, pension and retirement planning, compensation consulting, and workplace wellness programs. These integrated services help organizations manage risks and optimize their human capital strategies.
#
#
# 15
# Ultima provides comprehensive IT services including Cloud Services, Managed Services, Digital Workspace, Security Services, Data/Automation/AI, and Networking & Connectivity solutions. They offer 24/7 technical support, infrastructure management, and specialized IT expertise to help businesses achieve their digital transformation goals while maintaining security and operational efficiency.
# Comprehensive IT services encompassing cloud computing, managed services, digital workspace solutions, cybersecurity, data analytics, automation, artificial intelligence, and network connectivity. Services include technical support, infrastructure management, and specialized IT expertise focused on digital transformation and operational efficiency.
#
#
# 16
# Paradigm Business Solutions is a Service Disabled Veteran Owned Small Business (SDVOSB) firm specializing in professional services, contract and supply chain management. They provide procurement services for government, military, and commercial clients with focus on Aerospace components, Engineering, IT, and Healthcare sectors. As a VA-CVE-certified SDVOSB, they partner with manufacturers to offer wide range of parts and products while delivering cost-effective solutions.
# Professional procurement and supply chain management services specializing in aerospace components, engineering solutions, information technology, and healthcare sector supplies. Services include contract management, vendor coordination, and procurement optimization for various industry sectors.
#
#
# 17
# Aegon is an international financial services group with a 180-year history, providing investment, protection, and retirement solutions. Their services include life insurance, retirement planning, investment management, pension solutions, and wealth protection services. Through their various businesses and partnerships, they serve millions of customers globally with a focus on helping people live their best lives.
# Comprehensive financial services including investment management, retirement planning, life insurance, pension solutions, and wealth protection services. Focus on long-term financial planning and wealth management for individuals and organizations.
#
#
# 18
# Gulf Coast Accounting & Tax Services provides comprehensive tax and accounting services including tax preparation, business consulting, financial planning, accounting & bookkeeping, payroll services, and tax planning. They serve both individuals and businesses with expertise in various types of tax returns including individual, business, corporate, partnership, estate, and trust returns.
# Professional tax and accounting services including tax preparation and planning, business consulting, financial planning, bookkeeping, and payroll services. Expertise in handling various types of tax returns including individual, business, corporate, partnership, estate, and trust returns.
#
#
# 19
# MNP is a leading national accounting, tax and business consulting firm in Canada providing comprehensive professional services including assurance and accounting, bookkeeping, consulting, corporate finance, digital services, enterprise risk, ESG consulting, family office services, forensics, insolvency, tax services and valuations. They serve clients across various sectors including agriculture, credit unions, dealerships, energy, manufacturing, public sector and more.
# Comprehensive professional services including accounting, tax services, business consulting, corporate finance, digital services, enterprise risk management, ESG consulting, family office services, forensic accounting, insolvency services, and business valuations. Services cover various aspects of financial and business management across multiple sectors.
#
#
# 20
# Singapore Chartered Tax Professionals (SCTP) is the national tax body that accredits qualified tax professionals, facilitates tax education and engages with the tax community to advance the profession and taxation. Launched in 2010, SCTP promotes tax excellence through standards, conduct and practice. The organization supports tax professionals from diverse backgrounds including tax accountants, lawyers, academics and public sector professionals through accreditation, professional development and industry engagement.
# Professional tax accreditation and education services focused on advancing tax excellence through standardization, professional development, and industry engagement. Services include accreditation of tax professionals, continuing education programs, and facilitation of professional networking within the tax community.
#
#
# 21
# The Oregon Association of Tax Consultants (OATC) provides professional tax services and education through its network of licensed tax practitioners. Founded in 1972, OATC organizes tax practitioners to protect their right to practice and provides education and guidance to better serve clients. The organization offers member benefits including local chapter affiliation, education programs, newsletters, website access, and networking opportunities. OATC also provides scholarship opportunities for those seeking to become Licensed Tax Preparers or Licensed Tax Consultants.
# Professional tax practitioner organization providing education, certification, and networking services. Core offerings include tax education programs, professional development resources, and support services for tax practitioners. Additional services include advocacy for practitioner rights and educational scholarship programs.
#
#
# 22
# Cash Tracks Financial provides professional tax preparation, tax resolution, and tax consulting services. They offer comprehensive tax services including individual returns, business returns, tax planning, IRS representation, and tax resolution for unfiled returns or back taxes. The firm has been in business since 1987 and is owned by Marcelino Dodge, EA, CTRC since 2004. They provide year-round tax services with a focus on personalized attention and building client relationships.
# Comprehensive tax services including professional tax preparation, resolution, and consulting. Services encompass individual and business tax return preparation, tax planning, government agency representation, and resolution services for unfiled returns and back taxes. Year-round tax advisory services are provided with personalized attention.
#
#
# 23
# Full service tax, accounting and business consulting firm providing services since 1985. Services include tax preparation and planning, accounting, payroll services, part-time CFO services, forensic accounting, bank financing, strategic business planning, succession planning, new business formation, estate planning, and elder care services.
# Integrated tax, accounting, and business advisory services including tax preparation and planning, accounting, payroll processing, CFO services, forensic accounting, financial planning, strategic business consulting, succession planning, business formation, estate planning, and elder care financial services.
#
#
# 24
# Blick Rothenberg is a leading tax, accounting and business advisory firm providing comprehensive services including audit, accounting, outsourcing, financial services, global mobility, international tax, private client services, and transaction services. They specialize in supporting businesses with UK operations and international expansion, offering expertise in areas like corporate tax, VAT, payroll, and wealth management.
# Comprehensive tax, accounting, and business advisory services with international scope. Services include audit, accounting, business process outsourcing, financial advisory, global mobility support, international taxation, private client services, and transaction advisory. Specialized expertise in corporate taxation, value-added tax, payroll services, and wealth management.
#
#
# 25
# Grant Thornton Ireland provides comprehensive professional services including advisory, audit, and tax services. Their advisory services encompass aviation advisory, business risk services, consulting, deal advisory, financial accounting and advisory, forensic accounting, restructuring, risk advisory, and sustainability advisory. They combine global scale with local insight and quality to help clients create, protect and transform value.
# Professional services encompassing advisory, audit, and tax services. Advisory services include aviation consulting, business risk assessment, general consulting, deal advisory, financial accounting, forensic accounting, restructuring, risk management, and sustainability consulting. These services aim to create, protect and transform business value through comprehensive professional guidance and expertise.
#
#
# 26
# Atos is a global AI-powered technology partner providing end-to-end IT services across cloud, cybersecurity, data and AI, application services, smart platforms and digital workplace, as well as localized consulting and advisory services. They support public and private organizations throughout their entire digital transformation journey, from strategy and architecture to operations and optimization. Their digital solutions and integrated capabilities are designed to deliver impact for clients, employees and society at large.
# End-to-end IT services including cloud computing, cybersecurity, data analytics, artificial intelligence, application services, smart platforms, and digital workplace solutions. Comprehensive digital transformation services covering strategy development, architecture design, operations management, and optimization. Services include consulting and advisory support for implementing digital solutions and integrated technological capabilities.
#
#
# 27
# Wolters Kluwer provides expert solutions combining domain expertise with advanced technology across multiple sectors including healthcare, tax and accounting, financial and corporate compliance, legal and regulatory, and corporate performance and ESG. They offer software solutions, information services, and expert guidance to help professionals make critical decisions, achieve successful outcomes, and increase productivity.
# Professional solutions combining industry expertise with advanced technology across healthcare, tax, accounting, financial compliance, corporate compliance, legal services, regulatory compliance, corporate performance, and ESG sectors. Services include software solutions, information services, and expert guidance focused on decision-making support, outcome optimization, and productivity enhancement.
#
#
# 28
# Intalio provides comprehensive digital transformation solutions with a focus on Content Services, Process Services, and Data Governance. With 30 years of experience, they support businesses throughout their entire digital transformation journey, offering careful planning and thorough implementation services to ensure successful business outcomes.
# Digital transformation solutions specializing in content services, process services, and data governance. Services include comprehensive planning and implementation support for business digital transformation initiatives, focused on achieving successful operational outcomes through systematic execution.
#
#
# 29
# Rimini Street is a global leader in enterprise software support and services, providing end-to-end solutions for mission-critical systems. They offer comprehensive support for enterprise applications, databases, and technology platforms including Oracle, SAP, VMware, Salesforce, and more. Their services include enterprise software support, managed services, professional services, security solutions, unified support services, interoperability services, monitoring and health check services, tax and regulatory compliance services, and license advisory services.
# Enterprise software support and services providing end-to-end solutions for mission-critical systems. Services include comprehensive support for enterprise applications, databases, and technology platforms. Offerings encompass software support, managed services, professional services, security solutions, unified support, interoperability services, system monitoring, health check services, compliance services, and license advisory.
#
#
# 30
# The Leppert CPA Group provides comprehensive tax advisory services focused on helping businesses and individuals reduce tax liabilities, optimize deductions, and ensure full compliance. Services include business tax compliance, business tax planning, personal tax planning, tax credits & deductions optimization, IRS representation, audit support, personalized tax consultation, and multi-state & federal tax navigation. Their approach emphasizes proactive tax planning and year-round strategic guidance to minimize tax burdens and maximize financial efficiency.
# Comprehensive tax advisory services encompassing business and individual tax planning, compliance, and optimization. Services include tax planning and preparation, deduction optimization, regulatory compliance, audit support, and tax consultation across multiple jurisdictions. The service focuses on strategic tax management to enhance financial efficiency through proactive planning and ongoing guidance.
#
#
# 31
# SMR CPA provides comprehensive Corporate Tax Services including corporate tax filing, planning, compliance, preparation, audit support, advisory, and sales tax filing (GST/HST). They specialize in optimizing tax efficiency while ensuring full compliance, handling everything from T2 filing to CRA representation. Their experienced Corporate Tax Accountants work across multiple industries to maximize deductions and credits while maintaining regulatory compliance.
# Corporate tax services offering comprehensive tax management solutions including tax filing, planning, compliance, preparation, and audit support. The service encompasses sales tax handling, tax efficiency optimization, and regulatory compliance maintenance. Professional tax consultation and representation services are provided to maximize allowable deductions and credits across various industries.
#
#
# 32
# SPC CPAs & Associates, LLC provides comprehensive tax preparation, accounting, bookkeeping, payroll, and business consulting services. They specialize in tax planning, IRS tax problem resolution, non-profit organizations, and QuickBooks services. The firm offers personalized attention and professional guidance to help businesses and individuals manage their financial matters effectively.
# Integrated financial services including tax preparation, accounting, bookkeeping, payroll processing, and business consulting. Services encompass tax planning, tax issue resolution, and specialized accounting for various organizational structures. Professional financial management guidance and support services are provided to optimize business and individual financial operations.
#
#
# 33
# Abdiwali Mohamed CPA PLLC provides comprehensive accounting, tax, and financial services including: accounting and bookkeeping, tax preparation and planning, payroll services, and part-time CFO services. They specialize in services for individuals, businesses, IRS problem resolution, supported living services, group homes, home care agencies, nursing homes, adult family homes, and non-profit organizations.
# Comprehensive financial and accounting services including bookkeeping, tax preparation and planning, payroll management, and executive financial oversight. Services include tax issue resolution and specialized accounting solutions for healthcare facilities, residential care services, and non-profit entities. The service provides both individual and business-focused financial management support.
#
#
# 34
# Jitendra Chartered Accountants (JCA) is a leading accounts, auditing, tax, and bookkeeping outsourcing firm established in January 2001. They provide comprehensive services including auditing & assurance, accounting & bookkeeping, VAT consultancy, AML consulting, economic substance reporting, company liquidation, and trademark registration. They are registered and approved tax agents by UAE Federal Tax Authority with expertise in internal audits, external audits, statutory audits, and management consultancy.
# Professional accounting and auditing services including assurance services, bookkeeping, tax consultancy, and regulatory compliance consulting. Services encompass various types of audits (internal, external, and statutory), anti-money laundering consulting, economic reporting, business dissolution support, and intellectual property services. The offering includes comprehensive management consultancy and tax advisory services.
#
#
# 35
# Mahanakorn Partners Group (MPG) is a leading professional services firm providing comprehensive Legal, Accounting, Auditing, Tax Advisory, and Business Consulting services. As a One-Stop Platform, they assist companies and individuals with seamless navigation through business, regulatory and legal matters, both domestically and internationally. Their services span across Legal Practice Areas, Accounting & Tax Advisory, Corporate Services, Immigration & Global Mobility, and Banking & Finance.
# Professional services encompassing legal, accounting, auditing, tax advisory, and business consulting. Services include assistance with business and regulatory matters, legal practice areas, corporate services, immigration and global mobility solutions, and banking and finance advisory.
#
#
# 36
# Column Tax provides white-label tax filing solutions that enable easy, embedded tax filing for banks, financial institutions, and businesses. Their platform offers API-first tax filing products with features like pre-filling customer data, DIY filing options, and expert review services. As an IRS Authorized e-File Provider, they deliver bank-grade security, SOC 2 certification, and 99.999%+ uptime.
# White-label tax filing solution platform offering API-integrated services for financial institutions. Features include automated data pre-filling, self-service filing options, and professional review services, supported by secure electronic filing capabilities.
#
#
# 37
# Tax990 provides comprehensive e-filing services for Form 990 series tax returns for nonprofit organizations. The service includes features like interview-style filing, form-based filing, data import capabilities, internal audit checks, team collaboration tools, and dedicated customer support. They offer complimentary extension requests, free retransmission of rejected returns, no-cost amendments, and a money-back guarantee for IRS approval.
# Nonprofit tax return e-filing service specializing in Form 990 series. Services include interactive filing systems, data importing, audit verification, and collaborative tools. Additional features comprise tax return amendments, extension processing, and return resubmission capabilities.
#
#
# 38
# EthioDiasporaHub is a comprehensive online platform providing services and resources for Ethiopian diaspora communities worldwide. The platform offers various services including news, banking services, real estate information, scholarship opportunities, career development, and cultural resources. It serves as a central hub connecting Ethiopian diaspora with opportunities and services in Ethiopia and abroad.
# Online diaspora community platform offering comprehensive resources and services including banking, real estate information, educational opportunities, career services, news updates, and cultural content. Functions as an information and service hub connecting diaspora communities with opportunities domestically and internationally.
#
#
# 39
# Glinda Company Inc. offers comprehensive tax and accounting services with the unique Double-A Advantage of having both a CPA and Retired Attorney. Services include individual/business tax returns, accounting, payroll services, tax planning, and financial statements. They specialize in tax preparation for all states, with expertise in Uber & Lyft tax returns. The company offers secure document handling through a web portal and HIPAA-compliant systems.
# Comprehensive tax and accounting services including tax return preparation, accounting, payroll processing, tax planning, and financial statement preparation. Services include secure document management and specialized tax preparation for various business types and individuals.
#
#
# 40
# San Diego Tax Professionals provides comprehensive tax and accounting services including individual taxes, small business taxes, rental property taxes, accounting & bookkeeping, tax preparation and planning, business consulting, trust & estates, late filing, employee stock options, multistate returns, military tax services, and virtual bookkeeping/tax preparation services.
# Comprehensive tax and accounting services encompassing individual and business tax preparation, accounting and bookkeeping, tax planning, trust and estate services, specialized tax handling for various income sources, multi-state tax returns, and virtual financial services. Services include ongoing financial record maintenance, tax compliance, strategic tax planning, and specialized tax preparation for various entities and situations.
#
#
# 41
# Qualys provides a comprehensive cloud-based security platform that helps organizations measure, communicate, and eliminate cyber risk. The Enterprise TruRisk Platform offers integrated IT security, compliance and risk management solutions including vulnerability management, threat detection, compliance monitoring, and cloud security. The platform features over 20 integrated apps with Six Sigma accuracy (99.99966%) for security scanning.
# Cloud-based cybersecurity platform offering integrated IT security, compliance, and risk management solutions. Core functionalities include vulnerability management, threat detection, compliance monitoring, and cloud security. The platform integrates multiple security applications to provide comprehensive digital security and risk assessment services.
#
#
# 42
# WWT (World Wide Technology) is a global technology solutions provider that delivers innovative solutions across networking, automation, mobility, and other technology domains. They combine deep technical expertise with industry knowledge to help organizations transform and modernize their technology infrastructure.
# Technology solutions services focusing on networking, automation, and mobility infrastructure. Services include technical consulting and implementation for technology infrastructure modernization, combining expertise across various technology domains to deliver comprehensive digital transformation solutions.
#
#
# 43
# Nuvei is a global payment technology provider offering comprehensive payment solutions including pay-ins, payouts, global acquiring, bank transfers, real-time payments, payment orchestration, analytics dashboard, and crypto & digital asset services. They provide seamless omnichannel payment processing, fraud management, and banking services across multiple countries and currencies.
# Comprehensive payment technology solutions including payment processing, global acquiring, bank transfers, real-time payments, payment orchestration, and digital asset services. Features include omnichannel payment processing capabilities, fraud management systems, and multi-currency banking services, supported by analytics and reporting tools.
#
#
# 44
# Barrett Distribution Centers provides customized third-party (3PL) logistics, omnichannel distribution, transportation, and direct-to-consumer (DTC) eCommerce fulfillment services since 1941. They operate 25+ facilities across the United States with over 6 million square feet of space specifically designed for warehousing, distribution, transportation and omnichannel eCommerce fulfillment. Their services include advanced Omnichannel, B2B and Direct-To-Consumer (DTC) eCommerce fulfillment solutions, managed transportation solutions with optimized shipping costs, and strategic warehouse locations optimized for speed and efficiency.
# Third-party logistics (3PL) and supply chain management services including warehousing, distribution, transportation, and eCommerce fulfillment. Services encompass B2B and D2C fulfillment solutions, managed transportation services, and strategic warehousing operations. Core capabilities include omnichannel distribution management and integrated logistics solutions focused on operational efficiency.
#
#
# 45
# Tinuiti is a performance-based, full-funnel digital marketing agency that provides comprehensive services across commerce, TV & audio, social, search, and more. They combine brilliant human expertise with powerful technology (Bliss Point by Tinuiti) to deliver measurable business outcomes across the entire customer journey. Their approach focuses on media strategy, operations, and execution while eliminating waste and maximizing growth potential for clients.
# Digital marketing services encompassing full-funnel marketing strategies across multiple channels including commerce, TV, audio, social media, and search engine marketing. The service integrates technology and expertise to optimize marketing operations, develop media strategies, and execute campaigns to improve customer journey outcomes and business growth.
#
#
# 46
# Aprio is a premier business advisory and accounting firm founded in 1952. With over 2,200 team members serving clients in 50+ countries and speaking 60+ languages natively, they provide comprehensive advisory services including audit & assurance, tax services, advisory services, and private client services. The firm specializes in various industries including construction, dental, financial services, healthcare, technology, and more.
# Comprehensive business advisory and accounting services including audit and assurance, tax services, business advisory, and private client services. The service covers multiple industry sectors such as construction, dental, financial services, healthcare, and technology, providing specialized expertise for each sector's unique requirements.
#
#
# 47
# Lazard is one of the world's preeminent financial advisory and asset management firms, providing sophisticated and differentiated advice and investment solutions for clients. The firm offers comprehensive financial advisory services including mergers and acquisitions, capital markets and capital solutions, restructuring and liability management, and specialized advisory services. Their asset management division provides investment solutions to institutions, corporations, governments, partnerships, family offices, and high net worth individuals.
# Financial advisory and asset management services including mergers and acquisitions consulting, capital markets solutions, restructuring services, liability management, and specialized financial advisory services. The service also encompasses comprehensive investment management solutions suitable for various types of investors and organizations.
#
#
# 48
# The U.S. Department of Commerce is a federal government agency focused on creating conditions for economic growth and opportunity for all communities. The department provides various services including trade enforcement, economic development, technological innovation, environmental stewardship, and data services.
# Economic development and regulatory services focusing on trade enforcement, technological innovation promotion, environmental protection, and data services provision. The service aims to foster economic growth and create opportunities through various regulatory and development initiatives.
#
#
# 49
# Crown Commercial Service (CCS) is the UK's biggest public procurement organisation and an executive agency of the Cabinet Office. They help the UK public sector get better value when buying products and services by creating strategic partnerships and competition among suppliers. Their services include helping customers stay compliant with procurement regulations, save time, get better value for money, and reach social value goals. In 2023/24, their customers achieved commercial benefits equal to £4.9 billion.
# Public procurement and sourcing services that facilitate strategic partnerships between buyers and suppliers. The service includes procurement compliance assistance, value optimization in purchasing, and social value achievement support through competitive supplier management and strategic sourcing solutions.
#
#
# 50
# The Ministry of Industry and Commerce (MOIC) provides comprehensive government services including business registration, industrial development, SME support, consumer protection, intellectual property services, and foreign investment facilitation. Key service areas include Business Services & Bahrain Investors Center Services, Industrial Development, SME Development, Trademarks and Patents, Consumer Services, Entrepreneurship Support, and Foreign Investment Services.
# Government regulatory and business facilitation services encompassing business registration, industrial development support, small and medium enterprise assistance, consumer protection oversight, intellectual property management, and investment facilitation. Core services include business development support, industrial sector development, entrepreneurship assistance, trademark and patent processing, consumer protection services, and investment facilitation.
#
#
# 51
# RAK Chamber provides comprehensive business and individual services including business directory services, certificate of origin issuance, membership services, ratification requests, supplier registration, legal and commercial consultation services, and venue booking facilities.
# Chamber of commerce services offering business support through directory listings, origin certification, membership benefits, document ratification, supplier registration management, legal and commercial consulting, and facility rental services.
#
#
# 52
# BDO provides comprehensive tax services including strategic business tax planning, corporate tax, structuring of acquisitions and disposals, employer taxes, VAT, capital gains and stamp taxes. They offer expert tax guidance for businesses and private clients, helping navigate complex tax landscapes both domestically and internationally. Their tax professionals have deep experience and excellent relationships with HMRC at both practical and policy levels. Services include personal tax advice for wealthy individuals, families, business owners, investors and entrepreneurs covering areas like inheritance tax, capital gains tax and international tax matters.
# Comprehensive tax advisory and planning services covering business and personal taxation, including strategic tax planning, corporate taxation, acquisition and disposal structuring, employment taxes, VAT, capital gains, and stamp duties. Services encompass domestic and international tax guidance, personal tax advisory for individuals, families, business owners, and investors, addressing areas such as inheritance tax, capital gains tax, and cross-border taxation.
#
#
# 53
# Grant Thornton provides pragmatic corporate tax advisory services to help businesses manage tax reporting requirements while ensuring value delivery. They offer practical, commercial advice for dynamic, growing businesses in an increasingly complex global tax landscape. Their services include corporate tax compliance, international tax, real estate tax, capital allowances, innovation tax reliefs, transactions tax, and tax dispute services.
# Corporate tax advisory services focused on tax reporting management and value optimization, offering practical guidance for businesses in global tax environments. Services include tax compliance, international taxation, real estate tax planning, capital allowances, innovation tax relief consultation, transaction tax services, and tax dispute resolution.
#
#
# 54
# Xplor provides comprehensive 24/7 Sage support services worldwide through their global team of Sage accredited multilingual consultants. Their support includes regular technical and software updates, legislative compliance checks, dedicated secure client portal for support tracking, flexible responses to software/technical/development demands, regular product training, and annual free health checks of Sage solutions. They specialize in supporting businesses running Sage systems including upgrades from Sage 50, Sage 200, or Sage 1000.
# Enterprise software support services providing round-the-clock technical assistance, software maintenance, compliance monitoring, secure support tracking, technical development support, product training, and system health assessment. Services include software upgrade support and system optimization for business management solutions.
#
#
# 55
# Abu Dhabi Government strives to ensure the emirate is one of the best places in the world to live, work, invest, visit and study. The government provides comprehensive services through various channels including TAMM portal, covering areas like business licensing, vehicle registration, visas, and more.
# Comprehensive government administrative services including business licensing, vehicle registration, visa processing, and related public services delivered through digital and traditional channels.
#
#
# 56
# The UAE Government provides comprehensive support for scientific research through various programmes and platforms. This includes the UAE Research Map, the Researcher platform, Arab Youth Research Platform and Arab Youth Research Council. These initiatives aim to advance scientific research capabilities and foster innovation in the UAE.
# Research support services encompassing research platforms, programs, and initiatives designed to advance scientific capabilities and foster innovation in academic and professional sectors.
#
#
# 57
# The Ministry of Interior of the United Arab Emirates provides comprehensive government services including traffic and licensing, civil defense, police leadership, correctional facilities, and various electronic services. They offer digital services through their smart customer box (blockchain) and gaming platform.
# Integrated public safety and administrative services including traffic management, licensing, civil defense, law enforcement, correctional services, and digital government services.
#
#
# 58
# Dubai Electricity and Water Authority (DEWA) is Dubai's exclusive electricity and water services provider. They offer comprehensive utility services including electricity and water supply, billing, smart metering, sustainable energy solutions, and infrastructure development. DEWA is committed to providing globally leading sustainable, efficient, and reliable power and water services, along with innovative smart solutions towards a Net-Zero Future.
# Comprehensive utility services including electricity and water supply, billing, smart metering, sustainable energy solutions, and infrastructure development, focusing on efficient and reliable power and water distribution.
#
#
# 59
# Dubai Police provides comprehensive law enforcement and public safety services including traffic management, crime prevention, emergency response, and various online services for residents and visitors of Dubai. They offer digital services through their website and mobile apps for traffic fines, police clearance certificates, reporting crimes, and other police-related services.
# Law enforcement and public safety services including traffic management, crime prevention, emergency response, and digital police services such as fine payment, clearance certificates, and crime reporting.
#
#
# 60
# The Ministry of Interior (MOI) of the United Arab Emirates is a federal government entity responsible for providing security, safety, and civil services. Established with the formation of the UAE federation in 1971, the ministry oversees various aspects of internal security, law enforcement, civil defense, and public services.
# Government security and civil services administration encompassing internal security operations, law enforcement management, civil defense coordination, and public service delivery.
#
#
# 61
# ...
#
#
# 249
# Official U.S. passport services including new passport applications, renewals, expedited service, and passport cards. Services include routine processing (4-6 weeks) and expedited processing (2-3 weeks) options. The agency provides comprehensive passport services for U.S. citizens including first-time applications, renewals, children's passports, and emergency passport services.
# Passport processing services including new applications, renewals, expedited processing, and emergency services for various passport types and documentation needs.
#
#
# 250
# The Department of Foreign Affairs (DFA) is a government agency providing various consular services including passport issuance, authentication, visa services, and consular records. They also handle diplomatic relations, protect overseas Filipino workers, and promote economic diplomacy. The DFA focuses on three fundamental pillars: preservation of national security, promotion of economic security, and protection of Filipino rights overseas.
# Comprehensive consular and diplomatic services encompassing passport issuance, document authentication, visa processing, and management of consular records. Additional services include diplomatic relations management, overseas citizen protection, and economic diplomacy initiatives focused on national security and economic development.
#
#
# 251
# The Passport Seva division under the Ministry of External Affairs, Government of India provides comprehensive passport services including new passport applications, renewals, and other related services. They operate through a network of Passport Seva Kendras (PSKs) and Post Office Passport Seva Kendras (POPSKs) across India.
# Comprehensive passport services including processing of new passport applications, renewals, and related documentation services. Services are delivered through a network of dedicated passport processing centers and auxiliary facilities.
#
#
# 252
# The General Security (GS) is a Lebanese government agency that provides various security and administrative services including passport issuance, visa services, residency permits, and border control. They handle immigration matters, artist work permits, and various security functions across Lebanon.
# Integrated security and administrative services covering passport issuance, visa processing, residency permit management, and border control operations. Services include immigration processing, specialized work permit issuance, and general security administration.
#
#
# 253
# The Department of Foreign Affairs (DFA) provides essential consular services including passport issuance, authentication, visa services, and consular records management. The department handles passport applications, renewals, and other related services through its consular offices. They also provide assistance to overseas Filipinos and handle diplomatic relations.
# Essential consular services comprising passport issuance, document authentication, visa processing, and consular records management. Services include handling passport applications, renewals, overseas citizen assistance, and diplomatic relations management.
#
#
# 254
# The U.S. Department of State provides essential government services including passport services, visa services, emergency assistance abroad, and handles international parental child abduction cases. They offer both routine and emergency passport processing, visa application support through the National Visa Center, and 24/7 emergency assistance for U.S. citizens abroad through their worldwide embassy network.
# Comprehensive government and consular services including passport processing (both routine and emergency), visa application support, overseas emergency assistance, and handling of international parental child abduction cases. Services include 24/7 emergency support through a global embassy network.
#
#
# 255
# befree provides comprehensive outsourcing services for accounting firms and finance professionals in the UK. Their services include bookkeeping, payroll, tax preparation, audit support, virtual practice administration, and finance transformation. They focus on boosting workflow efficiency, reducing overheads, and enhancing client satisfaction through customized outsourcing solutions. The company offers access to expert accountants, bookkeepers, and tax consultants 24/7 while helping clients reduce operational costs by up to 50%.
# Professional financial and accounting outsourcing services encompassing bookkeeping, payroll processing, tax preparation, audit support, practice administration, and finance transformation solutions. The services include access to accounting professionals and consultants for comprehensive financial management and operational efficiency.
#
#
# 256
# Motorola Solutions builds and connects technologies to help protect people, property and places. They provide comprehensive safety and security ecosystem solutions including critical communications, command center software, video security systems, and managed support services. Their technology portfolio includes rugged radio devices, unified command center software, AI-powered video security, and cybersecurity services designed to work together to strengthen safety across industries.
# Integrated safety and security technology solutions comprising critical communications systems, command center software, video surveillance systems, and managed security services. The service includes advanced communication devices, unified control center platforms, AI-enhanced video security, and cybersecurity protection services.
#
#
# 257
# Xylem is a leading global water technology company committed to solving critical water and infrastructure challenges with innovation. The company provides a full spectrum of innovative solutions including analytical instruments, communications systems, pumps, treatment products, and digital solutions for water and wastewater applications.
# Water technology and infrastructure solutions including analytical instrumentation, communication systems, pumping equipment, water treatment products, and digital water management solutions. The service covers comprehensive water and wastewater treatment applications with innovative technological solutions.
#
#
# 258
# Softtek is a global software engineering partner providing IT services and digital solutions. For over 40 years, they have helped clients build, implement and run technology that improves lives. As the originators of nearshore, Softtek brings innovation closer to business strategy. Their services include digital solutions, application services, cloud & DevOps, data & automation, and platform services across various industries.
# Software engineering and IT services encompassing digital solution development, application services, cloud computing and DevOps implementation, data management and automation, and platform services. The service provides comprehensive technology solutions for business process improvement and digital transformation.
#
#
# 259
# The Vanuatu Financial Services Commission (VFSC) provides company registration and regulatory services in Vanuatu. They handle the registration of various types of companies, business names, and charitable associations. The commission oversees compliance with relevant legislation and regulations.
# Company registration and regulatory compliance services including business name registration, company incorporation, and charitable organization registration. The service includes oversight and enforcement of regulatory compliance for registered entities.
#
#
# 260
# The Securities and Exchange Commission of Pakistan (SECP) is a regulatory authority established under the Securities and Exchange Commission of Pakistan Act, 1997, becoming operational in 1999. SECP provides comprehensive regulatory and supervisory services for Pakistan's corporate sector and financial markets, including regulation of corporate sector and capital market, supervision of insurance companies, oversight of non-banking finance companies and private pensions schemes, and supervision of various external service providers to the corporate and financial sectors.
# Regulatory and supervisory services for corporate sector and financial markets, encompassing oversight of capital markets, insurance companies, non-banking finance companies, private pension schemes, and external service providers to corporate and financial sectors.
#
#
# 261
# The Ministry of Commerce of Cambodia provides online business registration services through an automated system. The service includes company registration, partnership registration, sole proprietorship registration, name reservation, document verification, and other business-related services.
# Online business registration services through an automated system, including entity registration for companies, partnerships, and sole proprietorships, along with name reservation, document verification, and related business services.
#
#
# 262
# Mazzucco & Company CPAs provides comprehensive new business formation services including setup of small businesses, large businesses, LLCs, companies, corporations, partnerships, and non-profits. Their knowledgeable and experienced staff reviews projected business plans and determines the best course of action to minimize tax liability and offer protection of assets.
# Business formation services covering establishment of various entity types including small and large businesses, LLCs, corporations, partnerships, and non-profits, with business plan review, tax liability assessment, and asset protection advisory.
#
#
# 263
# Accura Indonesia provides comprehensive legal support and company formation services tailored for both local and foreign investors establishing businesses in Indonesia. Services include Foreign-Owned Company (PT PMA) Formation, Local-Owned Company (PT) Formation, Representative Office (KPPA) Formation, Amendments to Company Structure & Ownership, and Closing of Company (Dissolution). The company ensures seamless and legally compliant business setup in Indonesia.
# Legal support and company formation services for business establishment, including formation of various business entities, structural amendments, ownership changes, and company dissolution services, with focus on legal compliance.
#
#
# 264
# Finmaas is a leading business setup consultancy in Dubai, providing comprehensive corporate solutions including business setup services, banking solutions, and corporate services across UAE and international jurisdictions. They specialize in mainland, freezone, and offshore company formation, along with additional services like accounting, tax consultancy, PRO services, and banking assistance. With over 15,000 successful clients from 164+ countries, they offer tailored solutions for startups, SMEs, corporates, and multinational organizations.
# Comprehensive business setup and corporate solutions including company formation services for various jurisdictions, banking solutions, accounting services, tax consultancy, and corporate support services for businesses of all sizes.
#
#
# 265
# iConsult provides comprehensive corporate services including company formation, accounting, tax advisory, and business solutions in Dubai. Their services span offshore company registration, UAE company formation, accounting & bookkeeping, HR & payroll, and visa & residency services. Operating since 1974, they offer white-glove company formation services and enterprise-grade solutions that can be customized to specific client needs to ensure maximum ROI.
# Corporate services encompassing business formation, accounting, tax advisory, and comprehensive business solutions. Services include company registration, accounting and bookkeeping, human resources management, payroll processing, and immigration services. Offers customizable business formation and enterprise solutions tailored to client requirements.
#
#
# 266
# CACEIS is a leading asset servicing bank that provides execution, clearing, custody, depositary and fund administration services. The company offers comprehensive solutions including private equity real estate services (PERES), asset servicing solutions, and web portal access through OLIS platform.
# Asset servicing and banking services providing execution, clearing, custody, depositary and fund administration. Comprehensive solutions include private equity real estate services, asset servicing, and digital platform access for portfolio management.
#
#
# 267
# WSP is one of the world's leading professional services firms, combining engineering, advisory and scientific expertise to create positive impact. They imagine future solutions and implement them through technical know-how and innovation. The company provides sustainable solutions across multiple sectors including buildings & property, transport & infrastructure, environment & sustainability, energy & resources, and industry.
# Professional engineering and advisory services combining technical and scientific expertise. Provides sustainable solutions across sectors including buildings and property, transportation infrastructure, environmental services, energy and resources, and industrial applications. Services focus on innovative technical solutions and implementation.
#
#
# 268
# FTI Consulting's digital transformation services focus on driving concrete business outcomes by aligning business objectives with technological capabilities. They specialize in implementing digital solutions with strict governance and resource management to deliver tangible, sustainable results. Their approach combines data, AI and customized digital solutions to deliver revenue growth, cost optimization, valuation growth, and enhanced customer success. They help organizations overcome common challenges like budget overruns, stakeholder miscommunications, and resource constraints in digital transformation initiatives.
# Digital transformation services aligning business objectives with technological capabilities. Implementation of digital solutions with governance and resource management focus. Services combine data analytics, artificial intelligence, and customized digital solutions to achieve revenue growth, cost optimization, and enhanced customer success. Addresses digital transformation challenges including resource management and stakeholder communication.
#
#
# 269
# TechWaves helps Web3, AI & fintech companies grow through strategic PR, content, branding, reputation management & web development. They deliver real authority in 30-60 days with no paid placements or fluff. With 8+ years in tech experience, they offer comprehensive digital marketing services including PR, creative campaigns, B2B strategies, and global market expansion.
# Technology-focused marketing and development services including public relations, content creation, branding, reputation management, and web development. Comprehensive digital marketing services encompassing creative campaigns, B2B strategy development, and market expansion strategies, specifically tailored for technology sector companies.
#
#
# 270
# ARO is an award-winning IT Services and Solutions company providing customers with sustainable competitive advantages through world-class cloud technologies and first-class service. They offer comprehensive solutions across Cloud, Collaboration, Data Centre Services, and Sustainability, including Microsoft services, cyber security, unified communications, data center management, and sustainability consulting.
# Comprehensive IT services and solutions provider specializing in cloud technologies, collaboration tools, data center services, and sustainability solutions. Core offerings include cloud infrastructure management, cybersecurity services, unified communications systems, data center operations, and environmental sustainability consulting. Services encompass technical implementation, strategic planning, and ongoing management of enterprise IT infrastructure.

# %%
for i, general_service_description in enumerate(general_service_descriptions.general_service_description_output):
    await update_service_general_descriptions(general_service_description)
