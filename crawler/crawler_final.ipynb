# %%
import requests
import json
# from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from anthropic._exceptions import OverloadedError
import os
from pydantic import BaseModel
from typing import List, Dict, Any
from langchain_core.prompts import ChatPromptTemplate
import os
from bs4 import BeautifulSoup
import re
from bs4 import BeautifulSoup
import re
from pydantic import Field
# from __future__ import print_function
# from IPython.display import display
from typing import Optional
from utils import Country, ProviderType
import anthropic
# import traceback

llm_model = os.environ["LLM_VERSION"]

# search_starters = ["Digital Marketing Firm", "Tax Consultancy Firm", "Cybersecurity Firm", "Legal Services Provider", "Healthcare Consultancy"]

# search_starters = ["Company formation service UAE", "Business formation service MENA", "Business registration services Gulf", "Business setup services Dubai", "Investment migration services UAE", "Second passport services", "Citizenship By investment", "economic passport services", "Golden Visa services", "Tax services UAE", "Tax Consultancy Firm Dubai", "Tax Calculation Services Dubai"]

class ResultRelevance(BaseModel):
    explanation: str = Field(description="Be extremely brief and concise with your explanation.")
    link: str

class RelevanceCheckOutput(BaseModel):
    most_relevant_result: ResultRelevance

class SqlCommand(BaseModel):
    command: str


class ServiceProviderMemberDetails(BaseModel):
    name: str = Field(description="Very important. Find the name of the staff member from the CLEAN HTML content.")
    role_description: str = Field(description="Find the role description of the staff member from the CLEAN HTML content.")
    telephone: str = Field(description="Find the telephone number of the staff member from the CLEAN HTML content.")
    mobile: str = Field(description="Find the mobile number of the staff member from the CLEAN HTML content.")
    email: str = Field(description="Find the email address of the staff member from the CLEAN HTML content.")
    linkedin: Optional[str]
    facebook: Optional[str]
    instagram: Optional[str]
    twitter: Optional[str]
    additional_info: Optional[str]

class ServiceProviderOutput(BaseModel):
    service_title: Optional[str] = Field(description="Produce a suitable title for the service.")
    service_description: Optional[str] = Field(description="Do your due diligence on summarising the service description based on a holistic consideration of the scattered relevant service info throughout the entirety of the given CLEAN HTML content. Use a string, not a number. Null if unavailable.")
    rating_score: Optional[float] = Field(description="Must adhere to a rating standard out of 5. Must be a numeric rating score of type float. Use a number, not a string. Null if unavailable.")
    rating_description: Optional[str] = Field(description="Do your due diligence on summarising the rating description based on a holistic consideration of the scattered relevant rating info throughout the entirety of the given CLEAN HTML content. Use a string, not a number. Null if unavailable.")
    pricing: Optional[str]
    service_tags: List[str] = Field(description="Do your due diligence on summarising the service tags based on a holistic consideration of the scattered relevant service info throughout the entirety of the given CLEAN HTML content. Null if unavailable.")
    provider_type: ProviderType = Field("Company", description="ProviderType enum. Should be Company if the provider is a company or Agent if the provider is an agent.")
    # provider_type: ProviderType = Field(description="ProviderType enum. Should be Company if the provider is a company or Agent if the provider is an agent.")
    country: Optional[Country] = Field(description="Country enum.")
    name: Optional[str] = Field(description="Very important. Find the name of the company from the CLEAN HTML content.")
    vision: Optional[str] = Field(description="A brief summary of the company/firm's vision statement from the CLEAN HTML content.")
    logo: Optional[str] = Field(description="Find the absolute URL for the company logo from the CLEAN HTML content. Preferably in SVG format.")
    website: Optional[str] = Field(description="Very important. Must find the website link of the company from the HTML content or infer it from the base website link address. Null if unavailable.")
    linkedin: Optional[str] = Field(description="Null if unavailable.")
    facebook: Optional[str] = Field(description="Null if unavailable.")
    instagram: Optional[str] = Field(description="Null if unavailable.")
    telephones: List[str] = Field([], description="Mandatory. Must find at least one telephone number. Field must be a list of telephone numbers or empty list.")
    mobiles: List[str] = Field([], description="Mandatory. Must find at least one mobile number. Field must be a list of mobile numbers or empty list.")
    emails: List[str] = Field(
        [], description="Mandatory. Must find at least one email address of the company from the HTML content. Field must be a list of email addresses or empty list."
    )
    # emails: List[str] = Field(description="Very very important. Must find at least one email address of the company from the HTML content. Output must be a list of email addresses.")
    office_locations: Optional[str] = Field(description="Detailed address locations of the company offices eg. 123 Main St, City, Country, or description if address is not available. Null if unavailable.")
    key_individuals: Optional[str] = Field(description="Names and role descriptions of key people of the company. Null if unavailable.")
    representatives: Optional[str] = Field(description="Names and roles and contact details of representatives of the company. Null if unavailable.")
    # service_provider_member_details: Optional[List[ServiceProviderMemberDetails]]

class SearchTermOutput(BaseModel):
    search_term: str

class AboutUsOutput(BaseModel):
    about_us_link: Optional[List[str]]

def call_llm(model = "claude-3-5-sonnet-20241022", API_key = os.environ["ANTHROPIC_API_KEY"], prompt_template = None, input_dict = None, structured_output = None, temperature = 0):
    if prompt_template is None:
        raise ValueError("Prompt template is required")
    if input_dict is None:
        raise ValueError("Input dictionary is required")
    if structured_output is None:
        raise ValueError("Structured output is required")
    llm = ChatAnthropic(
        model=model,
        anthropic_api_key=API_key, temperature=temperature).with_structured_output(structured_output)
    llm_chain = prompt_template | llm
    llm_chain = llm_chain.with_retry(
        retry_if_exception_type=(OverloadedError,),
        wait_exponential_jitter=True,    
        stop_after_attempt=6
    )
    result = llm_chain.invoke(input_dict)
    return result

def search_serper(search_query):
    url = "https://google.serper.dev/search"
    
    payload = json.dumps({
        "q": search_query,
        "gl": "ae", 
        "num": 7,
        "tbs": "qdr:w"
    })

    headers = {
        'X-API-KEY': os.environ["SERPER_API_KEY"],
        'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload, timeout=(3,4))
    results = json.loads(response.text)
    results_list = results['organic']

    all_results = []
    for id, result in enumerate(results_list, 1):
        result_dict = {
            'title': result['title'],
            'link': result['link'],
            'snippet': result['snippet'],
            'search_term': search_query,
            'id': id
        }
        all_results.append(result_dict)
    return all_results

def load_prompt(prompt_name):
    with open(f"prompts/{prompt_name}.md", "r") as f:
        return f.read()



def check_search_relevance(search_term: str, search_results: Dict[str, Any]) -> RelevanceCheckOutput:
    prompt = load_prompt("relevance_check_one_link.md")
    
    prompt_template = ChatPromptTemplate.from_messages([
        ("system", prompt),
        ("human", f"Check relevance of search results to the given search term (but most importantly make sure it is the actual company's official website, not a search facilitator website or other service of that sort): {search_term}")
    ])
    
    return call_llm(prompt_template = prompt_template, input_dict = {"search_term": search_term, 'search_results': search_results}, structured_output = RelevanceCheckOutput, temperature=0)


def convert_html_to_markdown(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Headers
    for h in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']):
        level = int(h.name[1])
        h.replace_with('#' * level + ' ' + h.get_text() + '\n\n')
    
    # Links
    for a in soup.find_all('a'):
        href = a.get('href', '')
        text = a.get_text()
        if href and text:
            a.replace_with(f'[{text}]({href})')
    
    # Bold
    for b in soup.find_all(['b', 'strong']):
        b.replace_with(f'**{b.get_text()}**')
    
    # Italic
    for i in soup.find_all(['i', 'em']):
        i.replace_with(f'*{i.get_text()}*')
    
    # Lists
    for ul in soup.find_all('ul'):
        for li in ul.find_all('li'):
            li.replace_with(f'- {li.get_text()}\n')
    
    for ol in soup.find_all('ol'):
        for i, li in enumerate(ol.find_all('li'), 1):
            li.replace_with(f'{i}. {li.get_text()}\n')
    
    # Get text and clean up
    text = soup.get_text()
    
    # Remove excess whitespace/newlines
    text = re.sub(r'\n\s*\n', '\n\n', text)
    text = text.strip()
    
    return text

def scrape_and_save_markdown(relevant_results):
    markdown_contents = []
    for result in relevant_results:
        if 'link' in result:
            payload = {
                "api_key": os.environ["SCRAPING_API_KEY"], 
                "url": result['link'],
                "render_js": "true"
            }

            response = requests.get("https://scraping.narf.ai/api/v1/", params=payload)
            if response.status_code == 200:
                markdown_content = convert_html_to_markdown(response.content.decode())
                
                markdown_contents.append({
                    'url': result['link'],
                    'markdown': markdown_content,
                    'title': result.get('title', ''),
                    'id': result.get('id', '')
                })
            else:
                print(f"Failed to fetch {result['link']}: Status code {response.status_code}")

    print(f"Successfully downloaded and saved {len(markdown_contents)} pages as markdown")
    return markdown_contents




from scrapper import HtmlScraper
import tiktoken
import string
import secrets

import os
import django
import sys
from asgiref.sync import sync_to_async
from urllib.parse import urlparse
from django.core.validators import validate_email, URLValidator
from django.core.exceptions import ValidationError

sys.path.insert(0, '/home/mohammed/Desktop/tech_projects/growbal/growbal_django')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "growbal.settings")

django.setup()

from services.models import Service
from services.serializers import ServiceSerializer
from accounts.serializers import ServiceProviderProfileSerializer
from accounts.models import CustomUser, ServiceProviderProfile
from asgiref.sync import sync_to_async
# from django.db import transaction
from scraper.models import Scrape          # adjust import path as needed
from scraper.serializers import ScrapeSerializer
# from django.core.files import File

def validate_emails(email_list):
    valid_emails = []
    for email in email_list:
        try:
            validate_email(email)
            valid_emails.append(email)
        except ValidationError:
            error_message = f"Error validating email {email}"
            print(error_message)
            with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                log_file.write(error_message + "\n")
    return valid_emails


_url_validator = URLValidator()
def validate_url(raw_url: str | None) -> bool:
    if not raw_url:
        return False

    raw_url = raw_url.strip()
    if not urlparse(raw_url).scheme:
        raw_url = "http://" + raw_url

    try:
        _url_validator(raw_url)
        return True
    except ValidationError:
        return False


@sync_to_async
def get_or_create_user(name=None, email=None, username=None, password=None):
    user, created = CustomUser.objects.get_or_create_user(
        name=name,
        email=email,
        username=username,
        password=password
    )
    return user, created

@sync_to_async
def create_service(data):
    serializer = ServiceSerializer(data=data)
    if serializer.is_valid():
        service = serializer.save()
        return service
    else:
        error_message = f"Error validating service data {serializer.errors}"
        print(error_message)
        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
            log_file.write(error_message + "\n")

@sync_to_async
def create_service_provider_profile(data):
    serializer = ServiceProviderProfileSerializer(data=data)
    if serializer.is_valid():
        profile = serializer.save()
        return profile
    else:
        error_message = f"Error validating service provider profile data {serializer.errors}"
        print(error_message)
        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
            log_file.write(error_message + "\n")
        # raise ValueError(serializer.errors)

@sync_to_async
def create_scrape(data):
    serializer = ScrapeSerializer(data=data)
    if serializer.is_valid():
        scrape = serializer.save()
        return scrape
    else:
        error_message = f"Error validating scrape data {serializer.errors}"
        print(error_message)
        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
            log_file.write(error_message + "\n")
        # raise ValueError(serializer.errors)

@sync_to_async
def check_similar_scrapes(base_url):
    return Scrape.check_similar_base_url(base_url=base_url)

def generate_password(length=8):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ''.join(secrets.choice(characters) for _ in range(length))
    return password

# def count_tokens(text, model="gpt-4"):
#     encoding = tiktoken.encoding_for_model(model)
#     tokens = encoding.encode(text)
#     return len(tokens)

anthropic_client = anthropic.Anthropic()

def count_tokens(text, model="claude-3-5-sonnet-20241022", system_prompt=""):
    messages = [{"role": "user", "content": text}]
    
    response = anthropic_client.messages.count_tokens(
        model=model,
        system=system_prompt,
        messages=messages
    )

    return response.input_tokens

scraper = HtmlScraper(scraping_api_key=os.environ["SCRAPING_API_KEY"])

async def process_relevant_links(relevant_link, row_dict):
    if await check_similar_scrapes(relevant_link.link):
        return
    else:
        nav_html_list = []
        try:
                num_tokens_allowed = 38000
                max_page_tokens = 13000
                # min_page_num = 7
                i = 1
                clean_html_sum_links = []
                clean_html_sum = ""
                try:
                    nav_html_content_about = scraper.scrape_html_about(relevant_link.link)
                    if nav_html_content_about:
                        nav_html_list.append(nav_html_content_about)
                except Exception as e:
                    error_message = f"Error processing about page: {e}"
                    print(error_message)
                    with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                        log_file.write(error_message + "\n")

                try:
                    nav_html_content_contact = scraper.scrape_html_contact(relevant_link.link)
                    if nav_html_content_contact:
                        nav_html_list.append(nav_html_content_contact)
                except Exception as e:
                    error_message = f"Error processing contact page: {e}"
                    print(error_message)
                    with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                        log_file.write(error_message + "\n")

                try:
                    print("----------BASE PAGE----------")
                    print(relevant_link.link)
                    nav_html_content_base = scraper.scrape_html_base(relevant_link.link)
                    
                    clean_text, clean_html = scraper.clean_html_content(nav_html_content_base)
                    # scraper.save_html(clean_html, relevant_link.link)
                    if clean_html and (token_count := count_tokens(clean_html)) < max_page_tokens/2:
                        print(f"clean_html: {token_count} tokens")
                        print("approved")
                        clean_html_sum += f"CLEAN HTML PAGE {i}: ({relevant_link.link})\n\n"
                        clean_html_sum += clean_html + "\n\n"
                        clean_html_sum_links.append(relevant_link.link)
                    elif clean_text and (token_count := count_tokens(clean_text)) < max_page_tokens:
                        print(f"clean_text: {token_count} tokens")
                        print("approved")
                        clean_html_sum += f"ONLY TEXT FROM HTML PAGE {i}: ({relevant_link.link})\n\n"
                        clean_html_sum += clean_text + "\n\n"
                        clean_html_sum_links.append(relevant_link.link)
                    if nav_html_content_base:
                        nav_html_list.append(nav_html_content_base)
                except Exception as e:
                    error_message = f"Error processing base page: {e}"
                    print(error_message)
                    with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                        log_file.write(error_message + "\n")

                nav_links = []
                if len(nav_html_list) == 0 or not nav_html_list[0]: 
                    return
                for html_content in nav_html_list:
                    try:
                        nav_links.extend(scraper.get_nav_links(html_content))
                    except Exception as e:
                        error_message = f"Error processing nav links: {e}"
                        print(error_message)
                        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                            log_file.write(error_message + "\n")
                print("----------NAV LINKS----------")
                print(nav_links)
                nav_links_str = "\n".join([f"{title}: {link}" for title, link, _ in nav_links])

                prompt = load_prompt("generate_about_us_link")
                prompt_template = ChatPromptTemplate.from_messages([
                    ("system", prompt),
                    ("human", f'Filter "about us" page, contact us page, services page, team page, or any similar page.')
                ])
                

                result = call_llm(prompt_template = prompt_template, input_dict = {"nav_links": nav_links_str, "base_url": relevant_link.link}, structured_output = AboutUsOutput, temperature=0)
                print(len(result.about_us_link))
                print(result.about_us_link)
                print("\n")
                for i, link in enumerate(result.about_us_link):
                    if link in clean_html_sum_links:
                        continue
                    if clean_html_sum and count_tokens(clean_html_sum) >= num_tokens_allowed:
                        continue
                    try:
                        html_content = scraper.scrape_html_base(link)
                        clean_text, clean_html = scraper.clean_html_content(html_content)
                        
                        if clean_html: print(f"count_tokens(clean_html) {i} before approval: {count_tokens(clean_html)}")
                        else: print(f"not clean_text {i} before approval: {clean_html}")

                        if clean_html and (count_tokens(clean_html) < max_page_tokens and count_tokens(clean_html) < num_tokens_allowed - count_tokens(clean_html_sum) if clean_html_sum else 0):
                            clean_html_sum += f"CLEAN HTML PAGE {i}: ({link})\n\n"
                            clean_html_sum += clean_html + "\n\n"
                            clean_html_sum_links.append(link)
                            print(f"{i} approved {link}")
                        elif clean_html_sum and (token_count := count_tokens(clean_html_sum)) < num_tokens_allowed:
                            print(token_count)
                            clean_html_sum += f"ONLY TEXT FROM HTML PAGE {i}: ({link})\n\n"
                            clean_html_sum += clean_text + "\n\n"
                            clean_html_sum_links.append(link)
                            print(f"{i} approved {link}")
                        else:
                            break
                        i += 1
                    except Exception as e:
                        error_message = f"Error processing {link}: {e}"
                        print(error_message)
                        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                            log_file.write(error_message + "\n")
                
                if clean_html_sum: "PROPRIETARY DATA RECORD OF THE ORGANIZATION\n\n" + str(row_dict) + "\n\n" + clean_html_sum
                clean_html_sum = clean_html_sum[:int((num_tokens_allowed*4)/2)]
                if clean_html_sum != "":
                    prompt = load_prompt("generate_fields_with_email")
                    prompt_template = ChatPromptTemplate.from_messages([
                        ("system", prompt),
                        ("human", f"Generate fields from the given HTML content.")
                    ])
                    
                    result = call_llm(prompt_template = prompt_template, input_dict = {"html_content": clean_html_sum}, structured_output = ServiceProviderOutput, temperature=0)
                    if result.emails == None:
                        print("result.email is Null")
                        result.emails = []
                    if result.telephones == None:
                        print("result.telephones is Null")
                        result.telephones = []
                    if result.mobiles == None:
                        print("result.mobiles is Null")
                        result.mobiles = []
                    if result.logo:
                        result.logo = scraper.save_logo(result.logo)

                result.emails = validate_emails(result.emails)
                if hasattr(result, 'name') and result.name and result.name != "":
                    if hasattr(result, 'name') and result.name and result.name != "":
                        user = None
                        if validate_url(result.website):
                            profile = await ServiceProviderProfile.objects.aget(website=result.website)
                            if profile:
                                log_message = f"Profile already exists for this website: {result.website}"
                                print(log_message)
                                with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                                    log_file.write(log_message + "\n")
                                user = profile.user
                        
                        if not user and hasattr(result, 'emails') and result.emails and result.emails[0] != "":
                            print("creating user with name and email")
                            user_email = result.emails[0]
                            user_password = generate_password(8)
                            user, created = await get_or_create_user(name=result.name, email=user_email, username=user_email, password=user_password)
                            print("created user with email and name")
                        elif not user:
                            user_password = generate_password(8)
                            user, created = await get_or_create_user(name=result.name, password=user_password)
                            print("created user with name only")                        

                        if user:
                            # if not result.emails: result.emails = []
                            try:
                                profile = await ServiceProviderProfile.objects.aget(user_id=user.id)
                            except ServiceProviderProfile.DoesNotExist:
                                profile = None
                                error_message = f"Error profile does not exist!"
                                print(error_message)
                                with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                                    log_file.write(error_message + "\n")
                            except Exception as e:
                                profile = None
                                error_message = f"Error getting profile: {e}"
                                print(error_message)
                                with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                                    log_file.write(error_message + "\n")
                            
                            if not created and profile:
                                data = {
                                    "provider_type": result.provider_type[:50] if result.provider_type else profile.provider_type,
                                    "country": result.country[:100] if result.country else profile.country,
                                    "session_status": profile.session_status,
                                    "name": result.name[:255] if result.name else profile.name,
                                    "vision": result.vision or profile.vision,
                                    "website": result.website if validate_url(result.website) else profile.website,
                                    "logo": result.logo or profile.logo,
                                    "linkedin": result.linkedin if validate_url(result.linkedin) else profile.linkedin,
                                    "facebook": result.facebook if validate_url(result.facebook) else profile.facebook,
                                    "instagram": result.instagram if validate_url(result.instagram) else profile.instagram,
                                    "telephones": [x[:30] for x in result.telephones] if result.telephones else profile.telephones,
                                    "mobiles": [x[:30] for x in result.mobiles] if result.mobiles else profile.mobiles,
                                    "emails": result.emails if result.emails else profile.emails,
                                    "office_locations": result.office_locations or profile.office_locations,
                                    "key_individuals": result.key_individuals or profile.key_individuals,
                                    "representatives": result.representatives or profile.representatives
                                }
                                saved_profile, created_profile = await ServiceProviderProfile.objects.aupdate_or_create(
                                    user_id=user.id,             # lookup part – must stay unique
                                    defaults=data            # values to update/insert
                                )   
                                print(f"Profile updated: {saved_profile.name}")
                            else:
                                data = {
                                    "user": user.username,
                                    "provider_type": result.provider_type[:50] if result.provider_type else None,
                                    "country": result.country[:100] if result.country else None,
                                    "session_status": "inactive",
                                    "name": result.name[:255] if result.name else None,
                                    "vision": result.vision,
                                    "website": result.website if validate_url(result.website) else None,
                                    "logo": result.logo,
                                    "linkedin": result.linkedin if validate_url(result.linkedin) else None,
                                    "facebook": result.facebook if validate_url(result.facebook) else None,
                                    "instagram": result.instagram if validate_url(result.instagram) else None,
                                    "telephones": [x[:30] for x in result.telephones] if result.telephones else [],
                                    "mobiles": [x[:30] for x in result.mobiles] if result.mobiles else [],
                                    "emails": result.emails,
                                    "office_locations": result.office_locations,
                                    "key_individuals": result.key_individuals,
                                    "representatives": result.representatives
                                }
                                saved_profile = await create_service_provider_profile(data)
                                print(f"Profile created: {saved_profile.name}")

                            service_data_json = {
                                "profile": saved_profile.id,
                                "service_title": result.service_title[:255] if result.service_title else None,
                                "service_description": result.service_description,
                                "service_tags": result.service_tags,
                                "rating_score": result.rating_score,
                                "rating_description": result.rating_description,
                                "pricing": result.pricing
                            }
                            # Direct async call (works in Jupyter/IPython):
                            saved_service = await create_service(service_data_json)
                            print(f"Service created: {saved_service.service_title}")
                            scrape_data = {
                                "base_url": relevant_link.link,
                                "provider": saved_profile.id,
                                "service": saved_service.id,
                                "cleaned_html": clean_html_sum
                            }
                            saved_scrape = await create_scrape(scrape_data)
                            print(f"Scrape created: {saved_scrape.base_url}")
        except Exception as e:
            # raise ValueError(e)
            error_message = f"Error processing {relevant_link.link}: {e}"
            print(error_message)
            with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                log_file.write(error_message + "\n")
                # traceback.print_exc(file=log_file)

import argparse
import asyncio
from dotenv import load_dotenv
import pandas as pd

async def main(env_path: str, search_starters: list[str]) -> None:
    load_dotenv(env_path)
    print(f"Loaded envs from {env_path}")

    with open(os.environ["LOG_FILE_PATH"], "w") as log_file:
        log_file.write("")

    df = pd.read_csv(os.environ["EMAIL_LIST_PATH"])
    df = df[['ORGANIZATION','INDUSTRY', 'WEBSITE', 'COUNTRY', 'CITY', 'FIRSTNAME', 'LASTNAME', 'EMAIL', 'LINKEDIN', 'DESIGNATION']]
    df['ORGANIZATION_COPY'] = df['ORGANIZATION']
    df = df.set_index('ORGANIZATION_COPY')
    df = df.dropna(axis=1, how='all')
    grouped = (
        df.groupby(df.index)
        .agg(lambda x: x.dropna().iloc[0] if x.notna().any() else None)
    )
    i = 1
    for organization, group in grouped.iterrows():
        log_message = f"Processing Entry {i}/{len(grouped)} Organization: {organization}"
        print(log_message)
        with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
            log_file.write(log_message + "\n")
        row_dict = group.to_dict()
        prompt = load_prompt("generate_a_search_term")
        prompt_template = ChatPromptTemplate.from_messages([
            ("system", prompt),
            ("human", f"Generate only one suitable google search term to fetch the official website of the company/service provider/orginization: {row_dict['ORGANIZATION']}")
        ])

        result = call_llm(prompt_template = prompt_template, input_dict = {"row_dict": row_dict}, structured_output = SearchTermOutput, temperature=0)

        try:
            print(f"Processing search term: {result.search_term}")
            links = search_serper(result.search_term)
            most_relevant_result = check_search_relevance(result.search_term, links).most_relevant_result
            if most_relevant_result:
                print(most_relevant_result)
                await process_relevant_links(most_relevant_result)
            else:
                log_message = f"No relevant link found for search term: {result.search_term}"
                print(log_message)
                with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                    log_file.write(log_message + "\n")
        except Exception as e:
            error_message = f"Error processing Entry {i}/{len(grouped)} Organization: {organization}: {e}"
            print(error_message)
            with open(os.environ["LOG_FILE_PATH"], "a") as log_file:
                log_file.write(error_message + "\n")
        i += 1
        # if i == 10:
        #     break

    

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Run the crawl with an .env file and services.")

#     parser.add_argument(
#         "env_path",
#         help="Path to the .env file (e.g., /home/user/.env)."
#     )

#     parser.add_argument(
#         "services_file",
#         help="Path to file containing service names, one per line."
#     )

#     args = parser.parse_args()

#     with open(args.services_file, 'r') as f:
#         industry_service_country_region_list = [line.strip() for line in f if line.strip()]

#     asyncio.run(main(args.env_path, industry_service_country_region_list))
# Out:
# usage: ipykernel_launcher.py [-h] env_path services_file
# ipykernel_launcher.py: error: the following arguments are required: env_path, services_file
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/mohammed/anaconda3/envs/growbal/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3678: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
import glob
import os
# from IPython.display import display
pd.set_option('display.max_rows', 50)

folder_path = '/home/mohammed/Desktop/tech_projects/growbal/email_lists'
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# Load all CSVs into DataFrames, assuming they all use ';' as separator
dfs = [pd.read_csv(f, sep=';') for f in csv_files]

# Concatenate all DataFrames (ignore index if you want a fresh one)
df = pd.concat(dfs, ignore_index=True)
output_path = '/home/mohammed/Desktop/tech_projects/growbal/email_lists/concat_email_lists.csv'
df.to_csv(output_path, index=False)

# %%
df = pd.read_csv('/home/mohammed/Desktop/tech_projects/growbal/email_lists/concat_email_lists.csv')
# print(df.columns)
print(len(df['ORGANIZATION'].isnull()) + len(df['ORGANIZATION']==""))
print(len(df['ORGANIZATION'].unique()))
df = df.dropna(axis=1, how='all')
print(df.columns)
df = df[['ORGANIZATION','INDUSTRY', 'WEBSITE', 'COUNTRY', 'CITY', 'FIRSTNAME', 'LASTNAME', 'EMAIL', 'LINKEDIN', 'DESIGNATION']]
df['ORGANIZATION_COPY'] = df['ORGANIZATION']
df = df.set_index('ORGANIZATION_COPY')
df = df.dropna(axis=1, how='all')
grouped = (
    df.groupby(df.index)
    .agg(lambda x: x.dropna().iloc[0] if x.notna().any() else None)
)

i = 0
for organization, group in grouped.iterrows():
    row_dict = group.to_dict()
    print(row_dict)
    i += 1
    # if i == 10:
    #     break

# Display DataFrame
display(df.head(5))
# Out:
# 2886
# 956
# Index(['CONTACT ID', 'EMAIL', 'LASTNAME', 'FIRSTNAME', 'SMS', 'DESIGNATION',
#        'ORGANIZATION', 'INDUSTRY', 'WEBSITE', 'COUNTRY', 'LINKEDIN', 'CITY',
#        'ADDED_TIME', 'MODIFIED_TIME'],
#       dtype='object')
# {'ORGANIZATION': '111 Legal Services Limited', 'INDUSTRY': None, 'WEBSITE': '111legal.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Tony', 'LASTNAME': 'Ebraheem', 'EMAIL': 'tony@111legal.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder & Owner'}
# {'ORGANIZATION': '360 Chartered Accountants', 'INDUSTRY': 'Accounting', 'WEBSITE': '360accountants.co.uk', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Leanne', 'LASTNAME': 'Steele', 'EMAIL': 'leanne@360accountants.co.uk', 'LINKEDIN': 'https://www.linkedin.com/in/leanne-steele-293a2996', 'DESIGNATION': 'Human Resources Director'}
# {'ORGANIZATION': '3E Accounting India', 'INDUSTRY': 'Accounting', 'WEBSITE': '3ecpa.co.in', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'info@3ecpa.co.in', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': '3YZ W.L.L (Formerly known as Almoayed Holdings W.L.L.)', 'INDUSTRY': None, 'WEBSITE': '3yz.com', 'COUNTRY': 'Bahrain', 'CITY': None, 'FIRSTNAME': 'Rana', 'LASTNAME': 'Sehil', 'EMAIL': 'rana.sehil@3yz.com', 'LINKEDIN': None, 'DESIGNATION': 'Senior Legal Associate'}
# {'ORGANIZATION': '91Travel and Immigration', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Hyderabad, Telangana, India', 'FIRSTNAME': 'Praveen', 'LASTNAME': 'Reddy', 'EMAIL': 'praveen@91travel.in', 'LINKEDIN': 'https://www.linkedin.com/in/praveen-reddy-690b81157/', 'DESIGNATION': 'Sales Director'}
# {'ORGANIZATION': 'A E Y Propoerties', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Anique Zaman', 'LASTNAME': None, 'EMAIL': 'admin@aey.ae', 'LINKEDIN': None, 'DESIGNATION': 'Marketing Manager'}
# {'ORGANIZATION': 'A K A Management Consultancy L.L.C', 'INDUSTRY': None, 'WEBSITE': 'http://www.aka.ae', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Faten Sulaiman Aljammal', 'LASTNAME': None, 'EMAIL': 'tax.agency@aka.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'A M A ACCOUNTING & BOOKKEEPING', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ahmad Mahmoud Ahmad Obaid', 'LASTNAME': None, 'EMAIL': 'obidco71@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'A S Agarwal & Co., Chartered Accountants', 'INDUSTRY': 'Accounting', 'WEBSITE': 'asagarwal.in', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'shruti@asagarwal.in', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'A T N-MAC ACCOUNTING & BOOK KEEPING', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Hamdy Abdelnasser Nasreldin Abouelnadar', 'LASTNAME': None, 'EMAIL': 'hamdynaser96@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'A V Immigration and Careers Consultancy Pvt Ltd (Apex Visas)', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Pune, Maharashtra, India', 'FIRSTNAME': 'Maninder', 'LASTNAME': 'Arora', 'EMAIL': 'maninder.arora@apexvisas.com', 'LINKEDIN': 'https://www.linkedin.com/in/maninderarora/', 'DESIGNATION': 'Director Of Operations'}
# {'ORGANIZATION': 'A&A Associate', 'INDUSTRY': None, 'WEBSITE': 'aaconsultancy.ae', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abdalla', 'LASTNAME': 'Elmahdi', 'EMAIL': 'abdalla@aaconsultancy.ae', 'LINKEDIN': None, 'DESIGNATION': 'Senior business setup adviser'}
# {'ORGANIZATION': 'A&H CONSULTANTS LLC', 'INDUSTRY': None, 'WEBSITE': 'anhconsultants.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Pradeep', 'LASTNAME': 'Kumar', 'EMAIL': 'pradeepk@anhconsultants.com', 'LINKEDIN': None, 'DESIGNATION': 'Partner'}
# {'ORGANIZATION': 'A&S TAX CONSULTANT (FZE)', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Sharjah', 'FIRSTNAME': 'Ahmed N N Ashour', 'LASTNAME': None, 'EMAIL': 'taxagencyands@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'A1 Properties', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Marjorie', 'LASTNAME': None, 'EMAIL': 'marjorie@a1properties.ae', 'LINKEDIN': None, 'DESIGNATION': 'Admin Assistant'}
# {'ORGANIZATION': 'AA Consultant', 'INDUSTRY': 'Accounting', 'WEBSITE': 'aaconsultant.com.pk', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'info@aaconsultant.com.pk', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AAA Associates Immigration', 'INDUSTRY': None, 'WEBSITE': 'aaa-international.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shama', 'LASTNAME': 'Sayed', 'EMAIL': 'shama@aaa-international.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Migration Consultant'}
# {'ORGANIZATION': 'AB CAPITAL SERVICES FZE', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Sharjah', 'FIRSTNAME': 'BHARAT BAJAJ RAJA RAM BAJAJ', 'LASTNAME': None, 'EMAIL': 'info@abcapital.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ABDUL MAJEED AL MARZOOQY AUDITING OFFICE - SOLE PROPRIETORSHIP L.L.C.', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Abdul Majeed Mohamed Ali Jasem Al Marzooqi', 'LASTNAME': None, 'EMAIL': 'amao2004@eim.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ACDORA DMCC', 'INDUSTRY': None, 'WEBSITE': 'acdora.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Farseen', 'LASTNAME': 'Ahammed P', 'EMAIL': 'farseen@acdora.com', 'LINKEDIN': None, 'DESIGNATION': 'Corporate Consultant'}
# {'ORGANIZATION': 'ACUVAT AUDITING', 'INDUSTRY': None, 'WEBSITE': 'acuvat.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Moiz', 'LASTNAME': 'Alamdar', 'EMAIL': 'moizalamdar@acuvat.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'AD Ports Group', 'INDUSTRY': None, 'WEBSITE': 'adportsgroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mohamed Bin Tannaf', 'LASTNAME': 'Al Menhali', 'EMAIL': 'mohamed.menhali@adportsgroup.com', 'LINKEDIN': None, 'DESIGNATION': 'Regional CEO- Africa -International Office'}
# {'ORGANIZATION': 'ADEPTS CHARTERED ACCOUNTANTS L.L.C.', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'ASHRAF Bakr BASSAS', 'LASTNAME': None, 'EMAIL': 'md@abcpa.sa', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ADGM', 'INDUSTRY': None, 'WEBSITE': 'adgm.com', 'COUNTRY': 'Abu Dhabi Emirate, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Bharath', 'LASTNAME': 'Shivappa', 'EMAIL': 'bharath.shivappa@adgm.com', 'LINKEDIN': None, 'DESIGNATION': 'Executive Vice President Business Development'}
# {'ORGANIZATION': 'AGL and Company Consulting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Linnet Lee', 'LASTNAME': None, 'EMAIL': 'linnet@aglcoconsulting.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AGRO FERT INTERNATIONAL TRADING FZ-LLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'United Arab Emirates', 'CITY': 'Dubai, United Arab Emirates', 'FIRSTNAME': 'Harshmeet', 'LASTNAME': 'Singh', 'EMAIL': 'harshmeet@agrofertintl.com', 'LINKEDIN': 'https://www.linkedin.com/in/harshmeet-singh-097b81125/', 'DESIGNATION': 'Fertilizer Trader and Operations Specialist'}
# {'ORGANIZATION': 'AHG - Chartered Accountants', 'INDUSTRY': None, 'WEBSITE': 'a-h-g.net', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Sonia', 'LASTNAME': 'Louati', 'EMAIL': 's.louati@a-h-g.net', 'LINKEDIN': None, 'DESIGNATION': 'Admin and CEO Assistant'}
# {'ORGANIZATION': 'AHL AL KHIBRA TAX CONSULTANCIES CO. L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ayman Fathy Abdelhafeez Elkady', 'LASTNAME': None, 'EMAIL': 'ayman.elkady73@hotmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AHMAD ALAGBARI CHARTERED ACCOUNTANT', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Shafiq Ur Rehman Muhammad Siddique Bhatti', 'LASTNAME': None, 'EMAIL': 'shafiqcpa@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AIMS Immigration & Relocation Specialist', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Viet Nam', 'CITY': 'Vietnam', 'FIRSTNAME': 'Daniel', 'LASTNAME': 'Lim', 'EMAIL': 'daniel@aims.sg', 'LINKEDIN': 'https://www.linkedin.com/in/daniel-lim-41549ab8/', 'DESIGNATION': 'Managing Director(Vietnam & Indonesia)'}
# {'ORGANIZATION': 'AIX Business Consultancy LLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Kim Maghanoy', 'LASTNAME': None, 'EMAIL': 'kim.maghanoy@aixconsultancy.ae', 'LINKEDIN': None, 'DESIGNATION': 'Administrative officer'}
# {'ORGANIZATION': 'AKM Global', 'INDUSTRY': 'Accounting', 'WEBSITE': 'akmglobal.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Amit', 'LASTNAME': 'Maheshwari', 'EMAIL': 'amit@akmglobal.com', 'LINKEDIN': 'https://www.linkedin.com/in/amit-maheshwari-a187267/', 'DESIGNATION': 'Transfer Pricing'}
# {'ORGANIZATION': 'AKT Associates', 'INDUSTRY': 'Accounting', 'WEBSITE': 'aktassociates.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Kavita', 'LASTNAME': 'Tiwari', 'EMAIL': 'cs@aktassociates.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL AMEEN TAX CONSULTANCY L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Sharjah', 'FIRSTNAME': 'tarek motaz zarkawi', 'LASTNAME': None, 'EMAIL': 'tarek118844@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL ARISH TAX CONSULTANCY', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Sharjah', 'FIRSTNAME': 'Mahmoud Osama Mahmoud Haroun Suliman', 'LASTNAME': None, 'EMAIL': 'mahmoud.osama9393@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL BISHARAH DOCUMENTS CLEARING AND TYPING LLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Mahammad Sadhiq Kaup Merra Hammabba', 'LASTNAME': None, 'EMAIL': 'm_sadhiq@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL Jern General Trading LLC - A Flex Group of Companies', 'INDUSTRY': None, 'WEBSITE': 'aljern.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Muhammed', 'LASTNAME': 'Ashraque', 'EMAIL': 'ashraque@aljern.com', 'LINKEDIN': None, 'DESIGNATION': 'Sales Executive'}
# {'ORGANIZATION': 'AL MOTAKAMELA TAX CONSULTANCY L.L.C.', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'ENAN HISHAM SHAKER ALBADAREEN', 'LASTNAME': None, 'EMAIL': 'anantax2018@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL TAMAYUZ ACCOUNTING & BOOKKEEPING', 'INDUSTRY': None, 'WEBSITE': 'http://www.tmzacc.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Bassam Ismaeil Zaher', 'LASTNAME': None, 'EMAIL': 'tax@tmzacc.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AL ZAROONI TUREVA TAX CONSULTANCY L.L.C', 'INDUSTRY': None, 'WEBSITE': 'http://www.alzaroonitureva.com/about.html', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ghassan S. M. Jamoos', 'LASTNAME': None, 'EMAIL': 'office@azt.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ALAHLAM TAX CONSULTANCY - L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Elsayed Samir Elsayed Ahmed Elmahmoudi', 'LASTNAME': None, 'EMAIL': 'sayed.elmahmoudi@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ALALEELI ACCOUNTING (S.P.S - L.L.C)', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Ajman', 'FIRSTNAME': 'Khalifa Saeed Salem Alfashti Alaleeli', 'LASTNAME': None, 'EMAIL': 'alalili3@hotmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ALBASSAM AUDITING AND TAX CONSULTANCY', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Khaled Ismaeil Elharbi Moustafa Ali', 'LASTNAME': None, 'EMAIL': 'acc.kh.elharby@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ALLIED ACCOUNTING & AUDITING (CHARTERED ACCOUNTANTS)', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Mohamed Galal Abdelmeguid', 'LASTNAME': None, 'EMAIL': 'moh.galal101@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ALNABAHA CONSULTANCIES', 'INDUSTRY': None, 'WEBSITE': 'alnabaha.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abdul', 'LASTNAME': 'Rasheed', 'EMAIL': 'rasheed@alnabaha.com', 'LINKEDIN': None, 'DESIGNATION': 'FTA Approved Tax Agent 056-4487925'}
# {'ORGANIZATION': 'ALNAJJAR AUDITING OF ACCOUNTS', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Asmaa Saeed M A El Najjar', 'LASTNAME': None, 'EMAIL': 'a.alnajjarauditing@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AMA Audit Tax Advisory', 'INDUSTRY': None, 'WEBSITE': 'amaaudit.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Monish', 'LASTNAME': 'Mohan', 'EMAIL': 'monish@amaaudit.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder & Managing Partner'}
# {'ORGANIZATION': 'AMCA', 'INDUSTRY': None, 'WEBSITE': 'amca.ae', 'COUNTRY': 'Dubai, Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mohammad', 'LASTNAME': 'Sharique', 'EMAIL': 'mohammad@amca.ae', 'LINKEDIN': None, 'DESIGNATION': 'Sr. Business Advisor'}
# {'ORGANIZATION': 'ARC ASSOCIATES', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Adil Amin Ahmed Mohamed Almulla', 'LASTNAME': None, 'EMAIL': 'adilalmulla@arcauditing.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ARC Associates - Approved Auditors in UAE', 'INDUSTRY': None, 'WEBSITE': 'arcauditing.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Adil', 'LASTNAME': 'Al Mulla (CEO/CVO/CPO)', 'EMAIL': 'adil@arcauditing.ae', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'ARDOR GLOBAL CONSULTANCY', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Amjad Samir Alghussein', 'LASTNAME': None, 'EMAIL': 'amjadtaxagent@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ARKAN ACCOUNTING', 'INDUSTRY': None, 'WEBSITE': 'http://www.arkanacc.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Mohamed Mahmoud Mahmoud Ahmed', 'LASTNAME': None, 'EMAIL': 'mohamed@arkanacc.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ARQ Group', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Malta', 'CITY': 'Malta', 'FIRSTNAME': 'Maria', 'LASTNAME': 'Falzon', 'EMAIL': 'mfalzon@arqgroup.com', 'LINKEDIN': 'https://www.linkedin.com/in/maria-falzon/', 'DESIGNATION': 'Senior Advisor for (U)HNWI Private Clients'}
# {'ORGANIZATION': 'ASTOLINKS INTERNATIONAL', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Ghana', 'CITY': 'Kumasi, Ashanti Region, Ghana', 'FIRSTNAME': 'Richard Obeng', 'LASTNAME': 'Assuming', 'EMAIL': 'assumingrichard@astolinks.net', 'LINKEDIN': 'https://www.linkedin.com/in/richard-obeng-assuming-58b8111a5/', 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'ATTO TAXATION PROCEDURES', 'INDUSTRY': None, 'WEBSITE': 'http://www.atto.ae', 'COUNTRY': None, 'CITY': 'Dubai, Abu Dhabi, UAQ', 'FIRSTNAME': 'Ahmed Abdelazim Salem', 'LASTNAME': None, 'EMAIL': 'info@atto.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AUDITAX ADVISORY TAX CONSULTANCY', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Tony Youssef Bou Aoun', 'LASTNAME': None, 'EMAIL': 'tonybouaoun@auditaxadvisory.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AUDITCO GOLD FOR TAX CONSULTANT L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'MOHAMED MUSTAFA SHAHIN', 'LASTNAME': None, 'EMAIL': 'taxagent.auditco@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AVS Immigration', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Delhi, India', 'FIRSTNAME': 'Bavleen', 'LASTNAME': 'Kaur', 'EMAIL': 'bavleen@avsimmigration.in', 'LINKEDIN': 'https://www.linkedin.com/in/bavleen-kaur-952305238/', 'DESIGNATION': 'Immigration Consultant'}
# {'ORGANIZATION': 'AX CAPITAL Real Estate', 'INDUSTRY': None, 'WEBSITE': 'axcapital.ae', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Polina', 'LASTNAME': 'Dikanskaya', 'EMAIL': 'polina@axcapital.ae', 'LINKEDIN': None, 'DESIGNATION': 'Business setup and visa specialist'}
# {'ORGANIZATION': 'AY Chartered Accountants', 'INDUSTRY': None, 'WEBSITE': 'ay-uae.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Balram', 'LASTNAME': 'Viswanathan', 'EMAIL': 'balramv@ay-uae.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'AZ Advisory Services L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Ibrahim Ali Morshed Alryahna', 'LASTNAME': None, 'EMAIL': 'iryahneh@az-advisory.co', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Abacus', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Pakistan', 'CITY': 'Lahore District, Punjab, Pakistan', 'FIRSTNAME': 'Sharoon', 'LASTNAME': 'John', 'EMAIL': 'sharoon.john@abacus-global.com', 'LINKEDIN': 'https://www.linkedin.com/in/sharoon-john-060737175/', 'DESIGNATION': 'Managing Consultant'}
# {'ORGANIZATION': 'Abdallah Al Qaydi Spa Auditing', 'INDUSTRY': None, 'WEBSITE': 'http://www.spaauditing.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Abdalla Ali Saif Ali Alqaydi', 'LASTNAME': None, 'EMAIL': 'gm@spaauditing.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Abdulla Al Marzooqi Chartered Accountants', 'INDUSTRY': None, 'WEBSITE': 'http://www.amcaauditing.com', 'COUNTRY': None, 'CITY': 'Abu Dhabi, Dubai', 'FIRSTNAME': 'Abdulla Ahmed Mohamed Abdulrahman Al Marzooqi', 'LASTNAME': None, 'EMAIL': 'abdulla@amcaauditing.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Abdulmannan Al Janahi Accounting And Tax Consultancy', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Abdulmannan Mohammad Saleh Abdulrahem A Aljanahi', 'LASTNAME': None, 'EMAIL': 'info@amajuae.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Abhinav Immigration Services Pvt. Ltd.', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Delhi, India', 'FIRSTNAME': 'Ajay', 'LASTNAME': 'Sharma', 'EMAIL': 'ajay@abhinav.com', 'LINKEDIN': 'https://www.linkedin.com/in/ajaysharma1962/', 'DESIGNATION': 'Author'}
# {'ORGANIZATION': 'Abode Options', 'INDUSTRY': None, 'WEBSITE': 'abodeoptions.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Jehan', 'LASTNAME': 'Bhat', 'EMAIL': 'jehan@abodeoptions.com', 'LINKEDIN': None, 'DESIGNATION': 'Principal Consultant'}
# {'ORGANIZATION': 'Abu Ghazaleh Intellectual Property', 'INDUSTRY': None, 'WEBSITE': 'agip.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Magda', 'LASTNAME': 'Malovrouva/Intellectual Property', 'EMAIL': 'mmalovrouva@agip.com', 'LINKEDIN': None, 'DESIGNATION': 'Intellectual Property Marketing Executive'}
# {'ORGANIZATION': 'Abwab Al Mustaqbal Taxation Procedures Follow Up', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Hassan Dawod', 'LASTNAME': None, 'EMAIL': 'sanoarabi@hotmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Accenture the Netherlands', 'INDUSTRY': None, 'WEBSITE': 'accenture.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Maurizio', 'LASTNAME': 'Vagnozzi', 'EMAIL': 'maurizio.vagnozzi@accenture.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director - Business Operations - Growth Markets'}
# {'ORGANIZATION': 'Account Plus Account Plus Management Consultancy F.Z.E', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Ajman', 'FIRSTNAME': 'Walid A A Radi', 'LASTNAME': None, 'EMAIL': 'walidradi24@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Accounting Drive', 'INDUSTRY': 'Accounting', 'WEBSITE': 'accountingdrive.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'hira@accountingdrive.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Accurate Immigration and Visa Consultants', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Mumbai, Maharashtra, India', 'FIRSTNAME': 'Amrinder', 'LASTNAME': 'Kaur', 'EMAIL': 'amrinder@accurateimmigration.com', 'LINKEDIN': 'https://www.linkedin.com/in/amrinderkaurbuttar/', 'DESIGNATION': 'Chief Operations Officer'}
# {'ORGANIZATION': 'Ackah Business Immigration Law', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Canada', 'CITY': 'Canada', 'FIRSTNAME': 'Evelyn', 'LASTNAME': 'Ackah', 'EMAIL': 'eackah@ackahlaw.com', 'LINKEDIN': 'https://www.linkedin.com/in/evelynackah/', 'DESIGNATION': 'Founder and Managing Lawyer'}
# {'ORGANIZATION': 'Active Eda Taxation Procedures Follow Up', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Mohammad Tahsein Mahdawi', 'LASTNAME': None, 'EMAIL': 'mahdawi@outlook.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Acuvat', 'INDUSTRY': 'Accounting', 'WEBSITE': 'acuvat.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'inquiries@acuvat.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Ad Astra IRC', 'INDUSTRY': None, 'WEBSITE': 'adastrairc.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Sohail', 'LASTNAME': 'Ahmad', 'EMAIL': 'ahmad@adastrairc.com', 'LINKEDIN': None, 'DESIGNATION': 'Director'}
# {'ORGANIZATION': 'Adamjee Global Solutions', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Pakistan', 'CITY': 'Karachi Division, Sindh, Pakistan', 'FIRSTNAME': 'Asif', 'LASTNAME': 'Ali', 'EMAIL': 'asif.ali@adamjeeglobalsolutions.com', 'LINKEDIN': 'https://www.linkedin.com/in/asif-ali-81950124b/', 'DESIGNATION': 'Immigration Consultant'}
# {'ORGANIZATION': 'Adept Tax Consultancy And Organization Of Accounts', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Maher B A Swidan', 'LASTNAME': None, 'EMAIL': 'adept.tax.uae@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'AdeptBiz Consulting FZLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Shruti Ajmera', 'LASTNAME': None, 'EMAIL': 'adeptbiz.consulting@gmail.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Partner'}
# {'ORGANIZATION': 'Advantrus Consulting LLC', 'INDUSTRY': None, 'WEBSITE': 'advantrusfm.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Pieter', 'LASTNAME': 'Hayton', 'EMAIL': 'pieter@advantrusfm.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'Advent Management Consultancies', 'INDUSTRY': None, 'WEBSITE': 'adventmc.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Zahid', 'LASTNAME': 'Farooq', 'EMAIL': 'zahid.farooq@adventmc.com', 'LINKEDIN': None, 'DESIGNATION': 'Tax Partner'}
# {'ORGANIZATION': 'Advice House FZCO', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Ammar Zahid', 'LASTNAME': None, 'EMAIL': 'ammar.zahid@advicehouse.ae', 'LINKEDIN': None, 'DESIGNATION': 'Director'}
# {'ORGANIZATION': 'Afaq Accounting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ahmad M. Abdulkader Aldaher', 'LASTNAME': None, 'EMAIL': 'info@afaqacc.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Affiniax Partners', 'INDUSTRY': 'Accounting', 'WEBSITE': 'affiniax.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Yvonne', 'LASTNAME': 'Spiller', 'EMAIL': 'tanmay@affiniax.com', 'LINKEDIN': 'https://www.linkedin.com/in/yvonnedspiller', 'DESIGNATION': 'Director Of Risk'}
# {'ORGANIZATION': 'Agarwal Taxcon Pvt.Ltd.', 'INDUSTRY': 'Accounting', 'WEBSITE': 'agarwaltaxcon.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'incometax@agarwaltaxcon.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Ahmad Altayer Auditing And Tax Services', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ahmad Obaid Saif Ahmad Altayer', 'LASTNAME': None, 'EMAIL': 'ahmad.o.altayer@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Ajman Free Zone (AFZ)', 'INDUSTRY': None, 'WEBSITE': 'afz.ae', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Arbaz', 'LASTNAME': 'Sheikh', 'EMAIL': 'arbaz.sheikh@afz.ae', 'LINKEDIN': None, 'DESIGNATION': 'Channel Development Executive'}
# {'ORGANIZATION': 'Ajman Media City Free Zone', 'INDUSTRY': None, 'WEBSITE': 'amcfz.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abdalla', 'LASTNAME': 'Gohar', 'EMAIL': 'abdalla.gohar@amcfz.ae', 'LINKEDIN': None, 'DESIGNATION': 'Chief Financial Officer'}
# {'ORGANIZATION': 'Al Ameen Accounting & Tax', 'INDUSTRY': None, 'WEBSITE': 'http://www.alameenaccounting.ae', 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Islam Hafez Ibrahim Hafez Matar', 'LASTNAME': None, 'EMAIL': 'ameentax@alameenaccounting.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Arabiya Group | Business Setup', 'INDUSTRY': None, 'WEBSITE': 'alarabiya.business', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Camille', 'LASTNAME': 'H', 'EMAIL': 'hcamille@alarabiya.business', 'LINKEDIN': None, 'DESIGNATION': 'Office Manager'}
# {'ORGANIZATION': 'Al Firas General Contracting', 'INDUSTRY': None, 'WEBSITE': 'alfiras.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Firas', 'LASTNAME': 'Mashal', 'EMAIL': 'firas.mashal@alfiras.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'Al Habtoor Group', 'INDUSTRY': None, 'WEBSITE': 'habtoor.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Gracie', 'LASTNAME': 'Beazon', 'EMAIL': 'gracie@habtoor.com', 'LINKEDIN': None, 'DESIGNATION': 'HR - Talent Acquisition'}
# {'ORGANIZATION': 'Al Jazeera Tax Consultant', 'INDUSTRY': None, 'WEBSITE': 'http://www.ae-vat.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'AHMED ABUALJIBIN NATIQ', 'LASTNAME': None, 'EMAIL': 'uaevatagent@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Maimana Accounting & Bookkeeping', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Mai Al Saghbini', 'LASTNAME': None, 'EMAIL': 'maisaghbini@almaimana.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Mayya Group', 'INDUSTRY': None, 'WEBSITE': 'almayyagroup.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Suliyman', 'LASTNAME': 'Halbouni', 'EMAIL': 'suliyman@almayyagroup.ae', 'LINKEDIN': None, 'DESIGNATION': 'CEO, COO & Board Member'}
# {'ORGANIZATION': 'Al Mirath Real Estates', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Mahammad Adil', 'LASTNAME': None, 'EMAIL': 'info@almirath.ae', 'LINKEDIN': None, 'DESIGNATION': 'Admin Executive'}
# {'ORGANIZATION': 'Al Mutakamel For General Accounting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Fujairah', 'FIRSTNAME': 'Amin Elmoghawry Elmetwally Elbastawisy', 'LASTNAME': None, 'EMAIL': 'ameenrona210@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Reef Group', 'INDUSTRY': None, 'WEBSITE': 'alreefgroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mounir', 'LASTNAME': 'Khater', 'EMAIL': 'mkhater@alreefgroup.com', 'LINKEDIN': None, 'DESIGNATION': 'President'}
# {'ORGANIZATION': 'Al Sudais CPA', 'INDUSTRY': 'Accounting', 'WEBSITE': 'alsudaiscpa.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Diya', 'LASTNAME': 'Alsaeed', 'EMAIL': 'diya.alsaeed@alsudaiscpa.com', 'LINKEDIN': 'https://www.linkedin.com/in/osamah-alsudais-cpa-socpa-cma-38a39619', 'DESIGNATION': 'Managing Partner'}
# {'ORGANIZATION': 'Al Tamimi & Company', 'INDUSTRY': None, 'WEBSITE': 'tamimi.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Sahid', 'LASTNAME': 'Daud', 'EMAIL': 'd.sahid@tamimi.com', 'LINKEDIN': None, 'DESIGNATION': 'Senior Tax Advisor'}
# {'ORGANIZATION': 'Al Theqa For Accounting & Tax Consultting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Fujairah', 'FIRSTNAME': 'Essam Eid Abdelaziz Mohamed', 'LASTNAME': None, 'EMAIL': 'essam_alsaher2002@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Watania Tax Consultant', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Mohamed Khadim Alhemeiri', 'LASTNAME': None, 'EMAIL': 'mkalhemeiri@alwatania.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Al Zarooni Tureva Auditing', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Hassan Mohamed Hassan Mohamed', 'LASTNAME': None, 'EMAIL': 'hassan.abdelaziz@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Albaddad1971', 'INDUSTRY': None, 'WEBSITE': 'albaddad.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Dr.', 'LASTNAME': 'Ahmed AbouAhmed', 'EMAIL': 'ahmed@albaddad.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Audit Executive'}
# {'ORGANIZATION': 'Albatross Immigration Consultants', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Qatar', 'CITY': 'Doha, Doha, Qatar', 'FIRSTNAME': 'Abe', 'LASTNAME': 'Agad', 'EMAIL': 'abe@albatross-ic.com', 'LINKEDIN': 'https://www.linkedin.com/in/abe-agad-b0a33526a/', 'DESIGNATION': 'Immigration Consultant'}
# {'ORGANIZATION': 'Alchemist Consultants', 'INDUSTRY': 'Accounting', 'WEBSITE': 'alchemistconsultants.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'info@alchemistconsultants.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Alhadif Setup', 'INDUSTRY': None, 'WEBSITE': 'alhadifsetup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Adel', 'LASTNAME': 'Ahmed', 'EMAIL': 'adel.ahmed@alhadifsetup.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'Alpadis', 'INDUSTRY': None, 'WEBSITE': 'alpadis.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Bob', 'LASTNAME': 'Natividad', 'EMAIL': 'bob.natividad@alpadis.com', 'LINKEDIN': None, 'DESIGNATION': 'Corporate Administrator'}
# {'ORGANIZATION': 'Alpha 360 Advisory L.L.C-FZ', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Nurgul Sultanova', 'LASTNAME': None, 'EMAIL': 'n.sultanova@alpha360advisory.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'Alphabets Group', 'INDUSTRY': None, 'WEBSITE': 'alphabetsgroup.ae', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mukaram', 'LASTNAME': 'Riaz', 'EMAIL': 'm.riaz@alphabetsgroup.ae', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'Alterf Services', 'INDUSTRY': 'Accounting', 'WEBSITE': 'alterfservices.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'info@alterfservices.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Amalabh Capital Limited', 'INDUSTRY': None, 'WEBSITE': 'amalabh.com', 'COUNTRY': 'Dubai, Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Jay', 'LASTNAME': 'V Jegannathan', 'EMAIL': 'jay@amalabh.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder & Executive Director'}
# {'ORGANIZATION': 'Amir Ismail & Associates (AIA) - Global Citizenship & Immigration Advisers', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Canada', 'CITY': 'Toronto, Ontario, Canada', 'FIRSTNAME': 'Fariha', 'LASTNAME': 'Amir', 'EMAIL': 'fariha@amirismail.com', 'LINKEDIN': 'https://www.linkedin.com/in/fariha-amir-078b8970/', 'DESIGNATION': 'Operations Manager'}
# {'ORGANIZATION': 'Ampcus Cyber - Zero Trust Compliance Security Provider', 'INDUSTRY': None, 'WEBSITE': 'ampcuscyber.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Pooja', 'LASTNAME': 'Singh', 'EMAIL': 'pooja.singh@ampcuscyber.com', 'LINKEDIN': None, 'DESIGNATION': 'Regional Manager'}
# {'ORGANIZATION': 'Anbac Advisors', 'INDUSTRY': 'Accounting', 'WEBSITE': 'anbacadvisors.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'office@anbacadvisors.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Anil K. Goyal & Associates', 'INDUSTRY': 'Accounting', 'WEBSITE': 'akgassociates.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Anil', 'LASTNAME': 'Goyal', 'EMAIL': 'anilgoyal@akgassociates.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Annaka Group', 'INDUSTRY': None, 'WEBSITE': 'annakagroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Satakshi', 'LASTNAME': 'Singh', 'EMAIL': 'satakshi@annakagroup.com', 'LINKEDIN': None, 'DESIGNATION': 'CEO & Founder'}
# {'ORGANIZATION': 'Antal International', 'INDUSTRY': None, 'WEBSITE': 'antal.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Salauddin', 'LASTNAME': 'J N صلاح الدين', 'EMAIL': 'sldyn@antal.com', 'LINKEDIN': None, 'DESIGNATION': 'Recruitment Specialist'}
# {'ORGANIZATION': 'Arab Center for Consultancy & Economic Studies', 'INDUSTRY': None, 'WEBSITE': 'drassat.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Atef', 'LASTNAME': 'Elromhe', 'EMAIL': 'atef@drassat.com', 'LINKEDIN': None, 'DESIGNATION': 'Acting CEO'}
# {'ORGANIZATION': 'Ardent Advisory Accounting', 'INDUSTRY': 'Accounting', 'WEBSITE': 'ardentadvisory.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Sharad', 'LASTNAME': 'Bhandari', 'EMAIL': 'sharadbhandari@ardentadvisory.com', 'LINKEDIN': 'https://www.linkedin.com/in/sharad-bhandari-a9b03a63', 'DESIGNATION': 'COO'}
# {'ORGANIZATION': 'Ardor Global Consultancy', 'INDUSTRY': None, 'WEBSITE': 'agconsultancy.ae', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mirsad', 'LASTNAME': 'Kk', 'EMAIL': 'mirsad@agconsultancy.ae', 'LINKEDIN': None, 'DESIGNATION': 'Accounting and UAE VAT'}
# {'ORGANIZATION': 'Ardub Intl Trading Company', 'INDUSTRY': None, 'WEBSITE': 'ardubinternationaltrading.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Analia', 'LASTNAME': 'Pichelli', 'EMAIL': 'a.pichelli@ardubinternationaltrading.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'Argentum Attestation FZ LLC', 'INDUSTRY': None, 'WEBSITE': 'argentum-llc.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Bilal', 'LASTNAME': 'Akhtar', 'EMAIL': 'bilal.akhtar@argentum-llc.com', 'LINKEDIN': None, 'DESIGNATION': 'Head of Public Relations - Visa and Attestation'}
# {'ORGANIZATION': 'Arise Immigration Consultant', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Ahmedabad, Gujarat, India', 'FIRSTNAME': 'Jaydev', 'LASTNAME': 'Bhitora', 'EMAIL': 'jaydev@ariseimmigrationconsultant.com', 'LINKEDIN': 'https://www.linkedin.com/in/jaydev-bhitora-153b168a/', 'DESIGNATION': 'Co-Founder'}
# {'ORGANIZATION': 'Arka', 'INDUSTRY': 'Accounting', 'WEBSITE': 'arka.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'support@arka.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Asalwan', 'INDUSTRY': 'Accounting', 'WEBSITE': 'asalwan.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'asa@asalwan.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Ascent Attestation Services', 'INDUSTRY': None, 'WEBSITE': 'ascentattestation.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shiju', 'LASTNAME': 'Parambayil', 'EMAIL': 'shiju@ascentattestation.com', 'LINKEDIN': None, 'DESIGNATION': 'Head of Sales and Marketing'}
# {'ORGANIZATION': 'Ascentia  UAE', 'INDUSTRY': None, 'WEBSITE': 'ascentiame.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shiju', 'LASTNAME': 'P', 'EMAIL': 'shiju@ascentiame.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder and CEO'}
# {'ORGANIZATION': 'Ask Kubeir Immigration', 'INDUSTRY': None, 'WEBSITE': 'askkubeir.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': 'Greater Toronto Area, Canada, Canada', 'FIRSTNAME': 'Monica Raj', 'LASTNAME': 'Kudari', 'EMAIL': 'monica@askkubeir.com', 'LINKEDIN': 'https://www.linkedin.com/in/askkubeir/', 'DESIGNATION': 'Business Manager'}
# {'ORGANIZATION': 'Askew CPA Consulting Firm, LLC', 'INDUSTRY': None, 'WEBSITE': 'askewcpafirm.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'elizabeth@askewcpafirm.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Atom Privé Financial Services', 'INDUSTRY': None, 'WEBSITE': 'atomprive.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Harsha', 'LASTNAME': 'Vardhana', 'EMAIL': 'harsha@atomprive.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder & Managing Director'}
# {'ORGANIZATION': 'Audiix Accounting And Bookkeeping', 'INDUSTRY': None, 'WEBSITE': 'http://www.audiix.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Elsir Khatib Badri Mohamed', 'LASTNAME': None, 'EMAIL': 'hello@audiix.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Aura Ventures', 'INDUSTRY': None, 'WEBSITE': 'auraventures.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shuaib', 'LASTNAME': 'S', 'EMAIL': 'shuaib@auraventures.ae', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'Aurega Group', 'INDUSTRY': None, 'WEBSITE': 'auregagroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Tony', 'LASTNAME': 'Chakhtoura', 'EMAIL': 'tony.chakhtoura@auregagroup.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Development Manager'}
# {'ORGANIZATION': 'Aurion Business Consultants', 'INDUSTRY': None, 'WEBSITE': 'dubaifreezonecompany.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Syam', 'LASTNAME': 'Prabhu', 'EMAIL': 'syam@dubaifreezonecompany.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder'}
# {'ORGANIZATION': 'Aussizz Group', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Ahmedabad, Gujarat, India', 'FIRSTNAME': 'Samiksha', 'LASTNAME': 'Jangid', 'EMAIL': 'samiksha@aussizzgroup.com', 'LINKEDIN': 'https://www.linkedin.com/in/samiksha-jangid-80196a243/', 'DESIGNATION': 'Canada Immigration Admin and Consultant'}
# {'ORGANIZATION': 'Avanceon Middle East & South Asia', 'INDUSTRY': None, 'WEBSITE': 'avanceon.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Bakhtiar', 'LASTNAME': 'Wain', 'EMAIL': 'bwain@avanceon.ae', 'LINKEDIN': None, 'DESIGNATION': 'Founder and CEO'}
# {'ORGANIZATION': 'Averyx Management Consultancies', 'INDUSTRY': None, 'WEBSITE': 'http://www.averyxgroup.com', 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Jadd Shalak', 'LASTNAME': None, 'EMAIL': 'jadd@averyxgroup.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Avyanco Business Setup Consultancy', 'INDUSTRY': None, 'WEBSITE': 'avyanco.com', 'COUNTRY': 'Dubai, Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Nikeeta', 'LASTNAME': 'Prajapati', 'EMAIL': 'nikeeta@avyanco.com', 'LINKEDIN': None, 'DESIGNATION': 'Human Resources Officer'}
# {'ORGANIZATION': 'Axiom Mark Intellectual Property', 'INDUSTRY': None, 'WEBSITE': 'axiom-mark.com', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Gigy', 'LASTNAME': 'Antony', 'EMAIL': 'gigy@axiom-mark.com', 'LINKEDIN': None, 'DESIGNATION': 'Senior Business Setup  Consultant'}
# {'ORGANIZATION': 'Az Advisory Services L.L.C', 'INDUSTRY': None, 'WEBSITE': 'http://www.az-advisory.co/', 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Yazan Mohsen Nemer Alsaqer', 'LASTNAME': None, 'EMAIL': 'aztaxagency@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BBNC', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bbnc.in', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'info@bbnc.in', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BC Shetty & Co', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bcshettyco.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'dinesh@bcshettyco.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BDO Dr. Mohamed Al-Amri & Co.', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bdoalamri.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Zeeshan', 'LASTNAME': 'Shahid', 'EMAIL': 'z.shahid@bdoalamri.com', 'LINKEDIN': 'https://www.linkedin.com/in/zeeshan80', 'DESIGNATION': 'VAT Manager'}
# {'ORGANIZATION': 'BDO Pakistan', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bdo.com.pk', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Qasim', 'LASTNAME': 'Causer', 'EMAIL': 'qcauser@bdo.com.pk', 'LINKEDIN': 'https://www.linkedin.com/in/qasim-causer-879b2428', 'DESIGNATION': 'Chairman'}
# {'ORGANIZATION': 'BDO UAE', 'INDUSTRY': None, 'WEBSITE': 'bdo.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Afzal', 'LASTNAME': 'Koya', 'EMAIL': 'afzal.koya@bdo.ae', 'LINKEDIN': None, 'DESIGNATION': 'Partner'}
# {'ORGANIZATION': 'BDO in India', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bdo.in', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Tejas', 'LASTNAME': 'Vora', 'EMAIL': 'tejasvora@bdo.in', 'LINKEDIN': 'https://www.linkedin.com/in/tejas-vora-4719ab19', 'DESIGNATION': 'Associate Partner'}
# {'ORGANIZATION': 'BFM Enterprises LLC', 'INDUSTRY': None, 'WEBSITE': 'bfmdxb.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Jaber', 'LASTNAME': 'Albehandy', 'EMAIL': 'jaber@bfmdxb.com', 'LINKEDIN': None, 'DESIGNATION': 'Chairman'}
# {'ORGANIZATION': 'BI WORLDWIDE', 'INDUSTRY': None, 'WEBSITE': 'biworldwide.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Mohamed', 'LASTNAME': 'Nabil', 'EMAIL': 'mohamed.nabil@biworldwide.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Financial Officer'}
# {'ORGANIZATION': 'BOOK WORKS CONSULTANCY L.L.C.', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'HAZEM KHALIL ELHAJ KHALIL', 'LASTNAME': None, 'EMAIL': 'managment_z@hotmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BRIGHT UNIVERSE (ACCOUNTING & TAXES) L.L.C', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Abu Dhabi', 'FIRSTNAME': 'Waseem Mohd Hashem Mustafa Jaber', 'LASTNAME': None, 'EMAIL': 'wasim.jabr@brightuniverse.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BSI', 'INDUSTRY': None, 'WEBSITE': 'bsigroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Ahlame', 'LASTNAME': 'M.', 'EMAIL': 'am@bsigroup.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Development Manager'}
# {'ORGANIZATION': 'BSP HUB LLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Sumaira Malik', 'LASTNAME': None, 'EMAIL': 'info@bsp-hub.com', 'LINKEDIN': None, 'DESIGNATION': 'ADMIN OFFICER'}
# {'ORGANIZATION': 'BUSINESS TECHNOLOGY CONSULTING (www.btc-me.com)', 'INDUSTRY': 'Accounting', 'WEBSITE': 'btc-me.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'khurram@btc-me.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BVS Global', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'United Arab Emirates', 'CITY': 'Dubai, United Arab Emirates', 'FIRSTNAME': 'Nisha', 'LASTNAME': 'Diana', 'EMAIL': 'diana@bvsglobal.com', 'LINKEDIN': 'https://www.linkedin.com/in/nisha-diana-b33163176/', 'DESIGNATION': 'Global Visa Advisor'}
# {'ORGANIZATION': "BYJU'S", 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'United Arab Emirates', 'CITY': 'Dubai, United Arab Emirates', 'FIRSTNAME': 'Srishti', 'LASTNAME': 'Pandey', 'EMAIL': 'srishti.pandey@byjus.com', 'LINKEDIN': 'https://www.linkedin.com/in/srishti-pandey-447956269/', 'DESIGNATION': 'Business Development Associate'}
# {'ORGANIZATION': 'Bait Alkhebra Management Consulting & Accounting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Nagy Mohammed Ibrahim Youssef', 'LASTNAME': None, 'EMAIL': '1449911@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Baker McKenzie', 'INDUSTRY': None, 'WEBSITE': 'bakermckenzie.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Tim', 'LASTNAME': 'Meredith', 'EMAIL': 'tim.meredith@bakermckenzie.com', 'LINKEDIN': None, 'DESIGNATION': 'Director of Business Development and Marketing'}
# {'ORGANIZATION': 'Baker Tilly Middle East', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bakertillyjfc.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Salman', 'LASTNAME': 'Sajid', 'EMAIL': 'salman@bakertillyjfc.com', 'LINKEDIN': 'https://www.linkedin.com/in/aakriti-mago-a5845540', 'DESIGNATION': 'Executive Director'}
# {'ORGANIZATION': 'Baker Tilly Pakistan', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bakertilly.pk', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Qamar', 'LASTNAME': 'Rashid', 'EMAIL': 'qamarrashid@bakertilly.pk', 'LINKEDIN': None, 'DESIGNATION': 'Business Advisory Services'}
# {'ORGANIZATION': 'Banke International Properties LLC', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Musty Dhenkar', 'LASTNAME': None, 'EMAIL': 'mustufa@banke.ae', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Batley Law', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Pakistan', 'CITY': 'Islāmābād, Pakistan', 'FIRSTNAME': 'Shireen', 'LASTNAME': 'Jamal', 'EMAIL': 'shireen@batleylaw.co.uk', 'LINKEDIN': 'https://www.linkedin.com/in/shireen-jamal-98b27923a/', 'DESIGNATION': 'Immigration Paralegal'}
# {'ORGANIZATION': 'Bayat Legal Services', 'INDUSTRY': None, 'WEBSITE': 'bayatgroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Erick', 'LASTNAME': 'Ramirez', 'EMAIL': 'erick.ramirez@bayatgroup.com', 'LINKEDIN': None, 'DESIGNATION': 'Legal Assistant / Case Processing'}
# {'ORGANIZATION': 'Bazaar Accounting & Management Advisors LLC', 'INDUSTRY': None, 'WEBSITE': 'bazaaraccounting.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Atul', 'LASTNAME': 'Varma', 'EMAIL': 'atul@bazaaraccounting.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'Becker Advisors Accounting & Taxation Procedures', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Muhanned Anbari', 'LASTNAME': None, 'EMAIL': 'anbari.muhanned@gmail.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Best Folio Consulting And Accounting', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Dubai', 'FIRSTNAME': 'Ahmad Musa Salameh Alswaiti', 'LASTNAME': None, 'EMAIL': 'ahmed.alswaiti@bestfolio.net', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'Best Solution', 'INDUSTRY': None, 'WEBSITE': 'best-solution.ae', 'COUNTRY': 'Dubai, Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abdulla', 'LASTNAME': 'Al Harthi', 'EMAIL': 'abdulla@best-solution.ae', 'LINKEDIN': None, 'DESIGNATION': 'General Manager'}
# {'ORGANIZATION': 'Bhuta Shah & Co', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bhutashah.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Pawan', 'LASTNAME': 'Pareek', 'EMAIL': 'pawan.pareek@bhutashah.com', 'LINKEDIN': 'https://www.linkedin.com/in/harsh-bhuta-0545852a', 'DESIGNATION': 'Partner'}
# {'ORGANIZATION': 'Big Bracket UAE', 'INDUSTRY': 'Accounting', 'WEBSITE': 'bigbracketuae.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': None, 'LASTNAME': None, 'EMAIL': 'solutions@bigbracketuae.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'BinHimyar Law Group', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Canada', 'CITY': 'Vancouver, British Columbia, Canada', 'FIRSTNAME': 'Miguel', 'LASTNAME': 'Martins', 'EMAIL': 'miguel@himyarlaw.com', 'LINKEDIN': 'https://www.linkedin.com/in/miguel-martins-pereirinha-604401104/', 'DESIGNATION': 'Immigration Lawyer'}
# ...
# {'ORGANIZATION': 'ZK Sports & Entertainment', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'United Arab Emirates', 'CITY': 'United Arab Emirates', 'FIRSTNAME': 'Jennifer', 'LASTNAME': 'Connell', 'EMAIL': 'jennifer@zk-sports.com', 'LINKEDIN': 'https://www.linkedin.com/in/jennylynoconnell/', 'DESIGNATION': 'Client Relations & Operations Director'}
# {'ORGANIZATION': 'al bastaki business services uae', 'INDUSTRY': None, 'WEBSITE': 'albastakiuae.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Farhad', 'LASTNAME': 'Chikliwala', 'EMAIL': 'farhad@albastakiuae.com', 'LINKEDIN': None, 'DESIGNATION': 'Strategic Communications Manager'}
# {'ORGANIZATION': 'alama intellectual property', 'INDUSTRY': None, 'WEBSITE': 'alamaip.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Fatima', 'LASTNAME': 'Mohamed', 'EMAIL': 'fatima@alamaip.com', 'LINKEDIN': None, 'DESIGNATION': 'General Manager'}
# {'ORGANIZATION': 'bizbridged', 'INDUSTRY': None, 'WEBSITE': 'bizbridged.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Awad', 'LASTNAME': 'Makkawi', 'EMAIL': 'awad@bizbridged.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder'}
# {'ORGANIZATION': 'bluemena, a BlueWorld company.', 'INDUSTRY': None, 'WEBSITE': 'blueworld.ai', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Riadh', 'LASTNAME': 'Boukhris', 'EMAIL': 'riadh.boukhris@blueworld.ai', 'LINKEDIN': None, 'DESIGNATION': 'Founder & CEO'}
# {'ORGANIZATION': 'can-able immigration consultants', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'India', 'CITY': 'Ludhiana, Punjab, India', 'FIRSTNAME': 'Khilandeep', 'LASTNAME': 'Kharbanda', 'EMAIL': 'khilandeep@can-able.com', 'LINKEDIN': 'https://www.linkedin.com/in/khilandeep-kharbanda/', 'DESIGNATION': 'CEO & Marketing Head'}
# {'ORGANIZATION': 'cellutech fze (previously known - express mobile) & tech bay electronics', 'INDUSTRY': None, 'WEBSITE': 'techtronicsdubai.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'muhammad', 'LASTNAME': 'mahad', 'EMAIL': 'mahad@techtronicsdubai.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Development Manager'}
# {'ORGANIZATION': 'clip law', 'INDUSTRY': None, 'WEBSITE': 'clip-law.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shuggufta', 'LASTNAME': 'Khokhar', 'EMAIL': 'shuggufta.khokhar@clip-law.com', 'LINKEDIN': None, 'DESIGNATION': 'Partner and Co Founder'}
# {'ORGANIZATION': 'customer experience group', 'INDUSTRY': None, 'WEBSITE': 'customerexperiencegroup.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Jing', 'LASTNAME': 'Han', 'EMAIL': 'jing.han@customerexperiencegroup.com', 'LINKEDIN': None, 'DESIGNATION': 'Executive Assistant to CEO'}
# {'ORGANIZATION': 'dormakaba, access solutions americas', 'INDUSTRY': None, 'WEBSITE': 'dorma.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Shirley', 'LASTNAME': 'Alcantara', 'EMAIL': 'shirley.alcantara@dorma.com', 'LINKEDIN': None, 'DESIGNATION': 'Secretary to the Regional Sales Director'}
# {'ORGANIZATION': 'ellery consulting', 'INDUSTRY': None, 'WEBSITE': 'elleryconsulting.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Tracey', 'LASTNAME': 'Lebeanya', 'EMAIL': 'tracey@elleryconsulting.com', 'LINKEDIN': None, 'DESIGNATION': 'Director of Strategy'}
# {'ORGANIZATION': 'emirates international group', 'INDUSTRY': None, 'WEBSITE': 'emiratesint.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Marie', 'LASTNAME': 'Gormley', 'EMAIL': 'marie@emiratesint.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'express global residency & resettlement consultants (egrrc)', 'INDUSTRY': None, 'WEBSITE': 'egrrc.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Katrina', 'LASTNAME': 'Nacu', 'EMAIL': 'katrina@egrrc.com', 'LINKEDIN': None, 'DESIGNATION': 'Customer Care Supervisor'}
# {'ORGANIZATION': 'futurevision', 'INDUSTRY': None, 'WEBSITE': 'futurevisionme.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Joy-Ann', 'LASTNAME': 'Macoco', 'EMAIL': 'joy@futurevisionme.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Setup Consultant'}
# {'ORGANIZATION': 'g consulting fze', 'INDUSTRY': None, 'WEBSITE': 'gconsultingco.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Patrick', 'LASTNAME': 'Gambin', 'EMAIL': 'patrick.gambin@gconsultingco.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'global express legal translation', 'INDUSTRY': None, 'WEBSITE': 'legalarabictranslation.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'LAURA', 'LASTNAME': 'NOURA LANNOCCA', 'EMAIL': 'laura@legalarabictranslation.com', 'LINKEDIN': None, 'DESIGNATION': 'Founder & C.E.O.'}
# {'ORGANIZATION': 'hermes apply | موسسه مهاجرتی هرمس اپلای', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Iran', 'CITY': 'Tehran Province, Iran', 'FIRSTNAME': 'Mahgol', 'LASTNAME': 'Movahedi', 'EMAIL': 'm.movahedi@hermesapply.com', 'LINKEDIN': 'https://www.linkedin.com/in/mahgol-movahedi-080332242/', 'DESIGNATION': 'Immigration Consultant'}
# {'ORGANIZATION': 'holistic legacy accounting (s.p.s - l.l.c)', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': None, 'CITY': 'Ajman', 'FIRSTNAME': 'Mohammad Yousef Mohammad Mosleh', 'LASTNAME': None, 'EMAIL': 'hamada.altareefe@yahoo.com', 'LINKEDIN': None, 'DESIGNATION': None}
# {'ORGANIZATION': 'ideal b international', 'INDUSTRY': None, 'WEBSITE': 'ibdubai.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'SETUP', 'LASTNAME': 'BUSINESS IN UAE', 'EMAIL': 'business@ibdubai.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'immigrents consulting', 'INDUSTRY': None, 'WEBSITE': 'immigrents.ca', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Yousuf', 'LASTNAME': 'Khan', 'EMAIL': 'yousuf.khan@immigrents.ca', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'immivest global immigration services', 'INDUSTRY': None, 'WEBSITE': 'immivest.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Hina', 'LASTNAME': 'Zakir', 'EMAIL': 'hina@immivest.com', 'LINKEDIN': None, 'DESIGNATION': 'Immigration Case Processing Manager'}
# {'ORGANIZATION': 'independent advisor', 'INDUSTRY': None, 'WEBSITE': 'corprecover.co.za', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Richard', 'LASTNAME': 'Shediac', 'EMAIL': 'richards@corprecover.co.za', 'LINKEDIN': None, 'DESIGNATION': 'Strategy Advisor'}
# {'ORGANIZATION': 'merlintech fze', 'INDUSTRY': None, 'WEBSITE': 'merlintech.fi', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Reima', 'LASTNAME': 'Okkola', 'EMAIL': 'reima@merlintech.fi', 'LINKEDIN': None, 'DESIGNATION': 'Chairman'}
# {'ORGANIZATION': 'moirai legal consultancy fzc', 'INDUSTRY': None, 'WEBSITE': 'moirailegal.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Suresh', 'LASTNAME': 'Coelho', 'EMAIL': 'suresh.coelho@moirailegal.ae', 'LINKEDIN': None, 'DESIGNATION': 'Partner'}
# {'ORGANIZATION': 'morison (uae) consulting', 'INDUSTRY': None, 'WEBSITE': 'morisonmenon.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Ahsan', 'LASTNAME': 'Saleem', 'EMAIL': 'ahsan@morisonmenon.com', 'LINKEDIN': None, 'DESIGNATION': 'General Accountant'}
# {'ORGANIZATION': 'parker randall uae', 'INDUSTRY': None, 'WEBSITE': 'parkerrandalluae.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abdul', 'LASTNAME': 'Rahuman', 'EMAIL': 'abdulrahuman@parkerrandalluae.com', 'LINKEDIN': None, 'DESIGNATION': 'Audit Manager'}
# {'ORGANIZATION': 'polinsys', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'United Arab Emirates', 'CITY': 'Sharjah Emirate, United Arab Emirates', 'FIRSTNAME': 'Helna', 'LASTNAME': 'W', 'EMAIL': 'hw@polinsys.com', 'LINKEDIN': 'https://www.linkedin.com/in/helna-w-50a479235/', 'DESIGNATION': 'Immigration Specialist'}
# {'ORGANIZATION': 'sia accounting & auditing llc', 'INDUSTRY': None, 'WEBSITE': 'siauae.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Sunil', 'LASTNAME': 'Varghese', 'EMAIL': 'sunil@siauae.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'silver squares', 'INDUSTRY': None, 'WEBSITE': 'silversquaresme.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Samm', 'LASTNAME': 'Medina', 'EMAIL': 'samm.medina@silversquaresme.com', 'LINKEDIN': None, 'DESIGNATION': 'Projects and Partnerships'}
# {'ORGANIZATION': 'step-up transaction follow up services', 'INDUSTRY': None, 'WEBSITE': 'step-up.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Rana', 'LASTNAME': 'Said', 'EMAIL': 'rana@step-up.ae', 'LINKEDIN': None, 'DESIGNATION': 'Business Development Manager'}
# {'ORGANIZATION': 'strat!gos', 'INDUSTRY': None, 'WEBSITE': 'stratigosconsulting.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Peter', 'LASTNAME': 'Vanderwal', 'EMAIL': 'peter@stratigosconsulting.com', 'LINKEDIN': None, 'DESIGNATION': 'Chief Executive Officer'}
# {'ORGANIZATION': 'tenl.io', 'INDUSTRY': None, 'WEBSITE': 'tenl.io', 'COUNTRY': 'Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Jam', 'LASTNAME': 'Javier', 'EMAIL': 'jam@tenl.io', 'LINKEDIN': None, 'DESIGNATION': 'Community Manager'}
# {'ORGANIZATION': 'uae biz trade', 'INDUSTRY': None, 'WEBSITE': 'uaebiz.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Lucky', 'LASTNAME': 'Ramirez', 'EMAIL': 'lucky@uaebiz.ae', 'LINKEDIN': None, 'DESIGNATION': 'Sales Executive'}
# {'ORGANIZATION': 'universal business links - dubai', 'INDUSTRY': None, 'WEBSITE': 'ublcsp.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Abinesh', 'LASTNAME': 'Madhu', 'EMAIL': 'abinesh@ublcsp.com', 'LINKEDIN': None, 'DESIGNATION': 'Business Consultant'}
# {'ORGANIZATION': 'vault bucks consultancy', 'INDUSTRY': None, 'WEBSITE': 'vbc.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Vijay', 'LASTNAME': 'Thakur', 'EMAIL': 'vijay@vbc.ae', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director'}
# {'ORGANIZATION': 'vital corporate solutions', 'INDUSTRY': None, 'WEBSITE': 'vitaluae.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Christine', 'LASTNAME': 'Aslim', 'EMAIL': 'christine@vitaluae.com', 'LINKEDIN': None, 'DESIGNATION': 'Client Relationship Officer'}
# {'ORGANIZATION': 'wellness with tish', 'INDUSTRY': None, 'WEBSITE': 'wellnesswithtish.com', 'COUNTRY': 'Dubai, Dubai, United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Tisha', 'LASTNAME': 'Bhatia', 'EMAIL': 'tisha@wellnesswithtish.com', 'LINKEDIN': None, 'DESIGNATION': 'Entrepreneur'}
# {'ORGANIZATION': 'worldwide accounts & taxes solutions llc', 'INDUSTRY': None, 'WEBSITE': 'wats.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Ali', 'LASTNAME': None, 'EMAIL': 'ali@wats.ae', 'LINKEDIN': None, 'DESIGNATION': 'Finance , Accounts and Tax reporting'}
# {'ORGANIZATION': "y's consultancy fz lle", 'INDUSTRY': None, 'WEBSITE': 'ys-consultancy.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Hiroshi', 'LASTNAME': 'Yamaoka', 'EMAIL': 'h.yamaoka@ys-consultancy.com', 'LINKEDIN': None, 'DESIGNATION': 'Managing Director / Owner'}
# {'ORGANIZATION': 'مكتب علي الناصر', 'INDUSTRY': 'Accounting', 'WEBSITE': 'ans-cpa.com', 'COUNTRY': None, 'CITY': None, 'FIRSTNAME': 'Walaa', 'LASTNAME': 'Almalki', 'EMAIL': 'w.almalki@ans-cpa.com', 'LINKEDIN': 'https://www.linkedin.com/in/walaa-almalki-a7b088156', 'DESIGNATION': 'Partner'}
# {'ORGANIZATION': 'ِAL RAQEEM INTELLECTUAL PROPERTY', 'INDUSTRY': None, 'WEBSITE': 'alraqeem.ae', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Kaycee Lynn', 'LASTNAME': 'Austria', 'EMAIL': 'kaycee@alraqeem.ae', 'LINKEDIN': None, 'DESIGNATION': 'Graphic/Web Designer, Social Media Devt & PRO secretary'}
# {'ORGANIZATION': 'گروه مهاجرتی ادیسه', 'INDUSTRY': None, 'WEBSITE': None, 'COUNTRY': 'Iran', 'CITY': 'Tehran Province, Iran', 'FIRSTNAME': 'Masoud', 'LASTNAME': 'Moosavi', 'EMAIL': 'masoud@wcoe.ca', 'LINKEDIN': 'https://www.linkedin.com/in/moosavism/', 'DESIGNATION': 'Senior Immigration Consultant'}
# {'ORGANIZATION': '施耐德电气(中国)有限公司上海分公司', 'INDUSTRY': None, 'WEBSITE': 'schneider-electric.com', 'COUNTRY': 'United Arab Emirates', 'CITY': None, 'FIRSTNAME': 'Francoise', 'LASTNAME': 'Jolibois', 'EMAIL': 'francoise.jolibois@schneider-electric.com', 'LINKEDIN': None, 'DESIGNATION': 'Energy Business Unit Finance business partner and Regional Execution Center Finance Manager'}
#                                                                               ORGANIZATION  \
# ORGANIZATION_COPY
# The Accountant                                                              The Accountant
# Xara                                                                                  Xara
# Xara                                                                                  Xara
# Xara                                                                                  Xara
# Farahat & Co. Auditing Firm, Vat Consultants  Farahat & Co. Auditing Firm, Vat Consultants
#
#                                                 INDUSTRY           WEBSITE  \
# ORGANIZATION_COPY
# The Accountant                                Accounting  theaccountant.ae
# Xara                                          Accounting          xara.com
# Xara                                          Accounting          xara.com
# Xara                                          Accounting          xara.com
# Farahat & Co. Auditing Firm, Vat Consultants  Accounting     farahatco.com
#
#                                              COUNTRY CITY FIRSTNAME  LASTNAME  \
# ORGANIZATION_COPY
# The Accountant                                   NaN  NaN       NaN       NaN
# Xara                                             NaN  NaN      Neil      Howe
# Xara                                             NaN  NaN      Mick  Robinson
# Xara                                             NaN  NaN       NaN       NaN
# Farahat & Co. Auditing Firm, Vat Consultants     NaN  NaN       NaN       NaN
#
#                                                               EMAIL  \
# ORGANIZATION_COPY
# The Accountant                                info@theaccountant.ae
# Xara                                                 neilh@xara.com
# Xara                                                  mick@xara.com
# Xara                                                 sales@xara.com
# Farahat & Co. Auditing Firm, Vat Consultants    anwer@farahatco.com
#
#                                                                            LINKEDIN  \
# ORGANIZATION_COPY
# The Accountant                                                                  NaN
# Xara                                          https://www.linkedin.com/in/neil-howe
# Xara                                                                            NaN
# Xara                                                                            NaN
# Farahat & Co. Auditing Firm, Vat Consultants                                    NaN
#
#                                                            DESIGNATION
# ORGANIZATION_COPY
# The Accountant                                                     NaN
# Xara                                          Chief Technology Officer
# Xara                                                               NaN
# Xara                                                               NaN
# Farahat & Co. Auditing Firm, Vat Consultants                       NaN
